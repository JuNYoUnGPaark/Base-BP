# %%
import os
import glob
import time
import random
import gc
import numpy as np
import h5py
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from scipy.interpolate import interp1d
from scipy.integrate import trapezoid

# ==========================================
# [0] Experiment settings
# ==========================================
MAT_DIR = "/content/drive/MyDrive/Colab Notebooks/PulseDB"  # directory containing p*.mat
SEGMENT_LIMIT = None
PAD_LEN = 200
SEC_PER_SEGMENT = 10.0

BATCH_SIZE = 32
EPOCHS = 100
LR = 1e-3
WEIGHT_DECAY = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SEED = 42
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Using Device: {DEVICE}")

# Phase-3 protocol config
N_FOLDS = 5
BLOCK_GAP_MIN = 0                 # fixed
TIME_GAP_MIN = 5                  # fixed (main protocol candidate)
TEST_DUR_MIN = 5                  # fixed
TRAIN_DUR_SWEEP_MIN = [3, 5, 10, 15]
VAL_FRAC_IN_TRAIN = 0.20

FILTERING_SWEEP = [False, True]   # NEW

# ==========================================
# [1] Re-sample + Prior feature
# ==========================================
def preprocess_ensemble_by_rpeaks(ppg_raw, rpeaks_raw, sbp, dbp, target_len=125, threshold_corr=0.7):
    """
    NEW filtering:
      1) BP range filter
      2) split beats by ECG R-peaks
      3) resample each beat to target_len
      4) ensemble average + consistency check via correlation
    Return: processed PPG (0~1) or None (skip)
    """
    if not (50 <= sbp <= 250) or not (30 <= dbp <= 160):
        return None

    ppg = ppg_raw.squeeze()
    rpeaks = rpeaks_raw.squeeze()
    rpeaks = np.sort(rpeaks.astype(int))

    beats = []
    for i in range(len(rpeaks) - 1):
        start, end = rpeaks[i], rpeaks[i + 1]
        if start < 0 or end > len(ppg):
            continue
        beat_segment = ppg[start:end]
        if len(beat_segment) < 20:
            continue

        x_old = np.linspace(0, 1, len(beat_segment))
        x_new = np.linspace(0, 1, target_len)
        f_interp = interp1d(x_old, beat_segment, kind="linear", fill_value="extrapolate")
        beats.append(f_interp(x_new))

    if len(beats) < 5:
        return None

    beats = np.array(beats)
    ensemble_avg = np.mean(beats, axis=0)

    e_min, e_max = ensemble_avg.min(), ensemble_avg.max()
    if e_max - e_min > 1e-6:
        ensemble_avg = (ensemble_avg - e_min) / (e_max - e_min)

    correlations = [np.corrcoef(ensemble_avg, b)[0, 1] for b in beats]
    consistent_beats_count = sum(1 for c in correlations if c >= threshold_corr)

    if (consistent_beats_count / len(beats)) < 0.7:
        return None

    return ensemble_avg.astype(np.float32)

def cubic_resample(ppg, target_len=PAD_LEN):
    x_old = np.linspace(0, 1, len(ppg))
    x_new = np.linspace(0, 1, target_len)
    if len(ppg) < 4:
        return np.interp(x_new, x_old, ppg).astype(np.float32)
    try:
        f = interp1d(x_old, ppg, kind="cubic", bounds_error=False, fill_value="extrapolate")
        return f(x_new).astype(np.float32)
    except Exception:
        return np.interp(x_new, x_old, ppg).astype(np.float32)

def extract_multiscale_morph_features(ppg_01):
    scales = [100, 150, 200, 250]
    all_features = []
    for scale in scales:
        x = cubic_resample(ppg_01, scale)

        peak_idx = int(np.argmax(x))
        end_idx = scale - 1

        vp = float(x[peak_idx])
        vt = float(x[end_idx])
        dv = vp - vt
        vm = float(np.mean(x))
        std_val = float(np.std(x))

        tvp = peak_idx / scale

        diff = np.diff(x)
        kmax = float(np.max(diff)) if len(diff) > 0 else 0.0
        tkmax = (int(np.argmax(diff)) / scale) if len(diff) > 0 else 0.0

        amax = float(trapezoid(x[:peak_idx])) if peak_idx > 0 else 0.0

        centered = x - vm
        skew_approx = float(np.mean(centered**3) / (std_val**3)) if std_val > 0 else 0.0
        kurt_approx = float(np.mean(centered**4) / (std_val**4)) if std_val > 0 else 0.0

        all_features.extend([vp, vt, dv, vm, kmax, tkmax, amax, std_val, tvp, skew_approx, kurt_approx])

    return np.array(all_features, dtype=np.float32)

# ==========================================
# [2] Load data (filtering toggle)
# ==========================================
def load_data_from_mat(mat_path, segment_limit=None, filtering=False):
    segments, priors, targets = [], [], []
    skip_bp, skip_noise = 0, 0

    with h5py.File(mat_path, "r") as f:
        sw = f["Subj_Wins"]
        ppg_refs = sw["PPG_F"][0]
        sbp_refs = sw["SegSBP"][0]
        dbp_refs = sw["SegDBP"][0]

        ecg_refs = sw["ECG_RPeaks"][0] if "ECG_RPeaks" in sw.keys() else None

        total = min(len(ppg_refs), segment_limit) if segment_limit else len(ppg_refs)

        for i in range(total):
            sbp = float(f[sbp_refs[i]][()][0][0])
            dbp = float(f[dbp_refs[i]][()][0][0])

            if filtering:
                if ecg_refs is None:
                    # cannot run filtering without ECG_RPeaks
                    skip_noise += 1
                    continue

                ppg_raw = f[ppg_refs[i]][()]
                rpeaks_raw = f[ecg_refs[i]][()]
                processed_ppg = preprocess_ensemble_by_rpeaks(ppg_raw, rpeaks_raw, sbp, dbp)

                if processed_ppg is None:
                    if not (50 <= sbp <= 250) or not (30 <= dbp <= 160):
                        skip_bp += 1
                    else:
                        skip_noise += 1
                    continue

                ppg = processed_ppg  # (125,) 0~1
            else:
                # baseline: use PPG_F as-is (already 0~1 per segment)
                ppg = f[ppg_refs[i]][()].squeeze().astype(np.float32)

            segments.append(ppg)
            priors.append(extract_multiscale_morph_features(ppg))
            targets.append([sbp, dbp])

    if filtering:
        print(f"✅ filtering=True | kept: {len(segments)} / {total}")
        print(f"❌ excluded: (bp_range: {skip_bp}, noise/other: {skip_noise})")
    else:
        print(f"✅ filtering=False | kept: {len(segments)} / {total}")

    return segments, np.stack(priors).astype(np.float32), np.array(targets, dtype=np.float32)

# ==========================================
# [3] Dataset
# ==========================================
class PPGDatasetRawY(Dataset):
    def __init__(self, segments, priors, targets_mmHg):
        self.segments = segments
        self.priors = priors
        self.targets = targets_mmHg

    def __len__(self):
        return len(self.segments)

    def __getitem__(self, idx):
        x = cubic_resample(self.segments[idx], PAD_LEN)
        x = torch.tensor(x, dtype=torch.float32).unsqueeze(0)
        p = torch.tensor(self.priors[idx], dtype=torch.float32)
        y = torch.tensor(self.targets[idx], dtype=torch.float32)
        return x, p, y

# ==========================================
# [4] Model
# ==========================================
class MorphCNNRegressor(nn.Module):
    def __init__(self, prior_dim=44):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(1, 32, 7, padding=3),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(32, 64, 5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, 5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, 256, 3, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )

        self.fc_prior = nn.Sequential(
            nn.Linear(prior_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.ReLU()
        )

        self.fc_out = nn.Sequential(
            nn.Linear(256 + 256, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 2)
        )

    def forward(self, x, prior):
        feat = self.cnn(x).squeeze(-1)
        pfeat = self.fc_prior(prior)
        return self.fc_out(torch.cat([feat, pfeat], dim=1))

# ==========================================
# [5] Train-only label scaler
# ==========================================
class LabelScaler2D:
    def __init__(self, mode="minmax", eps=1e-6):
        assert mode in ["minmax", "zscore"]
        self.mode = mode
        self.eps = eps
        self.fitted = False

    def fit(self, y_train_mmHg: np.ndarray):
        y = np.asarray(y_train_mmHg, dtype=np.float32)
        if self.mode == "minmax":
            self.y_min = y.min(axis=0)
            self.y_max = y.max(axis=0)
        else:
            self.y_mean = y.mean(axis=0)
            self.y_std = y.std(axis=0)
        self.fitted = True
        return self

    def transform(self, y_mmHg: torch.Tensor) -> torch.Tensor:
        assert self.fitted
        if self.mode == "minmax":
            y_min = torch.tensor(self.y_min, device=y_mmHg.device, dtype=y_mmHg.dtype)
            y_max = torch.tensor(self.y_max, device=y_mmHg.device, dtype=y_mmHg.dtype)
            return (y_mmHg - y_min) / (y_max - y_min + self.eps)
        else:
            y_mean = torch.tensor(self.y_mean, device=y_mmHg.device, dtype=y_mmHg.dtype)
            y_std = torch.tensor(self.y_std, device=y_mmHg.device, dtype=y_mmHg.dtype)
            return (y_mmHg - y_mean) / (y_std + self.eps)

    def inverse(self, y_scaled: torch.Tensor) -> torch.Tensor:
        assert self.fitted
        if self.mode == "minmax":
            y_min = torch.tensor(self.y_min, device=y_scaled.device, dtype=y_scaled.dtype)
            y_max = torch.tensor(self.y_max, device=y_scaled.device, dtype=y_scaled.dtype)
            return y_scaled * (y_max - y_min + self.eps) + y_min
        else:
            y_mean = torch.tensor(self.y_mean, device=y_scaled.device, dtype=y_scaled.dtype)
            y_std = torch.tensor(self.y_std, device=y_scaled.device, dtype=y_scaled.dtype)
            return y_scaled * (y_std + self.eps) + y_mean

# ==========================================
# [6] Train / Eval
# ==========================================
def set_seed(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def train_one_model(train_loader, val_loader, scaler: LabelScaler2D):
    model = MorphCNNRegressor(prior_dim=44).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    criterion = nn.MSELoss()

    best_val = float("inf")
    best_state = None

    for _epoch in range(1, EPOCHS + 1):
        model.train()
        for x, p, y_mmHg in train_loader:
            x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
            y = scaler.transform(y_mmHg)
            pred = model(x, p)
            loss = criterion(pred, y)
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        val_losses = []
        with torch.no_grad():
            for x, p, y_mmHg in val_loader:
                x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
                y = scaler.transform(y_mmHg)
                pred = model(x, p)
                val_losses.append(float(criterion(pred, y).item()))
        avg_val = float(np.mean(val_losses)) if len(val_losses) else float("inf")

        if avg_val < best_val:
            best_val = avg_val
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    if best_state is not None:
        model.load_state_dict(best_state)
    return model

def eval_mae_sd_mmHg(model, loader, scaler: LabelScaler2D):
    model.eval()
    errs = []
    with torch.no_grad():
        for x, p, y_mmHg in loader:
            x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
            pred_scaled = model(x, p)
            pred_mmHg = scaler.inverse(pred_scaled)
            err = (pred_mmHg - y_mmHg).detach().cpu().numpy()
            errs.append(err)

    if len(errs) == 0:
        return dict(mae_sbp=np.nan, sd_sbp=np.nan, mae_dbp=np.nan, sd_dbp=np.nan, n=0)

    E = np.concatenate(errs, axis=0)
    e_sbp, e_dbp = E[:, 0], E[:, 1]
    return dict(
        mae_sbp=float(np.mean(np.abs(e_sbp))),
        sd_sbp=float(np.std(e_sbp, ddof=0)),
        mae_dbp=float(np.mean(np.abs(e_dbp))),
        sd_dbp=float(np.std(e_dbp, ddof=0)),
        n=int(E.shape[0]),
    )

# ==========================================
# [7] Phase-3 Engine (multi-patient + filtering sweep)
# ==========================================
def segs_from_minutes(minutes: float) -> int:
    return int((minutes * 60.0) / SEC_PER_SEGMENT)

def min_required_total_len_for_any_traindur():
    """
    Conservative min segments to ensure ALL TrainDur in sweep can run for all folds:
      fold_len = floor(total_len / N_FOLDS)  (BlockGap=0)
      Need per fold >= max_train + gap + test
      => total_len >= N_FOLDS * (max_train + gap + test)
    """
    max_tr_segs = segs_from_minutes(max(TRAIN_DUR_SWEEP_MIN))
    gap_segs = segs_from_minutes(TIME_GAP_MIN)
    test_segs = segs_from_minutes(TEST_DUR_MIN)
    need_per_fold = max_tr_segs + gap_segs + test_segs
    return N_FOLDS * need_per_fold

def run_phase3_one_patient(mat_path: str, filtering: bool):
    set_seed(SEED)

    print("\n" + "=" * 80)
    print(f"[PATIENT] {os.path.basename(mat_path)} | filtering={filtering}")
    print("=" * 80)

    segments, priors, targets_mmHg = load_data_from_mat(mat_path, segment_limit=SEGMENT_LIMIT, filtering=filtering)
    ds = PPGDatasetRawY(segments, priors, targets_mmHg)

    total_len = len(ds)
    print(f"[Data Ready] total_len={total_len}")

    min_need = min_required_total_len_for_any_traindur()
    if total_len < min_need:
        raise ValueError(f"Insufficient segments: total_len={total_len} < min_required={min_need}")

    b_gap_segs = segs_from_minutes(BLOCK_GAP_MIN)
    gap_segs   = segs_from_minutes(TIME_GAP_MIN)
    test_segs  = segs_from_minutes(TEST_DUR_MIN)

    available_len = total_len - (N_FOLDS - 1) * b_gap_segs
    if available_len <= 0:
        raise ValueError("Not enough segments for the requested N_FOLDS and BLOCK_GAP_MIN.")

    fold_len = available_len // N_FOLDS
    if fold_len <= 0:
        raise ValueError("Computed fold_len <= 0.")
    if fold_len <= test_segs + 1:
        raise ValueError("Fold too short for test duration.")

    print("\n=== PHASE 3 CONFIG ===")
    print(f"N_FOLDS={N_FOLDS} | BlockGap={BLOCK_GAP_MIN}min ({b_gap_segs} segs)")
    print(f"FoldLen={fold_len} segs (~{fold_len*SEC_PER_SEGMENT/60.0:.2f} min)")
    print(f"TimeGap={TIME_GAP_MIN}min ({gap_segs} segs) | TestDur={TEST_DUR_MIN}min ({test_segs} segs)")
    print(f"TrainDur sweep (min): {TRAIN_DUR_SWEEP_MIN}")
    print(f"ValFracInTrain={VAL_FRAC_IN_TRAIN:.2f}")

    patient_summary = {}  # tr_min -> {valid_folds, mae_sbp, sd_sbp, mae_dbp, sd_dbp}
    t_global0 = time.time()

    for tr_min in TRAIN_DUR_SWEEP_MIN:
        tr_segs = segs_from_minutes(tr_min)

        print(f"\n===============================")
        print(f" TrainDur = {tr_min} min")
        print(f"===============================")

        fold_stats = []
        t_tr0 = time.time()

        for f_idx in range(N_FOLDS):
            fold_start = f_idx * (fold_len + b_gap_segs)
            fold_end   = fold_start + fold_len

            test_end = fold_end
            test_start = test_end - test_segs

            train_end = test_start - gap_segs
            train_start = train_end - tr_segs

            if train_start < fold_start or train_end > test_start:
                print(f"[Fold {f_idx+1}] SKIP (insufficient room): "
                      f"fold=({fold_start},{fold_end}) train=({train_start},{train_end}) test=({test_start},{test_end})")
                fold_stats.append(None)
                continue

            train_indices = list(range(train_start, train_end))
            test_indices  = list(range(test_start, test_end))

            n_total = len(train_indices)
            n_val = max(1, int(n_total * VAL_FRAC_IN_TRAIN))
            if n_total - n_val < 1:
                print(f"[Fold {f_idx+1}] SKIP (train too small after val split).")
                fold_stats.append(None)
                continue

            real_train_idx = train_indices[:-n_val]
            val_idx        = train_indices[-n_val:]

            y_train = targets_mmHg[np.array(real_train_idx)]
            scaler = LabelScaler2D(mode="minmax", eps=1e-6).fit(y_train)

            train_loader = DataLoader(Subset(ds, real_train_idx), batch_size=BATCH_SIZE, shuffle=True)
            val_loader   = DataLoader(Subset(ds, val_idx), batch_size=BATCH_SIZE, shuffle=False)
            test_loader  = DataLoader(Subset(ds, test_indices), batch_size=BATCH_SIZE, shuffle=False)

            t0 = time.time()
            model = train_one_model(train_loader, val_loader, scaler)
            stat = eval_mae_sd_mmHg(model, test_loader, scaler)
            elapsed = time.time() - t0

            stat.update({
                "fold": f_idx + 1,
                "train_dur_min": tr_min,
                "train_n": len(real_train_idx),
                "val_n": len(val_idx),
                "test_n": len(test_indices),
                "elapsed_s": float(elapsed),
            })
            fold_stats.append(stat)

            print(f"\n[Fold {f_idx+1}] fold=({fold_start},{fold_end}) | "
                  f"train=({train_start},{train_end}) | test=({test_start},{test_end})")
            print(f"  sizes Train/Val/Test: {len(real_train_idx)}/{len(val_idx)}/{len(test_indices)}")
            print(f"  SBP: MAE={stat['mae_sbp']:.4f} | SD={stat['sd_sbp']:.4f}")
            print(f"  DBP: MAE={stat['mae_dbp']:.4f} | SD={stat['sd_dbp']:.4f}")
            print(f"  elapsed: {elapsed:.1f}s")

            del model
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
            gc.collect()

        valid = [fs for fs in fold_stats if fs is not None and np.isfinite(fs["mae_sbp"])]

        def mean_key(key):
            vals = [v[key] for v in valid]
            return float(np.mean(vals)) if len(vals) else float("nan")

        tr_summary = {
            "valid_folds": len(valid),
            "mae_sbp": mean_key("mae_sbp"),
            "sd_sbp": mean_key("sd_sbp"),
            "mae_dbp": mean_key("mae_dbp"),
            "sd_dbp": mean_key("sd_dbp"),
        }
        patient_summary[tr_min] = tr_summary

        print(f"\n--- TrainDur {tr_min} min SUMMARY (TimeGap={TIME_GAP_MIN}min) ---")
        print(f"ValidFolds: {tr_summary['valid_folds']}/{N_FOLDS}")
        print(f"Avg SBP: MAE={tr_summary['mae_sbp']:.4f} | SD={tr_summary['sd_sbp']:.4f}")
        print(f"Avg DBP: MAE={tr_summary['mae_dbp']:.4f} | SD={tr_summary['sd_dbp']:.4f}")
        print(f"Elapsed for this TrainDur: {time.time() - t_tr0:.1f}s")

    print(f"\n[Patient Done] {os.path.basename(mat_path)} | filtering={filtering} | elapsed: {time.time() - t_global0:.1f}s")
    return patient_summary

def run_phase3_all_patients(pulsedb_dir: str):
    patient_files = sorted(glob.glob(os.path.join(pulsedb_dir, "p*.mat")))
    if len(patient_files) == 0:
        raise FileNotFoundError(f"No .mat files found under: {pulsedb_dir}")

    print("\n" + "#" * 80)
    print(f"[RUN ALL] Found {len(patient_files)} patients in: {pulsedb_dir}")
    for f in patient_files:
        print("  -", os.path.basename(f))
    print("#" * 80)

    results_by_filter = {}  # filtering -> list of {"patient", "summary"}
    skipped_by_filter = {}  # filtering -> list of (patient, reason)

    t0_all = time.time()

    for filtering in FILTERING_SWEEP:
        print("\n" + "#" * 80)
        print(f"[FILTER SWEEP] filtering={filtering}")
        print("#" * 80)

        all_results = []
        skipped = []

        for i, mat_path in enumerate(patient_files, 1):
            print("\n" + "-" * 80)
            print(f"[{i}/{len(patient_files)}] START {os.path.basename(mat_path)} | filtering={filtering}")
            print("-" * 80)

            try:
                summary = run_phase3_one_patient(mat_path, filtering=filtering)
                all_results.append({"patient": os.path.basename(mat_path), "summary": summary})
            except ValueError as e:
                reason = str(e)
                print(f"[SKIP PATIENT] {os.path.basename(mat_path)} | filtering={filtering} | reason: {reason}")
                skipped.append((os.path.basename(mat_path), reason))
            except Exception as e:
                reason = f"Unexpected error: {type(e).__name__}: {e}"
                print(f"[SKIP PATIENT] {os.path.basename(mat_path)} | filtering={filtering} | reason: {reason}")
                skipped.append((os.path.basename(mat_path), reason))

            if torch.cuda.is_available():
                torch.cuda.empty_cache()
            gc.collect()

        results_by_filter[filtering] = all_results
        skipped_by_filter[filtering] = skipped

        # ---- FINAL SUMMARY for this filtering mode ----
        print("\n" + "#" * 80)
        print(f"[FINAL SUMMARY] filtering={filtering} | patient-level mean/std across usable patients")
        print(f"Used patients: {len(all_results)} / {len(patient_files)}")
        print("#" * 80)

        def safe_mean(arr):
            return float(np.mean(arr)) if len(arr) else float("nan")

        def safe_std(arr):
            return float(np.std(arr, ddof=1)) if len(arr) >= 2 else float("nan")

        for tr_min in TRAIN_DUR_SWEEP_MIN:
            sbp_maes, sbp_sds, dbp_maes, dbp_sds = [], [], [], []
            used_patients_for_tr = 0

            for item in all_results:
                g = item["summary"].get(tr_min, None)
                if g is None:
                    continue
                if not np.isfinite(g["mae_sbp"]):
                    continue
                used_patients_for_tr += 1
                sbp_maes.append(g["mae_sbp"])
                sbp_sds.append(g["sd_sbp"])
                dbp_maes.append(g["mae_dbp"])
                dbp_sds.append(g["sd_dbp"])

            print(f"\n[TrainDur={tr_min} min] PatientsUsed: {used_patients_for_tr}/{len(all_results)}")
            print(f"  SBP(MAE): mean={safe_mean(sbp_maes):.4f} | std={safe_std(sbp_maes):.4f}")
            print(f"  DBP(MAE): mean={safe_mean(dbp_maes):.4f} | std={safe_std(dbp_maes):.4f}")
            print(f"  SBP(err SD): mean={safe_mean(sbp_sds):.4f} | std={safe_std(sbp_sds):.4f}")
            print(f"  DBP(err SD): mean={safe_mean(dbp_sds):.4f} | std={safe_std(dbp_sds):.4f}")

        # Report skipped patients
        if len(skipped) > 0:
            print("\n" + "#" * 80)
            print(f"[SKIPPED PATIENTS] filtering={filtering}")
            print("#" * 80)
            for p, r in skipped:
                print(f"- {p}: {r}")

    print(f"\n[ALL DONE] Total elapsed: {time.time() - t0_all:.1f}s")
    return results_by_filter, skipped_by_filter

# ==========================================
# [MAIN]
# ==========================================
if __name__ == "__main__":
    run_phase3_all_patients(MAT_DIR)
# Out:
# Using Device: cuda
#
# ################################################################################
# [RUN ALL] Found 10 patients in: /content/drive/MyDrive/Colab Notebooks/PulseDB
#   - p001855.mat
#   - p004679.mat
#   - p004833.mat
#   - p009993.mat
#   - p030582.mat
#   - p030589.mat
#   - p030670.mat
#   - p040299.mat
#   - p041107.mat
#   - p043774.mat
# ################################################################################
#
# ################################################################################
# [FILTER SWEEP] filtering=False
# ################################################################################
#
# --------------------------------------------------------------------------------
# [1/10] START p001855.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p001855.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 2178 / 2178
# [Data Ready] total_len=2178
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=435 segs (~72.50 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,435) | train=(357,375) | test=(405,435)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=1.3339 | SD=1.3590
#   DBP: MAE=0.9954 | SD=1.0587
#   elapsed: 11.8s
#
# [Fold 2] fold=(435,870) | train=(792,810) | test=(840,870)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=9.2593 | SD=3.1413
#   DBP: MAE=4.3660 | SD=1.5413
#   elapsed: 2.7s
#
# [Fold 3] fold=(870,1305) | train=(1227,1245) | test=(1275,1305)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.6401 | SD=1.2936
#   DBP: MAE=2.1304 | SD=0.6524
#   elapsed: 3.3s
#
# [Fold 4] fold=(1305,1740) | train=(1662,1680) | test=(1710,1740)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.6231 | SD=2.7126
#   DBP: MAE=3.4682 | SD=1.6236
#   elapsed: 2.7s
#
# [Fold 5] fold=(1740,2175) | train=(2097,2115) | test=(2145,2175)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.6080 | SD=1.5590
#   DBP: MAE=0.9072 | SD=0.6413
#   elapsed: 2.6s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.0929 | SD=2.0131
# Avg DBP: MAE=2.3734 | SD=1.1035
# Elapsed for this TrainDur: 24.1s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,435) | train=(345,375) | test=(405,435)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=1.6006 | SD=1.7652
#   DBP: MAE=0.9300 | SD=1.1094
#   elapsed: 4.4s
#
# [Fold 2] fold=(435,870) | train=(780,810) | test=(840,870)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.9743 | SD=3.2364
#   DBP: MAE=1.8887 | SD=1.5556
#   elapsed: 4.7s
#
# [Fold 3] fold=(870,1305) | train=(1215,1245) | test=(1275,1305)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.6648 | SD=1.2010
#   DBP: MAE=2.1729 | SD=0.6629
#   elapsed: 3.6s
#
# [Fold 4] fold=(1305,1740) | train=(1650,1680) | test=(1710,1740)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=4.5151 | SD=2.7744
#   DBP: MAE=3.3030 | SD=1.6327
#   elapsed: 3.8s
#
# [Fold 5] fold=(1740,2175) | train=(2085,2115) | test=(2145,2175)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.5570 | SD=1.4644
#   DBP: MAE=1.2674 | SD=0.5451
#   elapsed: 4.1s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.2624 | SD=2.0883
# Avg DBP: MAE=1.9124 | SD=1.1011
# Elapsed for this TrainDur: 21.7s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,435) | train=(315,375) | test=(405,435)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.3071 | SD=1.5101
#   DBP: MAE=0.8620 | SD=1.0183
#   elapsed: 6.4s
#
# [Fold 2] fold=(435,870) | train=(750,810) | test=(840,870)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.5807 | SD=1.4217
#   DBP: MAE=1.6513 | SD=0.7649
#   elapsed: 6.6s
#
# [Fold 3] fold=(870,1305) | train=(1185,1245) | test=(1275,1305)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.6162 | SD=1.1523
#   DBP: MAE=1.4784 | SD=0.6661
#   elapsed: 6.6s
#
# [Fold 4] fold=(1305,1740) | train=(1620,1680) | test=(1710,1740)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.8223 | SD=2.7335
#   DBP: MAE=2.8850 | SD=1.6347
#   elapsed: 6.7s
#
# [Fold 5] fold=(1740,2175) | train=(2055,2115) | test=(2145,2175)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.1037 | SD=1.2888
#   DBP: MAE=1.5842 | SD=0.5334
#   elapsed: 6.3s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.0860 | SD=1.6213
# Avg DBP: MAE=1.6922 | SD=0.9235
# Elapsed for this TrainDur: 33.6s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,435) | train=(285,375) | test=(405,435)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=1.4850 | SD=1.6386
#   DBP: MAE=1.0036 | SD=1.1566
#   elapsed: 11.4s
#
# [Fold 2] fold=(435,870) | train=(720,810) | test=(840,870)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.3974 | SD=1.5508
#   DBP: MAE=1.9650 | SD=0.9594
#   elapsed: 10.3s
#
# [Fold 3] fold=(870,1305) | train=(1155,1245) | test=(1275,1305)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.6337 | SD=1.2511
#   DBP: MAE=0.7414 | SD=0.7026
#   elapsed: 9.4s
#
# [Fold 4] fold=(1305,1740) | train=(1590,1680) | test=(1710,1740)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.3131 | SD=2.9667
#   DBP: MAE=3.0886 | SD=1.6982
#   elapsed: 10.4s
#
# [Fold 5] fold=(1740,2175) | train=(2025,2115) | test=(2145,2175)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.7422 | SD=1.2885
#   DBP: MAE=1.3372 | SD=0.5291
#   elapsed: 10.0s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.5143 | SD=1.7391
# Avg DBP: MAE=1.6272 | SD=1.0092
# Elapsed for this TrainDur: 52.5s
#
# [Patient Done] p001855.mat | filtering=False | elapsed: 132.0s
#
# --------------------------------------------------------------------------------
# [2/10] START p004679.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p004679.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 1862 / 1862
# [Data Ready] total_len=1862
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=372 segs (~62.00 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,372) | train=(294,312) | test=(342,372)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.7749 | SD=3.3339
#   DBP: MAE=1.6070 | SD=1.5662
#   elapsed: 2.5s
#
# [Fold 2] fold=(372,744) | train=(666,684) | test=(714,744)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=5.4362 | SD=5.5817
#   DBP: MAE=2.6933 | SD=2.5239
#   elapsed: 2.6s
#
# [Fold 3] fold=(744,1116) | train=(1038,1056) | test=(1086,1116)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=10.0775 | SD=3.0928
#   DBP: MAE=4.4414 | SD=1.2805
#   elapsed: 2.8s
#
# [Fold 4] fold=(1116,1488) | train=(1410,1428) | test=(1458,1488)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=5.7689 | SD=2.5114
#   DBP: MAE=1.0943 | SD=1.3390
#   elapsed: 3.6s
#
# [Fold 5] fold=(1488,1860) | train=(1782,1800) | test=(1830,1860)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=24.1562 | SD=7.7042
#   DBP: MAE=9.3030 | SD=2.2887
#   elapsed: 2.6s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=9.6428 | SD=4.4448
# Avg DBP: MAE=3.8278 | SD=1.7996
# Elapsed for this TrainDur: 15.2s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,372) | train=(282,312) | test=(342,372)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.8207 | SD=3.1209
#   DBP: MAE=1.5529 | SD=1.4194
#   elapsed: 3.9s
#
# [Fold 2] fold=(372,744) | train=(654,684) | test=(714,744)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=5.2092 | SD=5.3822
#   DBP: MAE=2.3428 | SD=2.4057
#   elapsed: 4.5s
#
# [Fold 3] fold=(744,1116) | train=(1026,1056) | test=(1086,1116)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=10.5471 | SD=3.7379
#   DBP: MAE=4.0587 | SD=1.3123
#   elapsed: 4.2s
#
# [Fold 4] fold=(1116,1488) | train=(1398,1428) | test=(1458,1488)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=5.8998 | SD=2.8292
#   DBP: MAE=1.6454 | SD=1.5951
#   elapsed: 4.0s
#
# [Fold 5] fold=(1488,1860) | train=(1770,1800) | test=(1830,1860)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=21.7781 | SD=11.0230
#   DBP: MAE=7.5261 | SD=3.5268
#   elapsed: 4.4s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=9.2510 | SD=5.2186
# Avg DBP: MAE=3.4252 | SD=2.0519
# Elapsed for this TrainDur: 22.2s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,372) | train=(252,312) | test=(342,372)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.2859 | SD=2.8106
#   DBP: MAE=1.8670 | SD=1.4508
#   elapsed: 6.6s
#
# [Fold 2] fold=(372,744) | train=(624,684) | test=(714,744)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.7430 | SD=3.3882
#   DBP: MAE=1.7466 | SD=1.6306
#   elapsed: 6.9s
#
# [Fold 3] fold=(744,1116) | train=(996,1056) | test=(1086,1116)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.3965 | SD=4.1526
#   DBP: MAE=3.5383 | SD=3.0416
#   elapsed: 6.3s
#
# [Fold 4] fold=(1116,1488) | train=(1368,1428) | test=(1458,1488)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.1920 | SD=3.0946
#   DBP: MAE=1.2972 | SD=1.5840
#   elapsed: 6.6s
#
# [Fold 5] fold=(1488,1860) | train=(1740,1800) | test=(1830,1860)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=15.9036 | SD=9.8236
#   DBP: MAE=8.1835 | SD=5.3219
#   elapsed: 6.5s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.1042 | SD=4.6539
# Avg DBP: MAE=3.3265 | SD=2.6058
# Elapsed for this TrainDur: 33.9s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,372) | train=(222,312) | test=(342,372)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.0788 | SD=3.3554
#   DBP: MAE=2.2355 | SD=1.6567
#   elapsed: 10.1s
#
# [Fold 2] fold=(372,744) | train=(594,684) | test=(714,744)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.4635 | SD=3.6124
#   DBP: MAE=3.4539 | SD=1.4530
#   elapsed: 9.3s
#
# [Fold 3] fold=(744,1116) | train=(966,1056) | test=(1086,1116)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.4608 | SD=4.8024
#   DBP: MAE=4.3098 | SD=5.1420
#   elapsed: 9.4s
#
# [Fold 4] fold=(1116,1488) | train=(1338,1428) | test=(1458,1488)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.4072 | SD=2.7112
#   DBP: MAE=1.8705 | SD=1.9030
#   elapsed: 10.2s
#
# [Fold 5] fold=(1488,1860) | train=(1710,1800) | test=(1830,1860)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=14.4917 | SD=7.9866
#   DBP: MAE=9.6095 | SD=7.3990
#   elapsed: 10.1s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.7804 | SD=4.4936
# Avg DBP: MAE=4.2958 | SD=3.5107
# Elapsed for this TrainDur: 50.3s
#
# [Patient Done] p004679.mat | filtering=False | elapsed: 121.6s
#
# --------------------------------------------------------------------------------
# [3/10] START p004833.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p004833.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 2506 / 2506
# [Data Ready] total_len=2506
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=501 segs (~83.50 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,501) | train=(423,441) | test=(471,501)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=8.8653 | SD=5.5953
#   DBP: MAE=4.1135 | SD=3.9615
#   elapsed: 2.8s
#
# [Fold 2] fold=(501,1002) | train=(924,942) | test=(972,1002)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=3.6921 | SD=4.5328
#   DBP: MAE=1.0589 | SD=1.5888
#   elapsed: 2.7s
#
# [Fold 3] fold=(1002,1503) | train=(1425,1443) | test=(1473,1503)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.1979 | SD=2.7370
#   DBP: MAE=0.8898 | SD=1.0445
#   elapsed: 2.8s
#
# [Fold 4] fold=(1503,2004) | train=(1926,1944) | test=(1974,2004)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.7743 | SD=5.6710
#   DBP: MAE=1.4038 | SD=1.7032
#   elapsed: 3.5s
#
# [Fold 5] fold=(2004,2505) | train=(2427,2445) | test=(2475,2505)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=10.6944 | SD=9.6274
#   DBP: MAE=3.9949 | SD=6.9732
#   elapsed: 2.7s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.0448 | SD=5.6327
# Avg DBP: MAE=2.2922 | SD=3.0542
# Elapsed for this TrainDur: 15.5s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,501) | train=(411,441) | test=(471,501)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=6.5212 | SD=5.4100
#   DBP: MAE=2.5755 | SD=3.1270
#   elapsed: 3.9s
#
# [Fold 2] fold=(501,1002) | train=(912,942) | test=(972,1002)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.6639 | SD=3.8983
#   DBP: MAE=1.0480 | SD=1.3969
#   elapsed: 4.4s
#
# [Fold 3] fold=(1002,1503) | train=(1413,1443) | test=(1473,1503)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.4488 | SD=3.1289
#   DBP: MAE=0.8146 | SD=0.9736
#   elapsed: 4.4s
#
# [Fold 4] fold=(1503,2004) | train=(1914,1944) | test=(1974,2004)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.9564 | SD=4.7678
#   DBP: MAE=1.8328 | SD=1.9759
#   elapsed: 3.8s
#
# [Fold 5] fold=(2004,2505) | train=(2415,2445) | test=(2475,2505)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=6.6711 | SD=9.6793
#   DBP: MAE=5.0694 | SD=6.5836
#   elapsed: 4.1s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.4523 | SD=5.3768
# Avg DBP: MAE=2.2681 | SD=2.8114
# Elapsed for this TrainDur: 21.8s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,501) | train=(381,441) | test=(471,501)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.4696 | SD=6.0812
#   DBP: MAE=2.7951 | SD=2.2936
#   elapsed: 6.8s
#
# [Fold 2] fold=(501,1002) | train=(882,942) | test=(972,1002)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.3946 | SD=3.0639
#   DBP: MAE=0.9573 | SD=1.4380
#   elapsed: 6.6s
#
# [Fold 3] fold=(1002,1503) | train=(1383,1443) | test=(1473,1503)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.7403 | SD=2.6843
#   DBP: MAE=0.6772 | SD=0.7239
#   elapsed: 6.9s
#
# [Fold 4] fold=(1503,2004) | train=(1884,1944) | test=(1974,2004)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.8437 | SD=4.2880
#   DBP: MAE=0.9178 | SD=1.1841
#   elapsed: 6.8s
#
# [Fold 5] fold=(2004,2505) | train=(2385,2445) | test=(2475,2505)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.4826 | SD=8.8471
#   DBP: MAE=7.7717 | SD=7.4289
#   elapsed: 6.6s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.3862 | SD=4.9929
# Avg DBP: MAE=2.6238 | SD=2.6137
# Elapsed for this TrainDur: 34.9s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,501) | train=(351,441) | test=(471,501)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.2842 | SD=4.3765
#   DBP: MAE=4.3372 | SD=2.7589
#   elapsed: 10.1s
#
# [Fold 2] fold=(501,1002) | train=(852,942) | test=(972,1002)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.8922 | SD=3.5680
#   DBP: MAE=0.8920 | SD=1.3761
#   elapsed: 9.7s
#
# [Fold 3] fold=(1002,1503) | train=(1353,1443) | test=(1473,1503)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.0895 | SD=2.7185
#   DBP: MAE=0.6776 | SD=0.8364
#   elapsed: 9.8s
#
# [Fold 4] fold=(1503,2004) | train=(1854,1944) | test=(1974,2004)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.1259 | SD=4.3665
#   DBP: MAE=1.4046 | SD=1.1485
#   elapsed: 10.3s
#
# [Fold 5] fold=(2004,2505) | train=(2355,2445) | test=(2475,2505)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=20.9132 | SD=11.2905
#   DBP: MAE=4.8752 | SD=6.9943
#   elapsed: 10.1s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.4610 | SD=5.2640
# Avg DBP: MAE=2.4373 | SD=2.6229
# Elapsed for this TrainDur: 51.1s
#
# [Patient Done] p004833.mat | filtering=False | elapsed: 123.3s
#
# --------------------------------------------------------------------------------
# [4/10] START p009993.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p009993.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 2050 / 2050
# [Data Ready] total_len=2050
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=410 segs (~68.33 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,410) | train=(332,350) | test=(380,410)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=8.7928 | SD=1.8433
#   DBP: MAE=4.4202 | SD=1.6754
#   elapsed: 2.3s
#
# [Fold 2] fold=(410,820) | train=(742,760) | test=(790,820)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=15.2525 | SD=10.1599
#   DBP: MAE=24.8279 | SD=2.5579
#   elapsed: 2.5s
#
# [Fold 3] fold=(820,1230) | train=(1152,1170) | test=(1200,1230)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=10.3713 | SD=9.3470
#   DBP: MAE=3.0261 | SD=3.1501
#   elapsed: 2.5s
#
# [Fold 4] fold=(1230,1640) | train=(1562,1580) | test=(1610,1640)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=7.8997 | SD=10.6845
#   DBP: MAE=6.8587 | SD=3.2889
#   elapsed: 3.3s
#
# [Fold 5] fold=(1640,2050) | train=(1972,1990) | test=(2020,2050)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.1244 | SD=3.6297
#   DBP: MAE=1.4283 | SD=1.6055
#   elapsed: 2.5s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=9.2881 | SD=7.1329
# Avg DBP: MAE=8.1122 | SD=2.4556
# Elapsed for this TrainDur: 14.2s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,410) | train=(320,350) | test=(380,410)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=6.2995 | SD=1.9446
#   DBP: MAE=4.5178 | SD=1.6518
#   elapsed: 3.4s
#
# [Fold 2] fold=(410,820) | train=(730,760) | test=(790,820)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=12.2033 | SD=9.7100
#   DBP: MAE=29.1545 | SD=3.1671
#   elapsed: 3.7s
#
# [Fold 3] fold=(820,1230) | train=(1140,1170) | test=(1200,1230)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=10.1143 | SD=9.5467
#   DBP: MAE=3.4814 | SD=3.2031
#   elapsed: 4.5s
#
# [Fold 4] fold=(1230,1640) | train=(1550,1580) | test=(1610,1640)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=8.4570 | SD=10.6799
#   DBP: MAE=6.2873 | SD=3.3807
#   elapsed: 3.6s
#
# [Fold 5] fold=(1640,2050) | train=(1960,1990) | test=(2020,2050)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=4.3722 | SD=4.0592
#   DBP: MAE=1.5246 | SD=1.7450
#   elapsed: 3.8s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=8.2893 | SD=7.1881
# Avg DBP: MAE=8.9931 | SD=2.6295
# Elapsed for this TrainDur: 20.1s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,410) | train=(290,350) | test=(380,410)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.0229 | SD=1.9029
#   DBP: MAE=2.9724 | SD=1.6480
#   elapsed: 7.7s
#
# [Fold 2] fold=(410,820) | train=(700,760) | test=(790,820)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=11.2243 | SD=9.6394
#   DBP: MAE=23.6526 | SD=2.7238
#   elapsed: 6.6s
#
# [Fold 3] fold=(820,1230) | train=(1110,1170) | test=(1200,1230)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=11.6858 | SD=9.3715
#   DBP: MAE=3.5341 | SD=3.2752
#   elapsed: 7.5s
#
# [Fold 4] fold=(1230,1640) | train=(1520,1580) | test=(1610,1640)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.3970 | SD=10.0812
#   DBP: MAE=5.6270 | SD=3.1805
#   elapsed: 6.2s
#
# [Fold 5] fold=(1640,2050) | train=(1930,1990) | test=(2020,2050)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.2956 | SD=4.1664
#   DBP: MAE=1.7399 | SD=1.7032
#   elapsed: 7.7s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.9251 | SD=7.0323
# Avg DBP: MAE=7.5052 | SD=2.5061
# Elapsed for this TrainDur: 36.9s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,410) | train=(260,350) | test=(380,410)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.4786 | SD=1.8051
#   DBP: MAE=1.8793 | SD=1.6488
#   elapsed: 11.0s
#
# [Fold 2] fold=(410,820) | train=(670,760) | test=(790,820)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=13.1489 | SD=10.2590
#   DBP: MAE=23.6675 | SD=2.5622
#   elapsed: 10.1s
#
# [Fold 3] fold=(820,1230) | train=(1080,1170) | test=(1200,1230)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=11.8922 | SD=10.5634
#   DBP: MAE=4.1646 | SD=3.7283
#   elapsed: 10.6s
#
# [Fold 4] fold=(1230,1640) | train=(1490,1580) | test=(1610,1640)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.1812 | SD=8.7402
#   DBP: MAE=5.8537 | SD=2.8322
#   elapsed: 10.8s
#
# [Fold 5] fold=(1640,2050) | train=(1900,1990) | test=(2020,2050)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.6090 | SD=3.7267
#   DBP: MAE=1.4264 | SD=1.5367
#   elapsed: 10.5s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=8.2620 | SD=7.0189
# Avg DBP: MAE=7.3983 | SD=2.4616
# Elapsed for this TrainDur: 54.2s
#
# [Patient Done] p009993.mat | filtering=False | elapsed: 125.4s
#
# --------------------------------------------------------------------------------
# [5/10] START p030582.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p030582.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 2215 / 2215
# [Data Ready] total_len=2215
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=443 segs (~73.83 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,443) | train=(365,383) | test=(413,443)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.0778 | SD=2.4353
#   DBP: MAE=2.2146 | SD=1.1540
#   elapsed: 2.6s
#
# [Fold 2] fold=(443,886) | train=(808,826) | test=(856,886)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.9657 | SD=2.5851
#   DBP: MAE=4.6979 | SD=3.3287
#   elapsed: 2.3s
#
# [Fold 3] fold=(886,1329) | train=(1251,1269) | test=(1299,1329)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=12.8108 | SD=2.6136
#   DBP: MAE=3.7562 | SD=0.9648
#   elapsed: 2.7s
#
# [Fold 4] fold=(1329,1772) | train=(1694,1712) | test=(1742,1772)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.1659 | SD=1.4474
#   DBP: MAE=1.0145 | SD=0.6350
#   elapsed: 3.3s
#
# [Fold 5] fold=(1772,2215) | train=(2137,2155) | test=(2185,2215)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=5.0297 | SD=2.8363
#   DBP: MAE=2.7899 | SD=2.5268
#   elapsed: 2.7s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.4100 | SD=2.3835
# Avg DBP: MAE=2.8946 | SD=1.7219
# Elapsed for this TrainDur: 14.7s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,443) | train=(353,383) | test=(413,443)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=4.0181 | SD=3.5896
#   DBP: MAE=2.0880 | SD=1.2546
#   elapsed: 3.9s
#
# [Fold 2] fold=(443,886) | train=(796,826) | test=(856,886)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.0542 | SD=2.5682
#   DBP: MAE=4.0957 | SD=3.3601
#   elapsed: 3.9s
#
# [Fold 3] fold=(886,1329) | train=(1239,1269) | test=(1299,1329)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=12.6595 | SD=2.6047
#   DBP: MAE=4.4056 | SD=0.9381
#   elapsed: 3.8s
#
# [Fold 4] fold=(1329,1772) | train=(1682,1712) | test=(1742,1772)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=1.9164 | SD=1.3951
#   DBP: MAE=0.9881 | SD=0.6314
#   elapsed: 3.7s
#
# [Fold 5] fold=(1772,2215) | train=(2125,2155) | test=(2185,2215)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=4.5383 | SD=3.0488
#   DBP: MAE=2.4080 | SD=2.6032
#   elapsed: 3.6s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.0373 | SD=2.6413
# Avg DBP: MAE=2.7971 | SD=1.7575
# Elapsed for this TrainDur: 20.0s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,443) | train=(323,383) | test=(413,443)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.1641 | SD=3.3153
#   DBP: MAE=3.0931 | SD=1.3610
#   elapsed: 7.1s
#
# [Fold 2] fold=(443,886) | train=(766,826) | test=(856,886)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.0113 | SD=5.0260
#   DBP: MAE=4.0818 | SD=4.0734
#   elapsed: 6.1s
#
# [Fold 3] fold=(886,1329) | train=(1209,1269) | test=(1299,1329)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.0168 | SD=2.9832
#   DBP: MAE=4.6445 | SD=1.1682
#   elapsed: 7.0s
#
# [Fold 4] fold=(1329,1772) | train=(1652,1712) | test=(1742,1772)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.4496 | SD=1.2237
#   DBP: MAE=0.8102 | SD=0.5791
#   elapsed: 5.9s
#
# [Fold 5] fold=(1772,2215) | train=(2095,2155) | test=(2185,2215)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.4255 | SD=2.6269
#   DBP: MAE=1.8922 | SD=2.4618
#   elapsed: 7.2s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.2135 | SD=3.0350
# Avg DBP: MAE=2.9044 | SD=1.9287
# Elapsed for this TrainDur: 34.4s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,443) | train=(293,383) | test=(413,443)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.7809 | SD=2.5078
#   DBP: MAE=1.9247 | SD=1.0289
#   elapsed: 9.9s
#
# [Fold 2] fold=(443,886) | train=(736,826) | test=(856,886)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.7765 | SD=4.7446
#   DBP: MAE=5.2320 | SD=3.5257
#   elapsed: 9.0s
#
# [Fold 3] fold=(886,1329) | train=(1179,1269) | test=(1299,1329)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=12.4822 | SD=3.1718
#   DBP: MAE=6.9266 | SD=1.0734
#   elapsed: 9.9s
#
# [Fold 4] fold=(1329,1772) | train=(1622,1712) | test=(1742,1772)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.3126 | SD=1.8344
#   DBP: MAE=0.9250 | SD=0.7363
#   elapsed: 10.1s
#
# [Fold 5] fold=(1772,2215) | train=(2065,2155) | test=(2185,2215)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.7927 | SD=3.0454
#   DBP: MAE=1.7372 | SD=2.4934
#   elapsed: 9.4s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.0290 | SD=3.0608
# Avg DBP: MAE=3.3491 | SD=1.7715
# Elapsed for this TrainDur: 49.4s
#
# [Patient Done] p030582.mat | filtering=False | elapsed: 118.6s
#
# --------------------------------------------------------------------------------
# [6/10] START p030589.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p030589.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 2049 / 2049
# [Data Ready] total_len=2049
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=409 segs (~68.17 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,409) | train=(331,349) | test=(379,409)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=6.6189 | SD=5.5837
#   DBP: MAE=2.1910 | SD=2.0947
#   elapsed: 3.2s
#
# [Fold 2] fold=(409,818) | train=(740,758) | test=(788,818)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.8027 | SD=2.0955
#   DBP: MAE=0.8642 | SD=0.8545
#   elapsed: 2.7s
#
# [Fold 3] fold=(818,1227) | train=(1149,1167) | test=(1197,1227)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=7.1007 | SD=5.0539
#   DBP: MAE=2.5323 | SD=3.0150
#   elapsed: 2.4s
#
# [Fold 4] fold=(1227,1636) | train=(1558,1576) | test=(1606,1636)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.4343 | SD=2.1582
#   DBP: MAE=1.2652 | SD=1.0309
#   elapsed: 2.5s
#
# [Fold 5] fold=(1636,2045) | train=(1967,1985) | test=(2015,2045)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=3.3857 | SD=2.4470
#   DBP: MAE=1.0524 | SD=1.0562
#   elapsed: 3.4s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.8685 | SD=3.4676
# Avg DBP: MAE=1.5810 | SD=1.6103
# Elapsed for this TrainDur: 15.2s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,409) | train=(319,349) | test=(379,409)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=8.5561 | SD=4.7091
#   DBP: MAE=1.7182 | SD=1.6841
#   elapsed: 3.8s
#
# [Fold 2] fold=(409,818) | train=(728,758) | test=(788,818)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=4.2804 | SD=2.5721
#   DBP: MAE=0.9650 | SD=0.9705
#   elapsed: 3.8s
#
# [Fold 3] fold=(818,1227) | train=(1137,1167) | test=(1197,1227)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=6.7588 | SD=4.4990
#   DBP: MAE=2.4892 | SD=3.0006
#   elapsed: 4.3s
#
# [Fold 4] fold=(1227,1636) | train=(1546,1576) | test=(1606,1636)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.8299 | SD=1.5708
#   DBP: MAE=2.7667 | SD=0.6541
#   elapsed: 3.5s
#
# [Fold 5] fold=(1636,2045) | train=(1955,1985) | test=(2015,2045)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.3577 | SD=1.7798
#   DBP: MAE=4.0638 | SD=2.4085
#   elapsed: 3.5s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.1566 | SD=3.0262
# Avg DBP: MAE=2.4006 | SD=1.7436
# Elapsed for this TrainDur: 20.1s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,409) | train=(289,349) | test=(379,409)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.1893 | SD=4.3856
#   DBP: MAE=1.7149 | SD=1.6955
#   elapsed: 7.2s
#
# [Fold 2] fold=(409,818) | train=(698,758) | test=(788,818)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.3353 | SD=2.5044
#   DBP: MAE=1.0239 | SD=0.8819
#   elapsed: 6.0s
#
# [Fold 3] fold=(818,1227) | train=(1107,1167) | test=(1197,1227)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.4328 | SD=5.3039
#   DBP: MAE=2.4354 | SD=2.7581
#   elapsed: 7.3s
#
# [Fold 4] fold=(1227,1636) | train=(1516,1576) | test=(1606,1636)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.5527 | SD=1.9498
#   DBP: MAE=1.7036 | SD=0.7552
#   elapsed: 6.3s
#
# [Fold 5] fold=(1636,2045) | train=(1925,1985) | test=(2015,2045)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.9460 | SD=2.5344
#   DBP: MAE=2.2366 | SD=1.2322
#   elapsed: 7.2s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.2912 | SD=3.3356
# Avg DBP: MAE=1.8229 | SD=1.4646
# Elapsed for this TrainDur: 35.0s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,409) | train=(259,349) | test=(379,409)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.5578 | SD=3.7273
#   DBP: MAE=1.3782 | SD=1.4924
#   elapsed: 9.7s
#
# [Fold 2] fold=(409,818) | train=(668,758) | test=(788,818)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.9812 | SD=2.8803
#   DBP: MAE=0.8674 | SD=1.0908
#   elapsed: 10.6s
#
# [Fold 3] fold=(818,1227) | train=(1077,1167) | test=(1197,1227)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.2539 | SD=4.7093
#   DBP: MAE=2.1865 | SD=2.8404
#   elapsed: 10.8s
#
# [Fold 4] fold=(1227,1636) | train=(1486,1576) | test=(1606,1636)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=8.3954 | SD=2.0790
#   DBP: MAE=2.1121 | SD=0.7975
#   elapsed: 10.7s
#
# [Fold 5] fold=(1636,2045) | train=(1895,1985) | test=(2015,2045)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.7235 | SD=3.0552
#   DBP: MAE=1.1601 | SD=1.3789
#   elapsed: 9.6s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.1823 | SD=3.2902
# Avg DBP: MAE=1.5408 | SD=1.5200
# Elapsed for this TrainDur: 52.6s
#
# [Patient Done] p030589.mat | filtering=False | elapsed: 123.0s
#
# --------------------------------------------------------------------------------
# [7/10] START p030670.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p030670.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 1764 / 1764
# [Data Ready] total_len=1764
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=352 segs (~58.67 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,352) | train=(274,292) | test=(322,352)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=3.0008 | SD=1.7338
#   DBP: MAE=1.6203 | SD=0.7608
#   elapsed: 3.4s
#
# [Fold 2] fold=(352,704) | train=(626,644) | test=(674,704)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.7823 | SD=1.7143
#   DBP: MAE=0.7895 | SD=0.7310
#   elapsed: 2.6s
#
# [Fold 3] fold=(704,1056) | train=(978,996) | test=(1026,1056)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=6.2548 | SD=1.2359
#   DBP: MAE=1.7802 | SD=0.6466
#   elapsed: 2.7s
#
# [Fold 4] fold=(1056,1408) | train=(1330,1348) | test=(1378,1408)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.3630 | SD=3.8336
#   DBP: MAE=1.0602 | SD=0.9320
#   elapsed: 2.7s
#
# [Fold 5] fold=(1408,1760) | train=(1682,1700) | test=(1730,1760)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=2.3617 | SD=2.1744
#   DBP: MAE=0.6719 | SD=0.8337
#   elapsed: 3.5s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.7525 | SD=2.1384
# Avg DBP: MAE=1.1844 | SD=0.7808
# Elapsed for this TrainDur: 16.0s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,352) | train=(262,292) | test=(322,352)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.2582 | SD=1.6121
#   DBP: MAE=1.5050 | SD=0.7521
#   elapsed: 3.7s
#
# [Fold 2] fold=(352,704) | train=(614,644) | test=(674,704)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.2590 | SD=1.7271
#   DBP: MAE=1.0764 | SD=0.6886
#   elapsed: 3.6s
#
# [Fold 3] fold=(704,1056) | train=(966,996) | test=(1026,1056)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=6.5235 | SD=1.3769
#   DBP: MAE=0.9426 | SD=0.9179
#   elapsed: 4.3s
#
# [Fold 4] fold=(1056,1408) | train=(1318,1348) | test=(1378,1408)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=5.3265 | SD=4.2112
#   DBP: MAE=1.4977 | SD=1.2945
#   elapsed: 4.1s
#
# [Fold 5] fold=(1408,1760) | train=(1670,1700) | test=(1730,1760)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.4752 | SD=2.5257
#   DBP: MAE=0.9124 | SD=1.0290
#   elapsed: 3.6s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.7685 | SD=2.2906
# Avg DBP: MAE=1.1868 | SD=0.9364
# Elapsed for this TrainDur: 20.5s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,352) | train=(232,292) | test=(322,352)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.3317 | SD=1.7921
#   DBP: MAE=0.6237 | SD=0.7132
#   elapsed: 7.1s
#
# [Fold 2] fold=(352,704) | train=(584,644) | test=(674,704)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.8628 | SD=2.1740
#   DBP: MAE=0.8111 | SD=0.8112
#   elapsed: 6.3s
#
# [Fold 3] fold=(704,1056) | train=(936,996) | test=(1026,1056)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.4006 | SD=3.3628
#   DBP: MAE=2.2349 | SD=2.3402
#   elapsed: 7.5s
#
# [Fold 4] fold=(1056,1408) | train=(1288,1348) | test=(1378,1408)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.8222 | SD=4.1885
#   DBP: MAE=1.5497 | SD=1.1878
#   elapsed: 6.2s
#
# [Fold 5] fold=(1408,1760) | train=(1640,1700) | test=(1730,1760)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.5026 | SD=2.5586
#   DBP: MAE=0.6621 | SD=0.8024
#   elapsed: 7.3s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.5840 | SD=2.8152
# Avg DBP: MAE=1.1763 | SD=1.1709
# Elapsed for this TrainDur: 35.5s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,352) | train=(202,292) | test=(322,352)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=1.3155 | SD=1.4340
#   DBP: MAE=0.8548 | SD=0.7116
#   elapsed: 9.3s
#
# [Fold 2] fold=(352,704) | train=(554,644) | test=(674,704)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=1.4984 | SD=1.8498
#   DBP: MAE=0.6354 | SD=0.7747
#   elapsed: 10.0s
#
# [Fold 3] fold=(704,1056) | train=(906,996) | test=(1026,1056)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=6.8162 | SD=1.0111
#   DBP: MAE=1.2979 | SD=0.5852
#   elapsed: 10.0s
#
# [Fold 4] fold=(1056,1408) | train=(1258,1348) | test=(1378,1408)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.3696 | SD=3.9210
#   DBP: MAE=0.9081 | SD=0.8597
#   elapsed: 10.3s
#
# [Fold 5] fold=(1408,1760) | train=(1610,1700) | test=(1730,1760)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.7624 | SD=2.5563
#   DBP: MAE=0.7098 | SD=0.9404
#   elapsed: 9.2s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.5524 | SD=2.1544
# Avg DBP: MAE=0.8812 | SD=0.7743
# Elapsed for this TrainDur: 50.0s
#
# [Patient Done] p030670.mat | filtering=False | elapsed: 122.0s
#
# --------------------------------------------------------------------------------
# [8/10] START p040299.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p040299.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 2301 / 2301
# [Data Ready] total_len=2301
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=460 segs (~76.67 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(382,400) | test=(430,460)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=0.7269 | SD=0.8667
#   DBP: MAE=0.6406 | SD=0.7397
#   elapsed: 3.3s
#
# [Fold 2] fold=(460,920) | train=(842,860) | test=(890,920)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=7.4325 | SD=8.2325
#   DBP: MAE=3.7736 | SD=4.4477
#   elapsed: 2.7s
#
# [Fold 3] fold=(920,1380) | train=(1302,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.0903 | SD=0.9609
#   DBP: MAE=2.0245 | SD=0.6844
#   elapsed: 2.4s
#
# [Fold 4] fold=(1380,1840) | train=(1762,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=1.1972 | SD=1.2317
#   DBP: MAE=0.6746 | SD=0.8678
#   elapsed: 2.7s
#
# [Fold 5] fold=(1840,2300) | train=(2222,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=19.9306 | SD=4.0779
#   DBP: MAE=13.5865 | SD=2.9169
#   elapsed: 3.9s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.6755 | SD=3.0739
# Avg DBP: MAE=4.1400 | SD=1.9313
# Elapsed for this TrainDur: 16.0s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(370,400) | test=(430,460)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=1.2449 | SD=0.8303
#   DBP: MAE=0.6344 | SD=0.7503
#   elapsed: 4.1s
#
# [Fold 2] fold=(460,920) | train=(830,860) | test=(890,920)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=2.9874 | SD=3.8849
#   DBP: MAE=2.4696 | SD=2.8828
#   elapsed: 3.9s
#
# [Fold 3] fold=(920,1380) | train=(1290,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=4.3264 | SD=0.9838
#   DBP: MAE=1.8286 | SD=0.7072
#   elapsed: 4.3s
#
# [Fold 4] fold=(1380,1840) | train=(1750,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=0.9103 | SD=1.2443
#   DBP: MAE=0.7837 | SD=0.8744
#   elapsed: 4.2s
#
# [Fold 5] fold=(1840,2300) | train=(2210,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=19.1387 | SD=3.9310
#   DBP: MAE=13.1247 | SD=2.8990
#   elapsed: 3.8s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.7216 | SD=2.1749
# Avg DBP: MAE=3.7682 | SD=1.6227
# Elapsed for this TrainDur: 21.5s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(340,400) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.0552 | SD=1.4267
#   DBP: MAE=0.8742 | SD=0.9835
#   elapsed: 7.2s
#
# [Fold 2] fold=(460,920) | train=(800,860) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.2050 | SD=4.1054
#   DBP: MAE=1.5555 | SD=2.5760
#   elapsed: 6.6s
#
# [Fold 3] fold=(920,1380) | train=(1260,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.1086 | SD=1.1266
#   DBP: MAE=2.0890 | SD=0.7514
#   elapsed: 7.3s
#
# [Fold 4] fold=(1380,1840) | train=(1720,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.9635 | SD=1.1100
#   DBP: MAE=0.7347 | SD=0.7972
#   elapsed: 6.5s
#
# [Fold 5] fold=(1840,2300) | train=(2180,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=18.4973 | SD=4.0237
#   DBP: MAE=13.1359 | SD=2.9771
#   elapsed: 7.5s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.7659 | SD=2.3585
# Avg DBP: MAE=3.6779 | SD=1.6171
# Elapsed for this TrainDur: 36.2s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(310,400) | test=(430,460)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=0.9727 | SD=0.9452
#   DBP: MAE=0.6502 | SD=0.7048
#   elapsed: 9.9s
#
# [Fold 2] fold=(460,920) | train=(770,860) | test=(890,920)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=6.9597 | SD=7.9391
#   DBP: MAE=3.4800 | SD=4.2624
#   elapsed: 10.1s
#
# [Fold 3] fold=(920,1380) | train=(1230,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.1702 | SD=1.0053
#   DBP: MAE=3.2854 | SD=0.7395
#   elapsed: 10.3s
#
# [Fold 4] fold=(1380,1840) | train=(1690,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=0.8285 | SD=1.0076
#   DBP: MAE=0.9456 | SD=0.7854
#   elapsed: 10.4s
#
# [Fold 5] fold=(1840,2300) | train=(2150,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=18.9616 | SD=3.8478
#   DBP: MAE=13.3543 | SD=2.7707
#   elapsed: 9.7s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.5785 | SD=2.9490
# Avg DBP: MAE=4.3431 | SD=1.8526
# Elapsed for this TrainDur: 51.5s
#
# [Patient Done] p040299.mat | filtering=False | elapsed: 125.1s
#
# --------------------------------------------------------------------------------
# [9/10] START p041107.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p041107.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 1996 / 1996
# [Data Ready] total_len=1996
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=399 segs (~66.50 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(321,339) | test=(369,399)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.5911 | SD=2.5310
#   DBP: MAE=2.5747 | SD=0.8835
#   elapsed: 2.9s
#
# [Fold 2] fold=(399,798) | train=(720,738) | test=(768,798)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=6.2732 | SD=3.1397
#   DBP: MAE=1.0777 | SD=1.1638
#   elapsed: 2.4s
#
# [Fold 3] fold=(798,1197) | train=(1119,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=5.5494 | SD=7.1909
#   DBP: MAE=2.4883 | SD=2.4666
#   elapsed: 2.5s
#
# [Fold 4] fold=(1197,1596) | train=(1518,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=6.4272 | SD=6.8675
#   DBP: MAE=4.6040 | SD=2.6024
#   elapsed: 2.5s
#
# [Fold 5] fold=(1596,1995) | train=(1917,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=7.7494 | SD=5.9925
#   DBP: MAE=5.6456 | SD=5.1186
#   elapsed: 3.8s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.1180 | SD=5.1443
# Avg DBP: MAE=3.2781 | SD=2.4470
# Elapsed for this TrainDur: 15.1s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(309,339) | test=(369,399)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=6.0125 | SD=2.6776
#   DBP: MAE=2.6382 | SD=0.9351
#   elapsed: 3.6s
#
# [Fold 2] fold=(399,798) | train=(708,738) | test=(768,798)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.5505 | SD=4.1804
#   DBP: MAE=1.2229 | SD=1.4718
#   elapsed: 3.9s
#
# [Fold 3] fold=(798,1197) | train=(1107,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=4.4329 | SD=6.0723
#   DBP: MAE=1.9767 | SD=1.3579
#   elapsed: 4.4s
#
# [Fold 4] fold=(1197,1596) | train=(1506,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=5.4939 | SD=6.0236
#   DBP: MAE=3.6968 | SD=2.2293
#   elapsed: 4.1s
#
# [Fold 5] fold=(1596,1995) | train=(1905,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=8.8618 | SD=5.7212
#   DBP: MAE=5.9532 | SD=5.0689
#   elapsed: 3.9s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.6703 | SD=4.9350
# Avg DBP: MAE=3.0975 | SD=2.2126
# Elapsed for this TrainDur: 21.0s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(279,339) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.6436 | SD=2.8515
#   DBP: MAE=1.9569 | SD=0.8151
#   elapsed: 7.2s
#
# [Fold 2] fold=(399,798) | train=(678,738) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.7029 | SD=3.4027
#   DBP: MAE=0.9660 | SD=1.0890
#   elapsed: 6.1s
#
# [Fold 3] fold=(798,1197) | train=(1077,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.7019 | SD=9.8640
#   DBP: MAE=2.1779 | SD=1.9584
#   elapsed: 7.1s
#
# [Fold 4] fold=(1197,1596) | train=(1476,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.2194 | SD=5.8921
#   DBP: MAE=3.1488 | SD=3.8092
#   elapsed: 6.2s
#
# [Fold 5] fold=(1596,1995) | train=(1875,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.2163 | SD=5.9411
#   DBP: MAE=6.0818 | SD=4.7418
#   elapsed: 7.1s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.4968 | SD=5.5903
# Avg DBP: MAE=2.8663 | SD=2.4827
# Elapsed for this TrainDur: 34.8s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(249,339) | test=(369,399)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.0065 | SD=2.5508
#   DBP: MAE=2.6699 | SD=0.7832
#   elapsed: 8.9s
#
# [Fold 2] fold=(399,798) | train=(648,738) | test=(768,798)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.8571 | SD=2.8211
#   DBP: MAE=1.1352 | SD=0.9540
#   elapsed: 10.0s
#
# [Fold 3] fold=(798,1197) | train=(1047,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.1312 | SD=10.4333
#   DBP: MAE=2.8024 | SD=2.6087
#   elapsed: 9.9s
#
# [Fold 4] fold=(1197,1596) | train=(1446,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.4706 | SD=6.0923
#   DBP: MAE=2.9317 | SD=3.9577
#   elapsed: 9.8s
#
# [Fold 5] fold=(1596,1995) | train=(1845,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.8765 | SD=6.9958
#   DBP: MAE=3.2973 | SD=5.0397
#   elapsed: 9.0s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.6684 | SD=5.7786
# Avg DBP: MAE=2.5673 | SD=2.6687
# Elapsed for this TrainDur: 48.8s
#
# [Patient Done] p041107.mat | filtering=False | elapsed: 119.7s
#
# --------------------------------------------------------------------------------
# [10/10] START p043774.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p043774.mat | filtering=False
# ================================================================================
# ✅ filtering=False | kept: 1943 / 1943
# [Data Ready] total_len=1943
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=388 segs (~64.67 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(310,328) | test=(358,388)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=1.5536 | SD=1.6747
#   DBP: MAE=0.7299 | SD=0.9373
#   elapsed: 3.4s
#
# [Fold 2] fold=(388,776) | train=(698,716) | test=(746,776)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=10.1082 | SD=1.4737
# ...
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(382,400) | test=(430,460)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=0.7939 | SD=0.8694
#   DBP: MAE=0.5493 | SD=0.6567
#   elapsed: 2.6s
#
# [Fold 2] fold=(460,920) | train=(842,860) | test=(890,920)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=1.9171 | SD=2.3542
#   DBP: MAE=4.1434 | SD=3.6004
#   elapsed: 2.4s
#
# [Fold 3] fold=(920,1380) | train=(1302,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=3.8929 | SD=0.9750
#   DBP: MAE=2.2021 | SD=0.6432
#   elapsed: 2.0s
#
# [Fold 4] fold=(1380,1840) | train=(1762,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=0.8425 | SD=0.8996
#   DBP: MAE=0.5423 | SD=0.6740
#   elapsed: 2.0s
#
# [Fold 5] fold=(1840,2300) | train=(2222,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=20.2933 | SD=4.0049
#   DBP: MAE=13.6591 | SD=2.9138
#   elapsed: 1.9s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.5479 | SD=1.8206
# Avg DBP: MAE=4.2193 | SD=1.6976
# Elapsed for this TrainDur: 12.0s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(370,400) | test=(430,460)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=0.9852 | SD=0.8432
#   DBP: MAE=0.4973 | SD=0.6176
#   elapsed: 3.3s
#
# [Fold 2] fold=(460,920) | train=(830,860) | test=(890,920)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.6313 | SD=4.8274
#   DBP: MAE=1.6648 | SD=2.2637
#   elapsed: 3.4s
#
# [Fold 3] fold=(920,1380) | train=(1290,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=4.0318 | SD=1.0394
#   DBP: MAE=2.4680 | SD=0.7062
#   elapsed: 3.1s
#
# [Fold 4] fold=(1380,1840) | train=(1750,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=0.9245 | SD=1.0393
#   DBP: MAE=0.7729 | SD=0.9234
#   elapsed: 3.1s
#
# [Fold 5] fold=(1840,2300) | train=(2210,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=19.7595 | SD=4.0687
#   DBP: MAE=13.5457 | SD=2.9670
#   elapsed: 3.2s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.8665 | SD=2.3636
# Avg DBP: MAE=3.7897 | SD=1.4956
# Elapsed for this TrainDur: 17.3s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(340,400) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.4036 | SD=1.0924
#   DBP: MAE=0.6413 | SD=0.8050
#   elapsed: 5.1s
#
# [Fold 2] fold=(460,920) | train=(800,860) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.0528 | SD=3.7516
#   DBP: MAE=1.5489 | SD=2.1660
#   elapsed: 4.7s
#
# [Fold 3] fold=(920,1380) | train=(1260,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.6102 | SD=0.9316
#   DBP: MAE=2.1887 | SD=0.6659
#   elapsed: 5.6s
#
# [Fold 4] fold=(1380,1840) | train=(1720,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.6443 | SD=0.8411
#   DBP: MAE=0.6987 | SD=0.6317
#   elapsed: 4.8s
#
# [Fold 5] fold=(1840,2300) | train=(2180,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=18.0668 | SD=4.0033
#   DBP: MAE=13.1722 | SD=2.9004
#   elapsed: 4.7s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.5555 | SD=2.1240
# Avg DBP: MAE=3.6500 | SD=1.4338
# Elapsed for this TrainDur: 26.0s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(310,400) | test=(430,460)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=1.6441 | SD=0.8283
#   DBP: MAE=0.5890 | SD=0.6556
#   elapsed: 7.5s
#
# [Fold 2] fold=(460,920) | train=(770,860) | test=(890,920)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.9566 | SD=3.2849
#   DBP: MAE=1.6065 | SD=1.7727
#   elapsed: 7.2s
#
# [Fold 3] fold=(920,1380) | train=(1230,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.3057 | SD=0.9968
#   DBP: MAE=2.9168 | SD=0.6789
#   elapsed: 7.0s
#
# [Fold 4] fold=(1380,1840) | train=(1690,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=0.6576 | SD=0.8442
#   DBP: MAE=0.9081 | SD=0.6808
#   elapsed: 7.7s
#
# [Fold 5] fold=(1840,2300) | train=(2150,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=20.4010 | SD=3.9793
#   DBP: MAE=12.9250 | SD=2.8234
#   elapsed: 6.7s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.3930 | SD=1.9867
# Avg DBP: MAE=3.7891 | SD=1.3223
# Elapsed for this TrainDur: 37.3s
#
# [Patient Done] p040299.mat | filtering=True | elapsed: 92.7s
#
# --------------------------------------------------------------------------------
# [9/10] START p041107.mat | filtering=True
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p041107.mat | filtering=True
# ================================================================================
# ✅ filtering=True | kept: 1996 / 1996
# ❌ excluded: (bp_range: 0, noise/other: 0)
# [Data Ready] total_len=1996
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=399 segs (~66.50 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(321,339) | test=(369,399)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=6.1381 | SD=2.4729
#   DBP: MAE=2.5770 | SD=0.7636
#   elapsed: 2.0s
#
# [Fold 2] fold=(399,798) | train=(720,738) | test=(768,798)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=3.9796 | SD=3.5681
#   DBP: MAE=0.8526 | SD=1.1719
#   elapsed: 2.0s
#
# [Fold 3] fold=(798,1197) | train=(1119,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=8.3470 | SD=10.4195
#   DBP: MAE=2.9767 | SD=3.6449
#   elapsed: 2.6s
#
# [Fold 4] fold=(1197,1596) | train=(1518,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=5.5859 | SD=6.5046
#   DBP: MAE=3.0473 | SD=2.9299
#   elapsed: 2.7s
#
# [Fold 5] fold=(1596,1995) | train=(1917,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=7.5221 | SD=5.6704
#   DBP: MAE=5.3446 | SD=5.1989
#   elapsed: 2.0s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.3145 | SD=5.7271
# Avg DBP: MAE=2.9596 | SD=2.7418
# Elapsed for this TrainDur: 12.4s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(309,339) | test=(369,399)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.6321 | SD=2.2481
#   DBP: MAE=1.7978 | SD=0.6896
#   elapsed: 3.1s
#
# [Fold 2] fold=(399,798) | train=(708,738) | test=(768,798)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.2232 | SD=3.1244
#   DBP: MAE=0.9253 | SD=0.9928
#   elapsed: 3.1s
#
# [Fold 3] fold=(798,1197) | train=(1107,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=5.0707 | SD=6.1824
#   DBP: MAE=2.6582 | SD=1.7864
#   elapsed: 3.8s
#
# [Fold 4] fold=(1197,1596) | train=(1506,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=5.9672 | SD=7.1599
#   DBP: MAE=3.1625 | SD=3.7181
#   elapsed: 3.2s
#
# [Fold 5] fold=(1596,1995) | train=(1905,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=8.0204 | SD=7.3298
#   DBP: MAE=4.8543 | SD=5.2673
#   elapsed: 3.1s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.1827 | SD=5.2089
# Avg DBP: MAE=2.6796 | SD=2.4908
# Elapsed for this TrainDur: 17.4s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(279,339) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.1482 | SD=2.3553
#   DBP: MAE=2.5016 | SD=0.7106
#   elapsed: 5.3s
#
# [Fold 2] fold=(399,798) | train=(678,738) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.3595 | SD=2.9512
#   DBP: MAE=0.8659 | SD=1.0716
#   elapsed: 4.9s
#
# [Fold 3] fold=(798,1197) | train=(1077,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.1851 | SD=5.3270
#   DBP: MAE=3.3144 | SD=1.6581
#   elapsed: 4.6s
#
# [Fold 4] fold=(1197,1596) | train=(1476,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.5839 | SD=5.4851
#   DBP: MAE=4.1165 | SD=2.6051
#   elapsed: 5.5s
#
# [Fold 5] fold=(1596,1995) | train=(1875,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.1258 | SD=5.4368
#   DBP: MAE=6.4027 | SD=5.1646
#   elapsed: 4.8s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.2805 | SD=4.3111
# Avg DBP: MAE=3.4402 | SD=2.2420
# Elapsed for this TrainDur: 26.3s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(249,339) | test=(369,399)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.7723 | SD=2.7179
#   DBP: MAE=2.2547 | SD=0.7820
#   elapsed: 7.5s
#
# [Fold 2] fold=(399,798) | train=(648,738) | test=(768,798)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.3330 | SD=2.7905
#   DBP: MAE=0.8567 | SD=0.8706
#   elapsed: 6.7s
#
# [Fold 3] fold=(798,1197) | train=(1047,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.8596 | SD=4.7184
#   DBP: MAE=3.4223 | SD=1.8877
#   elapsed: 7.5s
#
# [Fold 4] fold=(1197,1596) | train=(1446,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.7989 | SD=5.3219
#   DBP: MAE=2.3599 | SD=3.1938
#   elapsed: 6.7s
#
# [Fold 5] fold=(1596,1995) | train=(1845,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=6.2766 | SD=7.2027
#   DBP: MAE=3.2055 | SD=5.3730
#   elapsed: 7.6s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.8081 | SD=4.5503
# Avg DBP: MAE=2.4198 | SD=2.4214
# Elapsed for this TrainDur: 37.2s
#
# [Patient Done] p041107.mat | filtering=True | elapsed: 93.3s
#
# --------------------------------------------------------------------------------
# [10/10] START p043774.mat | filtering=True
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p043774.mat | filtering=True
# ================================================================================
# ✅ filtering=True | kept: 1943 / 1943
# ❌ excluded: (bp_range: 0, noise/other: 0)
# [Data Ready] total_len=1943
#
# === PHASE 3 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=388 segs (~64.67 min)
# TimeGap=5min (30 segs) | TestDur=5min (30 segs)
# TrainDur sweep (min): [3, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TrainDur = 3 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(310,328) | test=(358,388)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=1.5369 | SD=1.4434
#   DBP: MAE=0.7287 | SD=0.8349
#   elapsed: 2.4s
#
# [Fold 2] fold=(388,776) | train=(698,716) | test=(746,776)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=10.2498 | SD=1.5251
#   DBP: MAE=6.5138 | SD=0.9789
#   elapsed: 2.0s
#
# [Fold 3] fold=(776,1164) | train=(1086,1104) | test=(1134,1164)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=3.0906 | SD=1.1790
#   DBP: MAE=0.8751 | SD=0.8249
#   elapsed: 2.0s
#
# [Fold 4] fold=(1164,1552) | train=(1474,1492) | test=(1522,1552)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=6.7476 | SD=0.9379
#   DBP: MAE=3.4422 | SD=0.5826
#   elapsed: 2.3s
#
# [Fold 5] fold=(1552,1940) | train=(1862,1880) | test=(1910,1940)
#   sizes Train/Val/Test: 15/3/30
#   SBP: MAE=4.9913 | SD=2.6054
#   DBP: MAE=1.0766 | SD=1.2185
#   elapsed: 2.9s
#
# --- TrainDur 3 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.3232 | SD=1.5381
# Avg DBP: MAE=2.5273 | SD=0.8880
# Elapsed for this TrainDur: 12.6s
#
# ===============================
#  TrainDur = 5 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(298,328) | test=(358,388)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=1.8690 | SD=1.4194
#   DBP: MAE=0.6547 | SD=0.8058
#   elapsed: 3.7s
#
# [Fold 2] fold=(388,776) | train=(686,716) | test=(746,776)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=9.9301 | SD=1.4983
#   DBP: MAE=5.9809 | SD=0.9581
#   elapsed: 3.1s
#
# [Fold 3] fold=(776,1164) | train=(1074,1104) | test=(1134,1164)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=3.4897 | SD=1.6035
#   DBP: MAE=1.6706 | SD=1.3265
#   elapsed: 3.2s
#
# [Fold 4] fold=(1164,1552) | train=(1462,1492) | test=(1522,1552)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=5.1446 | SD=1.2836
#   DBP: MAE=2.6369 | SD=0.5791
#   elapsed: 3.9s
#
# [Fold 5] fold=(1552,1940) | train=(1850,1880) | test=(1910,1940)
#   sizes Train/Val/Test: 24/6/30
#   SBP: MAE=12.6664 | SD=2.5942
#   DBP: MAE=3.3598 | SD=1.2272
#   elapsed: 3.2s
#
# --- TrainDur 5 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.6200 | SD=1.6798
# Avg DBP: MAE=2.8606 | SD=0.9793
# Elapsed for this TrainDur: 18.2s
#
# ===============================
#  TrainDur = 10 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(268,328) | test=(358,388)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.0629 | SD=1.4031
#   DBP: MAE=1.7170 | SD=0.8477
#   elapsed: 4.8s
#
# [Fold 2] fold=(388,776) | train=(656,716) | test=(746,776)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.4295 | SD=1.8306
#   DBP: MAE=5.9628 | SD=1.0777
#   elapsed: 5.7s
#
# [Fold 3] fold=(776,1164) | train=(1044,1104) | test=(1134,1164)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.7911 | SD=1.7229
#   DBP: MAE=0.8897 | SD=1.1232
#   elapsed: 4.6s
#
# [Fold 4] fold=(1164,1552) | train=(1432,1492) | test=(1522,1552)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.6677 | SD=1.2925
#   DBP: MAE=3.3489 | SD=0.6617
#   elapsed: 5.0s
#
# [Fold 5] fold=(1552,1940) | train=(1820,1880) | test=(1910,1940)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.8419 | SD=3.2717
#   DBP: MAE=5.2904 | SD=1.5771
#   elapsed: 6.3s
#
# --- TrainDur 10 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.9586 | SD=1.9042
# Avg DBP: MAE=3.4418 | SD=1.0574
# Elapsed for this TrainDur: 27.5s
#
# ===============================
#  TrainDur = 15 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(238,328) | test=(358,388)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=1.8516 | SD=1.8361
#   DBP: MAE=1.1092 | SD=1.1451
#   elapsed: 6.6s
#
# [Fold 2] fold=(388,776) | train=(626,716) | test=(746,776)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=9.6589 | SD=1.5127
#   DBP: MAE=5.4027 | SD=1.0091
#   elapsed: 7.7s
#
# [Fold 3] fold=(776,1164) | train=(1014,1104) | test=(1134,1164)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.2540 | SD=1.5850
#   DBP: MAE=1.6154 | SD=1.1233
#   elapsed: 7.4s
#
# [Fold 4] fold=(1164,1552) | train=(1402,1492) | test=(1522,1552)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.7232 | SD=1.0895
#   DBP: MAE=2.1146 | SD=0.7478
#   elapsed: 7.5s
#
# [Fold 5] fold=(1552,1940) | train=(1790,1880) | test=(1910,1940)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.7334 | SD=2.8058
#   DBP: MAE=3.4650 | SD=1.5098
#   elapsed: 8.2s
#
# --- TrainDur 15 min SUMMARY (TimeGap=5min) ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.2442 | SD=1.7658
# Avg DBP: MAE=2.7414 | SD=1.1070
# Elapsed for this TrainDur: 38.5s
#
# [Patient Done] p043774.mat | filtering=True | elapsed: 96.9s
#
# ################################################################################
# [FINAL SUMMARY] filtering=True | patient-level mean/std across usable patients
# Used patients: 10 / 10
# ################################################################################
#
# [TrainDur=3 min] PatientsUsed: 10/10
#   SBP(MAE): mean=5.6900 | std=1.4254
#   DBP(MAE): mean=2.9369 | std=0.9431
#   SBP(err SD): mean=3.3023 | std=1.5507
#   DBP(err SD): mean=1.7938 | std=0.7194
#
# [TrainDur=5 min] PatientsUsed: 10/10
#   SBP(MAE): mean=5.6377 | std=1.5274
#   DBP(MAE): mean=2.8683 | std=1.2268
#   SBP(err SD): mean=3.5026 | std=1.5641
#   DBP(err SD): mean=1.8801 | std=1.0371
#
# [TrainDur=10 min] PatientsUsed: 10/10
#   SBP(MAE): mean=5.3126 | std=1.0479
#   DBP(MAE): mean=2.9625 | std=1.1856
#   SBP(err SD): mean=3.1743 | std=1.3604
#   DBP(err SD): mean=1.7825 | std=0.9133
#
# [TrainDur=15 min] PatientsUsed: 10/10
#   SBP(MAE): mean=5.6104 | std=1.2985
#   DBP(MAE): mean=2.7218 | std=1.0141
#   SBP(err SD): mean=3.3442 | std=1.2283
#   DBP(err SD): mean=1.8053 | std=0.9026
#
# [ALL DONE] Total elapsed: 2446.5s
