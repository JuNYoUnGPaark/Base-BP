# %%
import os
import glob
import time
import random
import gc
import numpy as np
import h5py
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from scipy.interpolate import interp1d
from scipy.integrate import trapezoid

# ==========================================
# [0] Experiment settings
# ==========================================
MAT_FILE = "/content/drive/MyDrive/Colab Notebooks/PulseDB"  # directory
SEGMENT_LIMIT = None          # None = all segments
PAD_LEN = 200
SEC_PER_SEGMENT = 10.0

BATCH_SIZE = 32
EPOCHS = 100
LR = 1e-3
WEIGHT_DECAY = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SEED = 42
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Using Device: {DEVICE}")

# Phase-2 protocol config
N_FOLDS = 5
BLOCK_GAP_MIN = 0
TIME_GAP_SWEEP_MIN = [0, 5, 10, 15]

TRAIN_DUR_MIN = 10
TEST_DUR_MIN  = 5
VAL_FRAC_IN_TRAIN = 0.20

# NEW: sweep filtering
FILTER_SWEEP = [False, True]

# ==========================================
# [1] Re-sample + Prior feature
# ==========================================
def preprocess_ensemble_by_rpeaks(ppg_raw, rpeaks_raw, sbp, dbp, target_len=125, threshold_corr=0.7):
    # (1) BP range filter
    if not (50 <= sbp <= 250) or not (30 <= dbp <= 160):
        return None

    ppg = ppg_raw.squeeze()
    rpeaks = rpeaks_raw.squeeze()
    rpeaks = np.sort(rpeaks.astype(int))

    beats = []
    for i in range(len(rpeaks) - 1):
        start, end = rpeaks[i], rpeaks[i + 1]
        if start < 0 or end > len(ppg):
            continue
        beat_segment = ppg[start:end]
        if len(beat_segment) < 20:
            continue

        x_old = np.linspace(0, 1, len(beat_segment))
        x_new = np.linspace(0, 1, target_len)
        f_interp = interp1d(x_old, beat_segment, kind='linear', fill_value="extrapolate")
        beats.append(f_interp(x_new))

    if len(beats) < 5:
        return None

    beats = np.array(beats)
    ensemble_avg = np.mean(beats, axis=0)

    # normalize 0~1
    e_min, e_max = ensemble_avg.min(), ensemble_avg.max()
    if e_max - e_min > 1e-6:
        ensemble_avg = (ensemble_avg - e_min) / (e_max - e_min)

    # (3) consistency check
    correlations = [np.corrcoef(ensemble_avg, b)[0, 1] for b in beats]
    consistent_beats_count = sum(1 for c in correlations if c >= threshold_corr)
    if (consistent_beats_count / len(beats)) < 0.7:
        return None

    return ensemble_avg.astype(np.float32)

def cubic_resample(ppg, target_len=PAD_LEN):
    x_old = np.linspace(0, 1, len(ppg))
    x_new = np.linspace(0, 1, target_len)
    if len(ppg) < 4:
        return np.interp(x_new, x_old, ppg).astype(np.float32)
    try:
        f = interp1d(x_old, ppg, kind="cubic", bounds_error=False, fill_value="extrapolate")
        return f(x_new).astype(np.float32)
    except Exception:
        return np.interp(x_new, x_old, ppg).astype(np.float32)

def extract_multiscale_morph_features(ppg_01):
    scales = [100, 150, 200, 250]
    all_features = []
    for scale in scales:
        x = cubic_resample(ppg_01, scale)

        peak_idx = int(np.argmax(x))
        end_idx = scale - 1

        vp = float(x[peak_idx])
        vt = float(x[end_idx])
        dv = vp - vt
        vm = float(np.mean(x))
        std_val = float(np.std(x))

        tvp = peak_idx / scale

        diff = np.diff(x)
        kmax = float(np.max(diff)) if len(diff) > 0 else 0.0
        tkmax = (int(np.argmax(diff)) / scale) if len(diff) > 0 else 0.0

        amax = float(trapezoid(x[:peak_idx])) if peak_idx > 0 else 0.0

        centered = x - vm
        skew_approx = float(np.mean(centered**3) / (std_val**3)) if std_val > 0 else 0.0
        kurt_approx = float(np.mean(centered**4) / (std_val**4)) if std_val > 0 else 0.0

        all_features.extend([vp, vt, dv, vm, kmax, tkmax, amax, std_val, tvp, skew_approx, kurt_approx])

    return np.array(all_features, dtype=np.float32)

# ==========================================
# [2] Load data (PPG_F only) with filtering switch
# ==========================================
def load_data_from_mat(mat_path, segment_limit=None, filtering=False):
    """
    filtering=False: raw PPG_F 그대로 사용 (기존 코드 스타일)
    filtering=True : preprocess_ensemble_by_rpeaks 적용 (BP범위+앙상블+일관성)
    """
    segments, priors, targets = [], [], []
    skip_bp, skip_noise = 0, 0

    with h5py.File(mat_path, "r") as f:
        sw = f["Subj_Wins"]
        ppg_refs = sw["PPG_F"][0]
        sbp_refs = sw["SegSBP"][0]
        dbp_refs = sw["SegDBP"][0]

        ecg_refs = None
        if filtering:
            if "ECG_RPeaks" not in sw:
                raise KeyError("filtering=True인데 Subj_Wins/ECG_RPeaks가 없습니다.")
            ecg_refs = sw["ECG_RPeaks"][0]

        total = min(len(ppg_refs), segment_limit) if segment_limit else len(ppg_refs)

        for i in range(total):
            ppg_raw = f[ppg_refs[i]][()]
            sbp = float(f[sbp_refs[i]][()][0][0])
            dbp = float(f[dbp_refs[i]][()][0][0])

            if not filtering:
                # raw PPG_F (already 0~1 per segment)
                ppg = ppg_raw.squeeze().astype(np.float32)
            else:
                rpeaks_raw = f[ecg_refs[i]][()]
                processed_ppg = preprocess_ensemble_by_rpeaks(ppg_raw, rpeaks_raw, sbp, dbp)
                if processed_ppg is None:
                    if not (50 <= sbp <= 250) or not (30 <= dbp <= 160):
                        skip_bp += 1
                    else:
                        skip_noise += 1
                    continue
                ppg = processed_ppg

            segments.append(ppg)
            priors.append(extract_multiscale_morph_features(ppg))
            targets.append([sbp, dbp])

    if filtering:
        print(f"✅ (filtering=True) kept={len(segments)} / {total}")
        print(f"❌ 제외됨: (혈압범위: {skip_bp}, 신호편차: {skip_noise})")
    else:
        print(f"✅ (filtering=False) kept={len(segments)} / {total}")

    return segments, np.stack(priors).astype(np.float32), np.array(targets, dtype=np.float32)

# ==========================================
# [3] Dataset (RAW y; scaler is train-only)
# ==========================================
class PPGDatasetRawY(Dataset):
    def __init__(self, segments, priors, targets_mmHg):
        self.segments = segments
        self.priors = priors
        self.targets = targets_mmHg

    def __len__(self):
        return len(self.segments)

    def __getitem__(self, idx):
        x = cubic_resample(self.segments[idx], PAD_LEN)
        x = torch.tensor(x, dtype=torch.float32).unsqueeze(0)
        p = torch.tensor(self.priors[idx], dtype=torch.float32)
        y = torch.tensor(self.targets[idx], dtype=torch.float32)
        return x, p, y

# ==========================================
# [4] Model
# ==========================================
class MorphCNNRegressor(nn.Module):
    def __init__(self, prior_dim=44):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(1, 32, 7, padding=3),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(32, 64, 5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, 5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, 256, 3, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )

        self.fc_prior = nn.Sequential(
            nn.Linear(prior_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.ReLU()
        )

        self.fc_out = nn.Sequential(
            nn.Linear(256 + 256, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 2)
        )

    def forward(self, x, prior):
        feat = self.cnn(x).squeeze(-1)
        pfeat = self.fc_prior(prior)
        return self.fc_out(torch.cat([feat, pfeat], dim=1))

# ==========================================
# [5] Train-only label scaler
# ==========================================
class LabelScaler2D:
    def __init__(self, mode="minmax", eps=1e-6):
        assert mode in ["minmax", "zscore"]
        self.mode = mode
        self.eps = eps
        self.fitted = False

    def fit(self, y_train_mmHg: np.ndarray):
        y = np.asarray(y_train_mmHg, dtype=np.float32)
        if self.mode == "minmax":
            self.y_min = y.min(axis=0)
            self.y_max = y.max(axis=0)
        else:
            self.y_mean = y.mean(axis=0)
            self.y_std = y.std(axis=0)
        self.fitted = True
        return self

    def transform(self, y_mmHg: torch.Tensor) -> torch.Tensor:
        assert self.fitted
        if self.mode == "minmax":
            y_min = torch.tensor(self.y_min, device=y_mmHg.device, dtype=y_mmHg.dtype)
            y_max = torch.tensor(self.y_max, device=y_mmHg.device, dtype=y_mmHg.dtype)
            return (y_mmHg - y_min) / (y_max - y_min + self.eps)
        else:
            y_mean = torch.tensor(self.y_mean, device=y_mmHg.device, dtype=y_mmHg.dtype)
            y_std = torch.tensor(self.y_std, device=y_mmHg.device, dtype=y_mmHg.dtype)
            return (y_mmHg - y_mean) / (y_std + self.eps)

    def inverse(self, y_scaled: torch.Tensor) -> torch.Tensor:
        assert self.fitted
        if self.mode == "minmax":
            y_min = torch.tensor(self.y_min, device=y_scaled.device, dtype=y_scaled.dtype)
            y_max = torch.tensor(self.y_max, device=y_scaled.device, dtype=y_scaled.dtype)
            return y_scaled * (y_max - y_min + self.eps) + y_min
        else:
            y_mean = torch.tensor(self.y_mean, device=y_scaled.device, dtype=y_scaled.dtype)
            y_std = torch.tensor(self.y_std, device=y_scaled.device, dtype=y_scaled.dtype)
            return y_scaled * (y_std + self.eps) + y_mean

# ==========================================
# [6] Train / Eval
# ==========================================
def set_seed(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def train_one_model(train_loader, val_loader, scaler: LabelScaler2D):
    model = MorphCNNRegressor(prior_dim=44).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    criterion = nn.MSELoss()

    best_val = float("inf")
    best_state = None

    for epoch in range(1, EPOCHS + 1):
        model.train()
        for x, p, y_mmHg in train_loader:
            x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
            y = scaler.transform(y_mmHg)
            pred = model(x, p)
            loss = criterion(pred, y)
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        val_losses = []
        with torch.no_grad():
            for x, p, y_mmHg in val_loader:
                x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
                y = scaler.transform(y_mmHg)
                pred = model(x, p)
                val_losses.append(float(criterion(pred, y).item()))
        avg_val = float(np.mean(val_losses)) if len(val_losses) else float("inf")

        if avg_val < best_val:
            best_val = avg_val
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    if best_state is not None:
        model.load_state_dict(best_state)
    return model

def eval_mae_sd_mmHg(model, loader, scaler: LabelScaler2D):
    model.eval()
    errs = []
    with torch.no_grad():
        for x, p, y_mmHg in loader:
            x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
            pred_scaled = model(x, p)
            pred_mmHg = scaler.inverse(pred_scaled)
            err = (pred_mmHg - y_mmHg).detach().cpu().numpy()
            errs.append(err)

    if len(errs) == 0:
        return dict(mae_sbp=np.nan, sd_sbp=np.nan, mae_dbp=np.nan, sd_dbp=np.nan, n=0)

    E = np.concatenate(errs, axis=0)
    e_sbp, e_dbp = E[:, 0], E[:, 1]
    return dict(
        mae_sbp=float(np.mean(np.abs(e_sbp))),
        sd_sbp=float(np.std(e_sbp, ddof=0)),   # signed error std (NOT MAE std)
        mae_dbp=float(np.mean(np.abs(e_dbp))),
        sd_dbp=float(np.std(e_dbp, ddof=0)),
        n=int(E.shape[0])
    )

# ==========================================
# [7] Phase-2 Engine
# ==========================================
def segs_from_minutes(minutes: float) -> int:
    return int((minutes * 60.0) / SEC_PER_SEGMENT)

def min_required_total_len_for_any_gap():
    train_dur_segs = segs_from_minutes(TRAIN_DUR_MIN)
    test_dur_segs  = segs_from_minutes(TEST_DUR_MIN)
    max_gap_segs   = segs_from_minutes(max(TIME_GAP_SWEEP_MIN))
    need_per_fold = train_dur_segs + max_gap_segs + test_dur_segs
    return N_FOLDS * need_per_fold

def run_phase2_one_patient(mat_path: str, filtering: bool):
    set_seed(SEED)

    print("\n" + "=" * 80)
    print(f"[PATIENT] {os.path.basename(mat_path)} | filtering={filtering}")
    print("=" * 80)

    segments, priors, targets_mmHg = load_data_from_mat(mat_path, segment_limit=SEGMENT_LIMIT, filtering=filtering)
    ds = PPGDatasetRawY(segments, priors, targets_mmHg)
    total_len = len(ds)
    print(f"\n[Data Ready] total_len={total_len}")

    # skip if too short for worst gap protocol
    min_need = min_required_total_len_for_any_gap()
    if total_len < min_need:
        raise ValueError(f"Insufficient segments: total_len={total_len} < min_required={min_need}")

    b_gap_segs = segs_from_minutes(BLOCK_GAP_MIN)
    test_dur_segs  = segs_from_minutes(TEST_DUR_MIN)
    train_dur_segs = segs_from_minutes(TRAIN_DUR_MIN)

    available_len = total_len - (N_FOLDS - 1) * b_gap_segs
    if available_len <= 0:
        raise ValueError("Not enough segments for the requested N_FOLDS and BLOCK_GAP_MIN.")

    fold_len = available_len // N_FOLDS
    if fold_len <= 0:
        raise ValueError("Computed fold_len <= 0. Reduce N_FOLDS or BLOCK_GAP_MIN.")
    if fold_len <= test_dur_segs + 1:
        raise ValueError("Fold too short for test duration. Reduce TEST_DUR_MIN or N_FOLDS.")

    print("\n=== PHASE 2 CONFIG ===")
    print(f"N_FOLDS={N_FOLDS} | BlockGap={BLOCK_GAP_MIN}min ({b_gap_segs} segs)")
    print(f"FoldLen={fold_len} segs (~{fold_len*SEC_PER_SEGMENT/60.0:.2f} min)")
    print(f"TrainDur={TRAIN_DUR_MIN}min ({train_dur_segs} segs) | TestDur={TEST_DUR_MIN}min ({test_dur_segs} segs)")
    print(f"TimeGap sweep (min): {TIME_GAP_SWEEP_MIN}")
    print(f"ValFracInTrain={VAL_FRAC_IN_TRAIN:.2f}")

    patient_summary = {}
    t_global0 = time.time()

    for gap_min in TIME_GAP_SWEEP_MIN:
        gap_segs = segs_from_minutes(gap_min)
        print(f"\n===============================")
        print(f" TimeGap = {gap_min} min")
        print(f"===============================")

        fold_stats = []
        t_gap0 = time.time()

        for f_idx in range(N_FOLDS):
            fold_start = f_idx * (fold_len + b_gap_segs)
            fold_end   = fold_start + fold_len

            test_end = fold_end
            test_start = test_end - test_dur_segs

            train_end = test_start - gap_segs
            train_start = train_end - train_dur_segs

            if train_start < fold_start or train_end > test_start:
                print(f"[Fold {f_idx+1}] SKIP (insufficient room): "
                      f"fold=({fold_start},{fold_end}) train=({train_start},{train_end}) test=({test_start},{test_end})")
                fold_stats.append(None)
                continue

            train_indices = list(range(train_start, train_end))
            test_indices  = list(range(test_start, test_end))

            n_total = len(train_indices)
            n_val = max(1, int(n_total * VAL_FRAC_IN_TRAIN))
            if n_total - n_val < 1:
                print(f"[Fold {f_idx+1}] SKIP (train too small after val split).")
                fold_stats.append(None)
                continue

            real_train_idx = train_indices[:-n_val]
            val_idx        = train_indices[-n_val:]

            y_train = targets_mmHg[np.array(real_train_idx)]
            scaler = LabelScaler2D(mode="minmax", eps=1e-6).fit(y_train)

            train_loader = DataLoader(Subset(ds, real_train_idx), batch_size=BATCH_SIZE, shuffle=True)
            val_loader   = DataLoader(Subset(ds, val_idx), batch_size=BATCH_SIZE, shuffle=False)
            test_loader  = DataLoader(Subset(ds, test_indices), batch_size=BATCH_SIZE, shuffle=False)

            t0 = time.time()
            model = train_one_model(train_loader, val_loader, scaler)
            stat = eval_mae_sd_mmHg(model, test_loader, scaler)
            elapsed = time.time() - t0

            stat.update({
                "fold": f_idx + 1,
                "gap_min": gap_min,
                "train_n": len(real_train_idx),
                "val_n": len(val_idx),
                "test_n": len(test_indices),
                "elapsed_s": float(elapsed),
            })
            fold_stats.append(stat)

            print(f"\n[Fold {f_idx+1}] fold=({fold_start},{fold_end}) | "
                  f"train=({train_start},{train_end}) | test=({test_start},{test_end})")
            print(f"  sizes Train/Val/Test: {len(real_train_idx)}/{len(val_idx)}/{len(test_indices)}")
            print(f"  SBP: MAE={stat['mae_sbp']:.4f} | SD={stat['sd_sbp']:.4f}")
            print(f"  DBP: MAE={stat['mae_dbp']:.4f} | SD={stat['sd_dbp']:.4f}")
            print(f"  elapsed: {elapsed:.1f}s")

            del model
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
            gc.collect()

        valid = [fs for fs in fold_stats if fs is not None and np.isfinite(fs["mae_sbp"])]

        def mean_key(key):
            vals = [v[key] for v in valid]
            return float(np.mean(vals)) if len(vals) else float("nan")

        gap_summary = {
            "valid_folds": len(valid),
            "mae_sbp": mean_key("mae_sbp"),
            "sd_sbp": mean_key("sd_sbp"),
            "mae_dbp": mean_key("mae_dbp"),
            "sd_dbp": mean_key("sd_dbp"),
        }
        patient_summary[gap_min] = gap_summary

        print(f"\n--- TimeGap {gap_min} min SUMMARY ---")
        print(f"ValidFolds: {gap_summary['valid_folds']}/{N_FOLDS}")
        print(f"Avg SBP: MAE={gap_summary['mae_sbp']:.4f} | SD={gap_summary['sd_sbp']:.4f}")
        print(f"Avg DBP: MAE={gap_summary['mae_dbp']:.4f} | SD={gap_summary['sd_dbp']:.4f}")
        print(f"Elapsed for this gap: {time.time() - t_gap0:.1f}s")

    print(f"\n[Patient Done] {os.path.basename(mat_path)} | filtering={filtering} | elapsed: {time.time() - t_global0:.1f}s")
    return patient_summary

def run_phase2_all_patients(pulsedb_dir: str, filtering: bool):
    patient_files = sorted(glob.glob(os.path.join(pulsedb_dir, "p*.mat")))
    if len(patient_files) == 0:
        raise FileNotFoundError(f"No .mat files found under: {pulsedb_dir}")

    print("\n" + "#" * 80)
    print(f"[RUN ALL] filtering={filtering} | Found {len(patient_files)} patients in: {pulsedb_dir}")
    for f in patient_files:
        print("  -", os.path.basename(f))
    print("#" * 80)

    all_results = []
    skipped = []

    t0_all = time.time()

    for i, mat_path in enumerate(patient_files, 1):
        print("\n" + "-" * 80)
        print(f"[{i}/{len(patient_files)}] START {os.path.basename(mat_path)} | filtering={filtering}")
        print("-" * 80)

        try:
            summary = run_phase2_one_patient(mat_path, filtering=filtering)
            all_results.append({"patient": os.path.basename(mat_path), "summary": summary})
        except ValueError as e:
            reason = str(e)
            print(f"[SKIP PATIENT] {os.path.basename(mat_path)} | reason: {reason}")
            skipped.append((os.path.basename(mat_path), reason))
        except Exception as e:
            reason = f"Unexpected error: {type(e).__name__}: {e}"
            print(f"[SKIP PATIENT] {os.path.basename(mat_path)} | reason: {reason}")
            skipped.append((os.path.basename(mat_path), reason))

        if torch.cuda.is_available():
            torch.cuda.empty_cache()
        gc.collect()

    # FINAL: patient-level mean across usable patients
    print("\n" + "#" * 80)
    print(f"[FINAL SUMMARY] filtering={filtering} | patient-level mean across usable patients")
    print(f"Used patients: {len(all_results)} / {len(patient_files)}")
    print("#" * 80)

    for gap_min in TIME_GAP_SWEEP_MIN:
        sbp_maes, sbp_sds, dbp_maes, dbp_sds = [], [], [], []
        used_patients_for_gap = 0

        for item in all_results:
            g = item["summary"].get(gap_min, None)
            if g is None:
                continue
            if not np.isfinite(g["mae_sbp"]):
                continue
            used_patients_for_gap += 1
            sbp_maes.append(g["mae_sbp"])
            sbp_sds.append(g["sd_sbp"])
            dbp_maes.append(g["mae_dbp"])
            dbp_sds.append(g["sd_dbp"])

        def safe_mean(arr):
            return float(np.mean(arr)) if len(arr) else float("nan")

        def safe_std(arr):
            return float(np.std(arr, ddof=1)) if len(arr) >= 2 else float("nan")

        print(f"\n[TimeGap={gap_min} min] PatientsUsedForGap: {used_patients_for_gap}/{len(all_results)}")
        print(f"  SBP(MAE): mean={safe_mean(sbp_maes):.4f} | std={safe_std(sbp_maes):.4f}")
        print(f"  DBP(MAE): mean={safe_mean(dbp_maes):.4f} | std={safe_std(dbp_maes):.4f}")

        print(f"  SBP(err SD): mean={safe_mean(sbp_sds):.4f} | std={safe_std(sbp_sds):.4f}")
        print(f"  DBP(err SD): mean={safe_mean(dbp_sds):.4f} | std={safe_std(dbp_sds):.4f}")

    if len(skipped) > 0:
        print("\n" + "#" * 80)
        print(f"[SKIPPED PATIENTS] filtering={filtering}")
        print("#" * 80)
        for p, r in skipped:
            print(f"- {p}: {r}")

    print(f"\n[ALL DONE] filtering={filtering} | Total elapsed: {time.time() - t0_all:.1f}s")
    return all_results, skipped

def run_phase2_filter_sweep(pulsedb_dir: str):
    sweep_outputs = {}
    for filtering in FILTER_SWEEP:
        results, skipped = run_phase2_all_patients(pulsedb_dir, filtering=filtering)
        sweep_outputs[filtering] = {"results": results, "skipped": skipped}

    print("\n" + "=" * 80)
    print("[DONE] Filter sweep complete.")
    print("=" * 80)
    print("Compare: filtering=False vs filtering=True in the logs above.")
    return sweep_outputs

# ==========================================
# [MAIN]
# ==========================================
if __name__ == "__main__":
    run_phase2_filter_sweep(MAT_FILE)
# Out:
# Using Device: cuda
#
# ################################################################################
# [RUN ALL] filtering=False | Found 10 patients in: /content/drive/MyDrive/Colab Notebooks/PulseDB
#   - p001855.mat
#   - p004679.mat
#   - p004833.mat
#   - p009993.mat
#   - p030582.mat
#   - p030589.mat
#   - p030670.mat
#   - p040299.mat
#   - p041107.mat
#   - p043774.mat
# ################################################################################
#
# --------------------------------------------------------------------------------
# [1/10] START p001855.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p001855.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=2178 / 2178
#
# [Data Ready] total_len=2178
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=435 segs (~72.50 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,435) | train=(345,405) | test=(405,435)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.3594 | SD=1.5730
#   DBP: MAE=0.9676 | SD=1.0570
#   elapsed: 7.4s
#
# [Fold 2] fold=(435,870) | train=(780,840) | test=(840,870)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.6352 | SD=2.2857
#   DBP: MAE=1.8490 | SD=0.9910
#   elapsed: 4.9s
#
# [Fold 3] fold=(870,1305) | train=(1215,1275) | test=(1275,1305)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.4784 | SD=1.0216
#   DBP: MAE=0.7143 | SD=0.5946
#   elapsed: 4.7s
#
# [Fold 4] fold=(1305,1740) | train=(1650,1710) | test=(1710,1740)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.2969 | SD=2.7258
#   DBP: MAE=1.5648 | SD=1.6138
#   elapsed: 5.8s
#
# [Fold 5] fold=(1740,2175) | train=(2085,2145) | test=(2145,2175)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.2639 | SD=1.9266
#   DBP: MAE=1.4927 | SD=0.7470
#   elapsed: 4.9s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=2.4068 | SD=1.9065
# Avg DBP: MAE=1.3177 | SD=1.0007
# Elapsed for this gap: 28.4s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,435) | train=(315,375) | test=(405,435)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.3038 | SD=1.5007
#   DBP: MAE=0.9106 | SD=1.0075
#   elapsed: 6.0s
#
# [Fold 2] fold=(435,870) | train=(750,810) | test=(840,870)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.9297 | SD=1.3812
#   DBP: MAE=1.6422 | SD=0.6420
#   elapsed: 4.9s
#
# [Fold 3] fold=(870,1305) | train=(1185,1245) | test=(1275,1305)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.2512 | SD=1.2391
#   DBP: MAE=1.1409 | SD=0.7014
#   elapsed: 5.2s
#
# [Fold 4] fold=(1305,1740) | train=(1620,1680) | test=(1710,1740)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.5510 | SD=2.8096
#   DBP: MAE=2.8631 | SD=1.7229
#   elapsed: 5.5s
#
# [Fold 5] fold=(1740,2175) | train=(2055,2115) | test=(2145,2175)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.8999 | SD=1.3073
#   DBP: MAE=1.8611 | SD=0.5505
#   elapsed: 4.7s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=2.9871 | SD=1.6476
# Avg DBP: MAE=1.6836 | SD=0.9248
# Elapsed for this gap: 27.0s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,435) | train=(285,345) | test=(405,435)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.2857 | SD=2.5753
#   DBP: MAE=1.1724 | SD=1.4940
#   elapsed: 5.9s
#
# [Fold 2] fold=(435,870) | train=(720,780) | test=(840,870)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.8817 | SD=1.2822
#   DBP: MAE=1.4843 | SD=0.7045
#   elapsed: 4.8s
#
# [Fold 3] fold=(870,1305) | train=(1155,1215) | test=(1275,1305)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.2458 | SD=1.6946
#   DBP: MAE=1.0435 | SD=1.0144
#   elapsed: 5.1s
#
# [Fold 4] fold=(1305,1740) | train=(1590,1650) | test=(1710,1740)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.1516 | SD=2.9535
#   DBP: MAE=2.6799 | SD=1.7571
#   elapsed: 5.9s
#
# [Fold 5] fold=(1740,2175) | train=(2025,2085) | test=(2145,2175)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.8047 | SD=1.2383
#   DBP: MAE=2.6836 | SD=0.5923
#   elapsed: 5.2s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.6739 | SD=1.9488
# Avg DBP: MAE=1.8127 | SD=1.1125
# Elapsed for this gap: 28.0s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,435) | train=(255,315) | test=(405,435)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.4318 | SD=3.0242
#   DBP: MAE=5.6772 | SD=1.2767
#   elapsed: 6.0s
#
# [Fold 2] fold=(435,870) | train=(690,750) | test=(840,870)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.3779 | SD=2.9936
#   DBP: MAE=4.2973 | SD=1.2615
#   elapsed: 4.8s
#
# [Fold 3] fold=(870,1305) | train=(1125,1185) | test=(1275,1305)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.5783 | SD=1.2078
#   DBP: MAE=1.0236 | SD=0.5237
#   elapsed: 5.9s
#
# [Fold 4] fold=(1305,1740) | train=(1560,1620) | test=(1710,1740)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.3368 | SD=2.7702
#   DBP: MAE=2.3971 | SD=1.5913
#   elapsed: 4.9s
#
# [Fold 5] fold=(1740,2175) | train=(1995,2055) | test=(2145,2175)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.3056 | SD=1.3153
#   DBP: MAE=1.7494 | SD=0.5882
#   elapsed: 4.8s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.4061 | SD=2.2622
# Avg DBP: MAE=3.0289 | SD=1.0483
# Elapsed for this gap: 27.3s
#
# [Patient Done] p001855.mat | filtering=False | elapsed: 110.7s
#
# --------------------------------------------------------------------------------
# [2/10] START p004679.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p004679.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=1862 / 1862
#
# [Data Ready] total_len=1862
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=372 segs (~62.00 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,372) | train=(282,342) | test=(342,372)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.3239 | SD=2.7926
#   DBP: MAE=1.4116 | SD=1.4094
#   elapsed: 4.9s
#
# [Fold 2] fold=(372,744) | train=(654,714) | test=(714,744)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.8636 | SD=5.8804
#   DBP: MAE=2.6013 | SD=2.6561
#   elapsed: 6.0s
#
# [Fold 3] fold=(744,1116) | train=(1026,1086) | test=(1086,1116)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.2002 | SD=3.0154
#   DBP: MAE=0.8752 | SD=0.9534
#   elapsed: 4.9s
#
# [Fold 4] fold=(1116,1488) | train=(1398,1458) | test=(1458,1488)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.8161 | SD=2.8968
#   DBP: MAE=1.2954 | SD=1.6893
#   elapsed: 5.8s
#
# [Fold 5] fold=(1488,1860) | train=(1770,1830) | test=(1830,1860)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.9402 | SD=5.8351
#   DBP: MAE=3.3474 | SD=2.0176
#   elapsed: 5.0s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.6288 | SD=4.0841
# Avg DBP: MAE=1.9062 | SD=1.7451
# Elapsed for this gap: 27.3s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,372) | train=(252,312) | test=(342,372)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.3283 | SD=2.9364
#   DBP: MAE=1.8455 | SD=1.5376
#   elapsed: 4.9s
#
# [Fold 2] fold=(372,744) | train=(624,684) | test=(714,744)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.2979 | SD=4.2276
#   DBP: MAE=2.5937 | SD=1.9066
#   elapsed: 6.1s
#
# [Fold 3] fold=(744,1116) | train=(996,1056) | test=(1086,1116)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.6166 | SD=3.8027
#   DBP: MAE=2.1120 | SD=2.1773
#   elapsed: 4.8s
#
# [Fold 4] fold=(1116,1488) | train=(1368,1428) | test=(1458,1488)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.7800 | SD=2.8280
#   DBP: MAE=1.3440 | SD=1.4164
#   elapsed: 6.3s
#
# [Fold 5] fold=(1488,1860) | train=(1740,1800) | test=(1830,1860)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.8123 | SD=9.5416
#   DBP: MAE=5.7056 | SD=5.0194
#   elapsed: 4.9s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.9670 | SD=4.6673
# Avg DBP: MAE=2.7202 | SD=2.4115
# Elapsed for this gap: 27.7s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,372) | train=(222,282) | test=(342,372)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.1192 | SD=3.5576
#   DBP: MAE=2.6491 | SD=1.9227
#   elapsed: 5.3s
#
# [Fold 2] fold=(372,744) | train=(594,654) | test=(714,744)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.8796 | SD=3.5529
#   DBP: MAE=6.1602 | SD=1.5971
#   elapsed: 5.6s
#
# [Fold 3] fold=(744,1116) | train=(966,1026) | test=(1086,1116)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.1179 | SD=3.6565
#   DBP: MAE=1.5705 | SD=1.7972
#   elapsed: 4.8s
#
# [Fold 4] fold=(1116,1488) | train=(1338,1398) | test=(1458,1488)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.2593 | SD=3.9189
#   DBP: MAE=2.3381 | SD=2.3382
#   elapsed: 6.1s
#
# [Fold 5] fold=(1488,1860) | train=(1710,1770) | test=(1830,1860)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.7730 | SD=6.5958
#   DBP: MAE=10.2325 | SD=1.6709
#   elapsed: 4.8s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.6298 | SD=4.2563
# Avg DBP: MAE=4.5901 | SD=1.8652
# Elapsed for this gap: 27.4s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,372) | train=(192,252) | test=(342,372)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.5465 | SD=3.2306
#   DBP: MAE=1.8984 | SD=1.4958
#   elapsed: 5.3s
#
# [Fold 2] fold=(372,744) | train=(564,624) | test=(714,744)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.3091 | SD=4.9249
#   DBP: MAE=5.5514 | SD=2.0910
#   elapsed: 5.2s
#
# [Fold 3] fold=(744,1116) | train=(936,996) | test=(1086,1116)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.0486 | SD=7.2955
#   DBP: MAE=23.7600 | SD=5.1800
#   elapsed: 4.7s
#
# [Fold 4] fold=(1116,1488) | train=(1308,1368) | test=(1458,1488)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.9075 | SD=7.2069
#   DBP: MAE=2.7276 | SD=2.5673
#   elapsed: 5.8s
#
# [Fold 5] fold=(1488,1860) | train=(1680,1740) | test=(1830,1860)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.2670 | SD=5.9803
#   DBP: MAE=13.5102 | SD=1.7431
#   elapsed: 4.8s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.8157 | SD=5.7276
# Avg DBP: MAE=9.4895 | SD=2.6154
# Elapsed for this gap: 26.5s
#
# [Patient Done] p004679.mat | filtering=False | elapsed: 108.9s
#
# --------------------------------------------------------------------------------
# [3/10] START p004833.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p004833.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=2506 / 2506
#
# [Data Ready] total_len=2506
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=501 segs (~83.50 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,501) | train=(411,471) | test=(471,501)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.6541 | SD=6.6101
#   DBP: MAE=2.7510 | SD=3.5764
#   elapsed: 4.8s
#
# [Fold 2] fold=(501,1002) | train=(912,972) | test=(972,1002)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.8503 | SD=4.0980
#   DBP: MAE=1.5392 | SD=1.5452
#   elapsed: 5.8s
#
# [Fold 3] fold=(1002,1503) | train=(1413,1473) | test=(1473,1503)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.5573 | SD=2.2940
#   DBP: MAE=0.7067 | SD=0.8119
#   elapsed: 4.9s
#
# [Fold 4] fold=(1503,2004) | train=(1914,1974) | test=(1974,2004)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.0747 | SD=3.7698
#   DBP: MAE=0.8365 | SD=0.9954
#   elapsed: 5.0s
#
# [Fold 5] fold=(2004,2505) | train=(2415,2475) | test=(2475,2505)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.6656 | SD=7.8583
#   DBP: MAE=4.4306 | SD=6.2406
#   elapsed: 5.9s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.9604 | SD=4.9260
# Avg DBP: MAE=2.0528 | SD=2.6339
# Elapsed for this gap: 27.1s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,501) | train=(381,441) | test=(471,501)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.9049 | SD=6.6943
#   DBP: MAE=2.5730 | SD=2.1808
#   elapsed: 4.9s
#
# [Fold 2] fold=(501,1002) | train=(882,942) | test=(972,1002)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.3434 | SD=3.1443
#   DBP: MAE=0.8625 | SD=1.4067
#   elapsed: 5.9s
#
# [Fold 3] fold=(1002,1503) | train=(1383,1443) | test=(1473,1503)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.0995 | SD=2.4408
#   DBP: MAE=0.8256 | SD=0.7823
#   elapsed: 4.9s
#
# [Fold 4] fold=(1503,2004) | train=(1884,1944) | test=(1974,2004)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.2010 | SD=3.6273
#   DBP: MAE=0.8161 | SD=0.9823
#   elapsed: 5.1s
#
# [Fold 5] fold=(2004,2505) | train=(2385,2445) | test=(2475,2505)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.7034 | SD=9.5555
#   DBP: MAE=7.9650 | SD=7.6029
#   elapsed: 5.6s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.4505 | SD=5.0924
# Avg DBP: MAE=2.6085 | SD=2.5910
# Elapsed for this gap: 27.1s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,501) | train=(351,411) | test=(471,501)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=11.3995 | SD=4.7604
#   DBP: MAE=4.6137 | SD=2.4658
#   elapsed: 4.7s
#
# [Fold 2] fold=(501,1002) | train=(852,912) | test=(972,1002)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.4755 | SD=4.0774
#   DBP: MAE=0.9541 | SD=1.3447
#   elapsed: 5.8s
#
# [Fold 3] fold=(1002,1503) | train=(1353,1413) | test=(1473,1503)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.1315 | SD=2.6951
#   DBP: MAE=1.3157 | SD=0.9197
#   elapsed: 4.8s
#
# [Fold 4] fold=(1503,2004) | train=(1854,1914) | test=(1974,2004)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.5487 | SD=4.9092
#   DBP: MAE=1.2272 | SD=1.5082
#   elapsed: 5.0s
#
# [Fold 5] fold=(2004,2505) | train=(2355,2415) | test=(2475,2505)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=20.5322 | SD=8.8272
#   DBP: MAE=6.8905 | SD=6.7161
#   elapsed: 5.5s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=9.0175 | SD=5.0539
# Avg DBP: MAE=3.0002 | SD=2.5909
# Elapsed for this gap: 26.6s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,501) | train=(321,381) | test=(471,501)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=14.9351 | SD=4.3097
#   DBP: MAE=4.0039 | SD=2.6823
#   elapsed: 4.6s
#
# [Fold 2] fold=(501,1002) | train=(822,882) | test=(972,1002)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.3379 | SD=2.8937
#   DBP: MAE=1.4845 | SD=1.3081
#   elapsed: 5.7s
#
# [Fold 3] fold=(1002,1503) | train=(1323,1383) | test=(1473,1503)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.7916 | SD=2.5295
#   DBP: MAE=1.0101 | SD=0.8270
#   elapsed: 4.7s
#
# [Fold 4] fold=(1503,2004) | train=(1824,1884) | test=(1974,2004)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.2190 | SD=4.2844
#   DBP: MAE=2.3167 | SD=1.3172
#   elapsed: 4.9s
#
# [Fold 5] fold=(2004,2505) | train=(2325,2385) | test=(2475,2505)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=19.5191 | SD=8.6816
#   DBP: MAE=5.0573 | SD=6.3158
#   elapsed: 5.5s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=9.9605 | SD=4.5398
# Avg DBP: MAE=2.7745 | SD=2.4901
# Elapsed for this gap: 26.3s
#
# [Patient Done] p004833.mat | filtering=False | elapsed: 107.0s
#
# --------------------------------------------------------------------------------
# [4/10] START p009993.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p009993.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=2050 / 2050
#
# [Data Ready] total_len=2050
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=410 segs (~68.33 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,410) | train=(320,380) | test=(380,410)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.5057 | SD=2.7728
#   DBP: MAE=2.7217 | SD=1.8032
#   elapsed: 5.7s
#
# [Fold 2] fold=(410,820) | train=(730,790) | test=(790,820)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.8793 | SD=9.8587
#   DBP: MAE=3.0635 | SD=3.5169
#   elapsed: 4.7s
#
# [Fold 3] fold=(820,1230) | train=(1140,1200) | test=(1200,1230)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.6704 | SD=9.4348
#   DBP: MAE=3.3396 | SD=3.1582
#   elapsed: 5.8s
#
# [Fold 4] fold=(1230,1640) | train=(1550,1610) | test=(1610,1640)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.3919 | SD=10.3536
#   DBP: MAE=5.5984 | SD=3.4584
#   elapsed: 4.7s
#
# [Fold 5] fold=(1640,2050) | train=(1960,2020) | test=(2020,2050)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.9553 | SD=4.3980
#   DBP: MAE=1.4336 | SD=1.6356
#   elapsed: 4.7s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.6805 | SD=7.3636
# Avg DBP: MAE=3.2313 | SD=2.7145
# Elapsed for this gap: 26.5s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,410) | train=(290,350) | test=(380,410)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.9464 | SD=1.8289
#   DBP: MAE=3.0175 | SD=1.6553
#   elapsed: 5.6s
#
# [Fold 2] fold=(410,820) | train=(700,760) | test=(790,820)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.7343 | SD=9.4390
#   DBP: MAE=23.3147 | SD=2.7074
#   elapsed: 4.7s
#
# [Fold 3] fold=(820,1230) | train=(1110,1170) | test=(1200,1230)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.8791 | SD=9.0433
#   DBP: MAE=3.1693 | SD=3.2743
#   elapsed: 5.8s
#
# [Fold 4] fold=(1230,1640) | train=(1520,1580) | test=(1610,1640)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.9807 | SD=10.5023
#   DBP: MAE=5.3886 | SD=3.3064
#   elapsed: 4.7s
#
# [Fold 5] fold=(1640,2050) | train=(1930,1990) | test=(2020,2050)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.5625 | SD=3.9744
#   DBP: MAE=1.5417 | SD=1.7260
#   elapsed: 4.6s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.8206 | SD=6.9576
# Avg DBP: MAE=7.2864 | SD=2.5339
# Elapsed for this gap: 26.3s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,410) | train=(260,320) | test=(380,410)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.0035 | SD=1.8815
#   DBP: MAE=1.5301 | SD=1.7241
#   elapsed: 5.7s
#
# [Fold 2] fold=(410,820) | train=(670,730) | test=(790,820)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.0733 | SD=9.2587
#   DBP: MAE=22.9073 | SD=2.9864
#   elapsed: 4.7s
#
# [Fold 3] fold=(820,1230) | train=(1080,1140) | test=(1200,1230)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.6412 | SD=10.3211
#   DBP: MAE=3.1524 | SD=3.5326
#   elapsed: 5.9s
#
# [Fold 4] fold=(1230,1640) | train=(1490,1550) | test=(1610,1640)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.1363 | SD=8.9153
#   DBP: MAE=6.9972 | SD=2.8229
#   elapsed: 4.9s
#
# [Fold 5] fold=(1640,2050) | train=(1900,1960) | test=(2020,2050)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.8849 | SD=3.8350
#   DBP: MAE=3.3527 | SD=1.8634
#   elapsed: 5.0s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.7478 | SD=6.8423
# Avg DBP: MAE=7.5879 | SD=2.5859
# Elapsed for this gap: 27.0s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,410) | train=(230,290) | test=(380,410)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.1380 | SD=2.6512
#   DBP: MAE=2.3638 | SD=2.0131
#   elapsed: 5.8s
#
# [Fold 2] fold=(410,820) | train=(640,700) | test=(790,820)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.5613 | SD=7.6417
#   DBP: MAE=18.4609 | SD=7.0275
#   elapsed: 4.9s
#
# [Fold 3] fold=(820,1230) | train=(1050,1110) | test=(1200,1230)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=18.8656 | SD=10.2075
#   DBP: MAE=2.6488 | SD=3.2954
#   elapsed: 5.9s
#
# [Fold 4] fold=(1230,1640) | train=(1460,1520) | test=(1610,1640)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.9739 | SD=11.9482
#   DBP: MAE=7.0087 | SD=3.4789
#   elapsed: 4.9s
#
# [Fold 5] fold=(1640,2050) | train=(1870,1930) | test=(2020,2050)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.3564 | SD=5.1471
#   DBP: MAE=4.8826 | SD=2.5970
#   elapsed: 5.4s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=9.9790 | SD=7.5191
# Avg DBP: MAE=7.0730 | SD=3.6824
# Elapsed for this gap: 27.6s
#
# [Patient Done] p009993.mat | filtering=False | elapsed: 107.5s
#
# --------------------------------------------------------------------------------
# [5/10] START p030582.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p030582.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=2215 / 2215
#
# [Data Ready] total_len=2215
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=443 segs (~73.83 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,443) | train=(353,413) | test=(413,443)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.3833 | SD=2.7972
#   DBP: MAE=1.0752 | SD=1.1137
#   elapsed: 5.5s
#
# [Fold 2] fold=(443,886) | train=(796,856) | test=(856,886)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.0305 | SD=2.5688
#   DBP: MAE=4.0536 | SD=3.2573
#   elapsed: 5.2s
#
# [Fold 3] fold=(886,1329) | train=(1239,1299) | test=(1299,1329)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=11.7850 | SD=2.6443
#   DBP: MAE=4.6501 | SD=0.8089
#   elapsed: 4.8s
#
# [Fold 4] fold=(1329,1772) | train=(1682,1742) | test=(1742,1772)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.9316 | SD=1.0790
#   DBP: MAE=0.5481 | SD=0.5461
#   elapsed: 5.8s
#
# [Fold 5] fold=(1772,2215) | train=(2125,2185) | test=(2185,2215)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.5633 | SD=3.0903
#   DBP: MAE=2.2112 | SD=2.2596
#   elapsed: 4.8s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.9388 | SD=2.4359
# Avg DBP: MAE=2.5077 | SD=1.5971
# Elapsed for this gap: 26.8s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,443) | train=(323,383) | test=(413,443)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.8413 | SD=4.0770
#   DBP: MAE=2.9842 | SD=1.5332
#   elapsed: 5.7s
#
# [Fold 2] fold=(443,886) | train=(766,826) | test=(856,886)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.2217 | SD=5.2198
#   DBP: MAE=3.9764 | SD=4.4289
#   elapsed: 5.1s
#
# [Fold 3] fold=(886,1329) | train=(1209,1269) | test=(1299,1329)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=13.0414 | SD=2.8721
#   DBP: MAE=4.9546 | SD=1.1870
#   elapsed: 4.8s
#
# [Fold 4] fold=(1329,1772) | train=(1652,1712) | test=(1742,1772)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.6243 | SD=1.3401
#   DBP: MAE=0.8676 | SD=0.6390
#   elapsed: 5.8s
#
# [Fold 5] fold=(1772,2215) | train=(2095,2155) | test=(2185,2215)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.6852 | SD=2.7057
#   DBP: MAE=2.2034 | SD=2.5257
#   elapsed: 4.8s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.6828 | SD=3.2429
# Avg DBP: MAE=2.9972 | SD=2.0627
# Elapsed for this gap: 27.0s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,443) | train=(293,353) | test=(413,443)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.3285 | SD=2.3667
#   DBP: MAE=2.0883 | SD=1.0198
#   elapsed: 6.1s
#
# [Fold 2] fold=(443,886) | train=(736,796) | test=(856,886)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.8816 | SD=5.6151
#   DBP: MAE=3.9306 | SD=4.0376
#   elapsed: 4.9s
#
# [Fold 3] fold=(886,1329) | train=(1179,1239) | test=(1299,1329)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.6474 | SD=3.5839
#   DBP: MAE=3.3705 | SD=1.4220
#   elapsed: 4.9s
#
# [Fold 4] fold=(1329,1772) | train=(1622,1682) | test=(1742,1772)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.1117 | SD=1.3485
#   DBP: MAE=0.5903 | SD=0.6412
#   elapsed: 5.8s
#
# [Fold 5] fold=(1772,2215) | train=(2065,2125) | test=(2185,2215)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.5609 | SD=3.4622
#   DBP: MAE=2.2769 | SD=2.5884
#   elapsed: 4.7s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.3060 | SD=3.2753
# Avg DBP: MAE=2.4513 | SD=1.9418
# Elapsed for this gap: 27.2s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,443) | train=(263,323) | test=(413,443)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.8139 | SD=3.1228
#   DBP: MAE=1.2087 | SD=1.3971
#   elapsed: 5.8s
#
# [Fold 2] fold=(443,886) | train=(706,766) | test=(856,886)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=16.6119 | SD=2.3182
#   DBP: MAE=12.3337 | SD=3.2050
#   elapsed: 4.9s
#
# [Fold 3] fold=(886,1329) | train=(1149,1209) | test=(1299,1329)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.1229 | SD=3.6969
#   DBP: MAE=1.8207 | SD=2.2276
#   elapsed: 5.0s
#
# [Fold 4] fold=(1329,1772) | train=(1592,1652) | test=(1742,1772)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.4664 | SD=1.4462
#   DBP: MAE=0.9512 | SD=0.6459
#   elapsed: 5.6s
#
# [Fold 5] fold=(1772,2215) | train=(2035,2095) | test=(2185,2215)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.3377 | SD=3.4242
#   DBP: MAE=2.5436 | SD=2.7261
#   elapsed: 4.9s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.8705 | SD=2.8017
# Avg DBP: MAE=3.7716 | SD=2.0403
# Elapsed for this gap: 27.0s
#
# [Patient Done] p030582.mat | filtering=False | elapsed: 108.0s
#
# --------------------------------------------------------------------------------
# [6/10] START p030589.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p030589.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=2049 / 2049
#
# [Data Ready] total_len=2049
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=409 segs (~68.17 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,409) | train=(319,379) | test=(379,409)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.1557 | SD=3.1439
#   DBP: MAE=1.1093 | SD=1.3234
#   elapsed: 4.8s
#
# [Fold 2] fold=(409,818) | train=(728,788) | test=(788,818)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.0659 | SD=2.7107
#   DBP: MAE=0.7470 | SD=0.9871
#   elapsed: 5.9s
#
# [Fold 3] fold=(818,1227) | train=(1137,1197) | test=(1197,1227)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.3787 | SD=4.5426
#   DBP: MAE=2.0478 | SD=2.9506
#   elapsed: 4.7s
#
# [Fold 4] fold=(1227,1636) | train=(1546,1606) | test=(1606,1636)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.4655 | SD=1.5974
#   DBP: MAE=1.0590 | SD=0.9807
#   elapsed: 4.9s
#
# [Fold 5] fold=(1636,2045) | train=(1955,2015) | test=(2015,2045)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.1271 | SD=1.4405
#   DBP: MAE=0.6815 | SD=0.8592
#   elapsed: 5.9s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=2.4386 | SD=2.6870
# Avg DBP: MAE=1.1289 | SD=1.4202
# Elapsed for this gap: 27.0s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,409) | train=(289,349) | test=(379,409)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.1282 | SD=4.1752
#   DBP: MAE=2.3455 | SD=1.4556
#   elapsed: 5.0s
#
# [Fold 2] fold=(409,818) | train=(698,758) | test=(788,818)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.7296 | SD=2.4316
#   DBP: MAE=0.7587 | SD=0.9363
#   elapsed: 6.0s
#
# [Fold 3] fold=(818,1227) | train=(1107,1167) | test=(1197,1227)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.1598 | SD=4.8440
#   DBP: MAE=2.3029 | SD=2.5853
#   elapsed: 4.8s
#
# [Fold 4] fold=(1227,1636) | train=(1516,1576) | test=(1606,1636)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.6769 | SD=3.3808
#   DBP: MAE=2.1600 | SD=1.0789
#   elapsed: 5.4s
#
# [Fold 5] fold=(1636,2045) | train=(1925,1985) | test=(2015,2045)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.9977 | SD=2.4790
#   DBP: MAE=1.8792 | SD=0.9821
#   elapsed: 5.3s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.3384 | SD=3.4621
# Avg DBP: MAE=1.8893 | SD=1.4076
# Elapsed for this gap: 27.3s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,409) | train=(259,319) | test=(379,409)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.9586 | SD=3.4720
#   DBP: MAE=1.9787 | SD=1.2838
#   elapsed: 4.8s
#
# [Fold 2] fold=(409,818) | train=(668,728) | test=(788,818)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.1693 | SD=2.3104
#   DBP: MAE=0.8078 | SD=0.9700
#   elapsed: 6.2s
#
# [Fold 3] fold=(818,1227) | train=(1077,1137) | test=(1197,1227)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.5653 | SD=4.1721
#   DBP: MAE=1.6179 | SD=2.4343
#   elapsed: 5.0s
#
# [Fold 4] fold=(1227,1636) | train=(1486,1546) | test=(1606,1636)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.1772 | SD=3.0779
#   DBP: MAE=3.1104 | SD=1.0902
#   elapsed: 6.0s
#
# [Fold 5] fold=(1636,2045) | train=(1895,1955) | test=(2015,2045)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.0574 | SD=2.5682
#   DBP: MAE=1.2971 | SD=1.0455
#   elapsed: 5.0s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.7856 | SD=3.1201
# Avg DBP: MAE=1.7624 | SD=1.3648
# Elapsed for this gap: 27.7s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,409) | train=(229,289) | test=(379,409)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.1491 | SD=4.9783
#   DBP: MAE=1.5940 | SD=1.9670
#   elapsed: 4.8s
#
# [Fold 2] fold=(409,818) | train=(638,698) | test=(788,818)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.5362 | SD=3.5705
#   DBP: MAE=1.6446 | SD=1.4279
#   elapsed: 5.8s
#
# [Fold 3] fold=(818,1227) | train=(1047,1107) | test=(1197,1227)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.3170 | SD=4.6798
#   DBP: MAE=2.5000 | SD=3.0174
#   elapsed: 4.8s
#
# [Fold 4] fold=(1227,1636) | train=(1456,1516) | test=(1606,1636)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.1644 | SD=2.5080
#   DBP: MAE=2.6706 | SD=0.8417
#   elapsed: 5.9s
#
# [Fold 5] fold=(1636,2045) | train=(1865,1925) | test=(2015,2045)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.8294 | SD=1.9373
#   DBP: MAE=1.9809 | SD=1.0918
#   elapsed: 4.9s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.1992 | SD=3.5348
# Avg DBP: MAE=2.0780 | SD=1.6691
# Elapsed for this gap: 26.9s
#
# [Patient Done] p030589.mat | filtering=False | elapsed: 108.9s
#
# --------------------------------------------------------------------------------
# [7/10] START p030670.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p030670.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=1764 / 1764
#
# [Data Ready] total_len=1764
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=352 segs (~58.67 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,352) | train=(262,322) | test=(322,352)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.7579 | SD=2.1891
#   DBP: MAE=0.7316 | SD=0.9240
#   elapsed: 5.3s
#
# [Fold 2] fold=(352,704) | train=(614,674) | test=(674,704)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.3551 | SD=2.2069
#   DBP: MAE=0.8384 | SD=0.9932
#   elapsed: 4.9s
#
# [Fold 3] fold=(704,1056) | train=(966,1026) | test=(1026,1056)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.4878 | SD=0.9802
#   DBP: MAE=0.5015 | SD=0.4690
#   elapsed: 5.9s
#
# [Fold 4] fold=(1056,1408) | train=(1318,1378) | test=(1378,1408)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.1211 | SD=3.9470
#   DBP: MAE=1.3025 | SD=1.0444
#   elapsed: 4.8s
#
# [Fold 5] fold=(1408,1760) | train=(1670,1730) | test=(1730,1760)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.7092 | SD=2.3249
#   DBP: MAE=0.7427 | SD=0.9322
#   elapsed: 5.6s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.4862 | SD=2.3296
# Avg DBP: MAE=0.8233 | SD=0.8726
# Elapsed for this gap: 27.3s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,352) | train=(232,292) | test=(322,352)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.2694 | SD=1.7191
#   DBP: MAE=0.5947 | SD=0.6749
#   elapsed: 5.0s
#
# [Fold 2] fold=(352,704) | train=(584,644) | test=(674,704)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.6562 | SD=1.8142
#   DBP: MAE=0.8577 | SD=0.8356
#   elapsed: 4.8s
#
# [Fold 3] fold=(704,1056) | train=(936,996) | test=(1026,1056)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.7629 | SD=1.4815
#   DBP: MAE=0.8926 | SD=0.9267
#   elapsed: 5.8s
#
# [Fold 4] fold=(1056,1408) | train=(1288,1348) | test=(1378,1408)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.8944 | SD=4.2800
#   DBP: MAE=1.7416 | SD=1.1780
#   elapsed: 4.7s
#
# [Fold 5] fold=(1408,1760) | train=(1640,1700) | test=(1730,1760)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.9331 | SD=2.3684
#   DBP: MAE=0.6040 | SD=0.8123
#   elapsed: 5.6s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=3.5032 | SD=2.3326
# Avg DBP: MAE=0.9381 | SD=0.8855
# Elapsed for this gap: 26.7s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,352) | train=(202,262) | test=(322,352)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.3001 | SD=1.5387
#   DBP: MAE=0.5851 | SD=0.7032
#   elapsed: 4.9s
#
# [Fold 2] fold=(352,704) | train=(554,614) | test=(674,704)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.6160 | SD=1.7019
#   DBP: MAE=1.1285 | SD=0.6659
#   elapsed: 4.8s
#
# [Fold 3] fold=(704,1056) | train=(906,966) | test=(1026,1056)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.2369 | SD=1.0371
#   DBP: MAE=1.4863 | SD=0.5008
#   elapsed: 5.8s
#
# [Fold 4] fold=(1056,1408) | train=(1258,1318) | test=(1378,1408)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.8526 | SD=4.0144
#   DBP: MAE=0.7085 | SD=0.8850
#   elapsed: 4.8s
#
# [Fold 5] fold=(1408,1760) | train=(1610,1670) | test=(1730,1760)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.8920 | SD=1.8420
#   DBP: MAE=1.2889 | SD=0.6222
#   elapsed: 5.6s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.7795 | SD=2.0268
# Avg DBP: MAE=1.0394 | SD=0.6754
# Elapsed for this gap: 26.7s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,352) | train=(172,232) | test=(322,352)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.9391 | SD=1.9644
#   DBP: MAE=0.5707 | SD=0.7082
#   elapsed: 4.8s
#
# [Fold 2] fold=(352,704) | train=(524,584) | test=(674,704)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.3037 | SD=1.6740
#   DBP: MAE=0.5937 | SD=0.7138
#   elapsed: 4.7s
#
# [Fold 3] fold=(704,1056) | train=(876,936) | test=(1026,1056)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=17.4173 | SD=2.3508
#   DBP: MAE=9.2553 | SD=0.8069
#   elapsed: 5.8s
#
# [Fold 4] fold=(1056,1408) | train=(1228,1288) | test=(1378,1408)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.7355 | SD=3.8184
#   DBP: MAE=1.3734 | SD=1.0217
#   elapsed: 4.7s
#
# [Fold 5] fold=(1408,1760) | train=(1580,1640) | test=(1730,1760)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.0040 | SD=2.5298
#   DBP: MAE=1.7610 | SD=1.1618
#   elapsed: 5.6s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.4799 | SD=2.4675
# Avg DBP: MAE=2.7108 | SD=0.8825
# Elapsed for this gap: 26.4s
#
# [Patient Done] p030670.mat | filtering=False | elapsed: 107.1s
#
# --------------------------------------------------------------------------------
# [8/10] START p040299.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p040299.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=2301 / 2301
#
# [Data Ready] total_len=2301
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=460 segs (~76.67 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(370,430) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.8072 | SD=0.8830
#   DBP: MAE=0.6295 | SD=0.7313
#   elapsed: 5.7s
#
# [Fold 2] fold=(460,920) | train=(830,890) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.6796 | SD=4.2694
#   DBP: MAE=1.5210 | SD=2.4557
#   elapsed: 4.7s
#
# [Fold 3] fold=(920,1380) | train=(1290,1350) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.5338 | SD=1.1396
#   DBP: MAE=0.6918 | SD=0.6546
#   elapsed: 4.7s
#
# [Fold 4] fold=(1380,1840) | train=(1750,1810) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.6561 | SD=0.8755
#   DBP: MAE=0.6500 | SD=0.7170
#   elapsed: 5.8s
#
# [Fold 5] fold=(1840,2300) | train=(2210,2270) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=17.6505 | SD=4.8704
#   DBP: MAE=12.4341 | SD=3.3894
#   elapsed: 4.8s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.8654 | SD=2.4076
# Avg DBP: MAE=3.1853 | SD=1.5896
# Elapsed for this gap: 26.5s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(340,400) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.4890 | SD=0.8548
#   DBP: MAE=0.5955 | SD=0.7334
#   elapsed: 5.7s
#
# [Fold 2] fold=(460,920) | train=(800,860) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.7669 | SD=2.9264
#   DBP: MAE=1.5564 | SD=2.3509
#   elapsed: 4.7s
#
# [Fold 3] fold=(920,1380) | train=(1260,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.1480 | SD=0.8874
#   DBP: MAE=2.5066 | SD=0.5661
#   elapsed: 4.8s
#
# [Fold 4] fold=(1380,1840) | train=(1720,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.8764 | SD=1.0455
#   DBP: MAE=0.6831 | SD=0.7906
#   elapsed: 5.9s
#
# [Fold 5] fold=(1840,2300) | train=(2180,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=18.4504 | SD=4.0683
#   DBP: MAE=13.2691 | SD=3.0111
#   elapsed: 4.7s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.3461 | SD=1.9565
# Avg DBP: MAE=3.7221 | SD=1.4904
# Elapsed for this gap: 26.5s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(310,370) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.7849 | SD=0.9045
#   DBP: MAE=1.5481 | SD=0.6894
#   elapsed: 5.7s
#
# [Fold 2] fold=(460,920) | train=(770,830) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.7988 | SD=7.6119
#   DBP: MAE=3.9576 | SD=4.3051
#   elapsed: 4.7s
#
# [Fold 3] fold=(920,1380) | train=(1230,1290) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.4020 | SD=1.0486
#   DBP: MAE=3.9145 | SD=0.7044
#   elapsed: 4.7s
#
# [Fold 4] fold=(1380,1840) | train=(1690,1750) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.9356 | SD=1.0650
#   DBP: MAE=0.6279 | SD=0.7699
#   elapsed: 5.8s
#
# [Fold 5] fold=(1840,2300) | train=(2150,2210) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=17.7753 | SD=3.8991
#   DBP: MAE=13.4224 | SD=2.8154
#   elapsed: 4.7s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.3393 | SD=2.9058
# Avg DBP: MAE=4.6941 | SD=1.8568
# Elapsed for this gap: 26.5s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(280,340) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.4692 | SD=1.0672
#   DBP: MAE=3.1132 | SD=0.6669
#   elapsed: 5.6s
#
# [Fold 2] fold=(460,920) | train=(740,800) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.2220 | SD=5.8267
#   DBP: MAE=2.6627 | SD=3.0469
#   elapsed: 4.7s
#
# [Fold 3] fold=(920,1380) | train=(1200,1260) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.9327 | SD=1.2728
#   DBP: MAE=5.5158 | SD=0.7341
#   elapsed: 4.7s
#
# [Fold 4] fold=(1380,1840) | train=(1660,1720) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.0168 | SD=1.0071
#   DBP: MAE=0.8164 | SD=0.7899
#   elapsed: 5.8s
#
# [Fold 5] fold=(1840,2300) | train=(2120,2180) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=15.0720 | SD=4.2167
#   DBP: MAE=12.3093 | SD=2.9338
#   elapsed: 4.7s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.1425 | SD=2.6781
# Avg DBP: MAE=4.8835 | SD=1.6343
# Elapsed for this gap: 26.3s
#
# [Patient Done] p040299.mat | filtering=False | elapsed: 105.8s
#
# --------------------------------------------------------------------------------
# [9/10] START p041107.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p041107.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=1996 / 1996
#
# [Data Ready] total_len=1996
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=399 segs (~66.50 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(309,369) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.5646 | SD=1.9458
#   DBP: MAE=1.4325 | SD=0.8965
#   elapsed: 4.7s
#
# [Fold 2] fold=(399,798) | train=(708,768) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.6582 | SD=3.3928
#   DBP: MAE=1.0429 | SD=1.1964
#   elapsed: 5.1s
#
# [Fold 3] fold=(798,1197) | train=(1107,1167) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.4293 | SD=11.3925
#   DBP: MAE=2.2448 | SD=2.6710
#   elapsed: 5.3s
#
# [Fold 4] fold=(1197,1596) | train=(1506,1566) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.7313 | SD=6.6990
#   DBP: MAE=2.6780 | SD=2.3034
#   elapsed: 4.7s
#
# [Fold 5] fold=(1596,1995) | train=(1905,1965) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.6379 | SD=5.5344
#   DBP: MAE=5.6246 | SD=5.1929
#   elapsed: 5.8s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.4043 | SD=5.7929
# Avg DBP: MAE=2.6046 | SD=2.4520
# Elapsed for this gap: 26.4s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(279,339) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.9397 | SD=2.8148
#   DBP: MAE=1.9247 | SD=0.8391
#   elapsed: 4.7s
#
# [Fold 2] fold=(399,798) | train=(678,738) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.4463 | SD=3.2776
#   DBP: MAE=0.9668 | SD=1.0397
#   elapsed: 5.3s
#
# [Fold 3] fold=(798,1197) | train=(1077,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.3351 | SD=9.1918
#   DBP: MAE=2.4517 | SD=2.0300
#   elapsed: 5.2s
#
# [Fold 4] fold=(1197,1596) | train=(1476,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.1694 | SD=6.6537
#   DBP: MAE=3.1024 | SD=3.3862
#   elapsed: 4.8s
#
# [Fold 5] fold=(1596,1995) | train=(1875,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.4194 | SD=6.9284
#   DBP: MAE=6.8866 | SD=5.2471
#   elapsed: 5.8s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.8620 | SD=5.7733
# Avg DBP: MAE=3.0664 | SD=2.5084
# Elapsed for this gap: 26.5s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(249,309) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.2421 | SD=2.4875
#   DBP: MAE=2.6195 | SD=0.7841
#   elapsed: 4.7s
#
# [Fold 2] fold=(399,798) | train=(648,708) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.0727 | SD=2.8010
#   DBP: MAE=0.7534 | SD=0.8619
#   elapsed: 5.2s
#
# [Fold 3] fold=(798,1197) | train=(1047,1107) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.3028 | SD=10.2415
#   DBP: MAE=2.5512 | SD=2.4911
#   elapsed: 5.2s
#
# [Fold 4] fold=(1197,1596) | train=(1446,1506) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.6171 | SD=6.6434
#   DBP: MAE=3.5870 | SD=2.9822
#   elapsed: 4.8s
#
# [Fold 5] fold=(1596,1995) | train=(1845,1905) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=11.8135 | SD=5.6438
#   DBP: MAE=7.8231 | SD=4.9885
#   elapsed: 5.8s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.8096 | SD=5.5635
# Avg DBP: MAE=3.4668 | SD=2.4216
# Elapsed for this gap: 26.5s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(219,279) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=17.7693 | SD=2.3752
#   DBP: MAE=6.4055 | SD=0.7408
#   elapsed: 4.7s
#
# [Fold 2] fold=(399,798) | train=(618,678) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.1611 | SD=2.9669
#   DBP: MAE=0.8500 | SD=0.9999
#   elapsed: 5.3s
#
# [Fold 3] fold=(798,1197) | train=(1017,1077) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.3994 | SD=10.0983
#   DBP: MAE=2.9596 | SD=3.0606
#   elapsed: 5.2s
#
# [Fold 4] fold=(1197,1596) | train=(1416,1476) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.0749 | SD=6.0865
#   DBP: MAE=4.2661 | SD=2.9541
#   elapsed: 4.8s
#
# [Fold 5] fold=(1596,1995) | train=(1815,1875) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.8365 | SD=6.9819
#   DBP: MAE=6.4275 | SD=4.8980
#   elapsed: 5.8s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=9.4482 | SD=5.7017
# Avg DBP: MAE=4.1817 | SD=2.5307
# Elapsed for this gap: 26.5s
#
# [Patient Done] p041107.mat | filtering=False | elapsed: 105.9s
#
# --------------------------------------------------------------------------------
# [10/10] START p043774.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p043774.mat | filtering=False
# ================================================================================
# ✅ (filtering=False) kept=1943 / 1943
#
# [Data Ready] total_len=1943
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=388 segs (~64.67 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(298,358) | test=(358,388)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.4385 | SD=1.7433
#   DBP: MAE=0.7990 | SD=1.0108
#   elapsed: 5.8s
#
# [Fold 2] fold=(388,776) | train=(686,746) | test=(746,776)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.6554 | SD=5.5065
#   DBP: MAE=3.3579 | SD=3.2262
#   elapsed: 4.8s
#
# [Fold 3] fold=(776,1164) | train=(1074,1134) | test=(1134,1164)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.8334 | SD=2.0012
#   DBP: MAE=1.0361 | SD=1.3582
#   elapsed: 5.1s
#
# [Fold 4] fold=(1164,1552) | train=(1462,1522) | test=(1522,1552)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.3943 | SD=1.4474
#   DBP: MAE=2.0387 | SD=0.8061
#   elapsed: 5.5s
#
# [Fold 5] fold=(1552,1940) | train=(1850,1910) | test=(1910,1940)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.8520 | SD=3.3109
#   DBP: MAE=1.4282 | SD=1.8241
#   elapsed: 4.8s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=2.8347 | SD=2.8019
# Avg DBP: MAE=1.7320 | SD=1.6451
# Elapsed for this gap: 26.8s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(268,328) | test=(358,388)
#   sizes Train/Val/Test: 48/12/30
# ...
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(370,430) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.7725 | SD=0.9052
#   DBP: MAE=0.5458 | SD=0.6589
#   elapsed: 3.5s
#
# [Fold 2] fold=(460,920) | train=(830,890) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.9551 | SD=2.7318
#   DBP: MAE=3.9907 | SD=4.5102
#   elapsed: 3.5s
#
# [Fold 3] fold=(920,1380) | train=(1290,1350) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.5228 | SD=0.9232
#   DBP: MAE=0.5396 | SD=0.6521
#   elapsed: 4.1s
#
# [Fold 4] fold=(1380,1840) | train=(1750,1810) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.7109 | SD=0.8940
#   DBP: MAE=0.5773 | SD=0.7017
#   elapsed: 3.8s
#
# [Fold 5] fold=(1840,2300) | train=(2210,2270) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=18.3529 | SD=5.9588
#   DBP: MAE=13.4052 | SD=4.2026
#   elapsed: 3.6s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.6628 | SD=2.2826
# Avg DBP: MAE=3.8117 | SD=2.1451
# Elapsed for this gap: 19.1s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(340,400) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.2016 | SD=0.7926
#   DBP: MAE=0.5278 | SD=0.6198
#   elapsed: 3.6s
#
# [Fold 2] fold=(460,920) | train=(800,860) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.0991 | SD=3.1871
#   DBP: MAE=1.6639 | SD=2.4860
#   elapsed: 4.2s
#
# [Fold 3] fold=(920,1380) | train=(1260,1320) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.7633 | SD=1.0267
#   DBP: MAE=2.4208 | SD=0.7642
#   elapsed: 3.6s
#
# [Fold 4] fold=(1380,1840) | train=(1720,1780) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.6487 | SD=0.7702
#   DBP: MAE=0.6810 | SD=0.6755
#   elapsed: 3.5s
#
# [Fold 5] fold=(1840,2300) | train=(2180,2240) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=19.3710 | SD=4.0115
#   DBP: MAE=13.4001 | SD=2.9177
#   elapsed: 4.4s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.6167 | SD=1.9576
# Avg DBP: MAE=3.7387 | SD=1.4927
# Elapsed for this gap: 20.1s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(310,370) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.5235 | SD=0.8821
#   DBP: MAE=1.9047 | SD=0.6603
#   elapsed: 3.5s
#
# [Fold 2] fold=(460,920) | train=(770,830) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.4614 | SD=5.6120
#   DBP: MAE=1.8842 | SD=2.3646
#   elapsed: 3.5s
#
# [Fold 3] fold=(920,1380) | train=(1230,1290) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.7868 | SD=1.0028
#   DBP: MAE=3.3517 | SD=0.7102
#   elapsed: 4.0s
#
# [Fold 4] fold=(1380,1840) | train=(1690,1750) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=0.7705 | SD=0.8729
#   DBP: MAE=0.8495 | SD=0.6587
#   elapsed: 3.9s
#
# [Fold 5] fold=(1840,2300) | train=(2150,2210) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=18.5298 | SD=3.9555
#   DBP: MAE=14.0874 | SD=2.8811
#   elapsed: 3.5s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.2144 | SD=2.4651
# Avg DBP: MAE=4.4155 | SD=1.4550
# Elapsed for this gap: 19.1s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,460) | train=(280,340) | test=(430,460)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.0495 | SD=0.9032
#   DBP: MAE=2.9025 | SD=0.6237
#   elapsed: 3.5s
#
# [Fold 2] fold=(460,920) | train=(740,800) | test=(890,920)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.1973 | SD=2.5380
#   DBP: MAE=1.9429 | SD=2.4125
#   elapsed: 4.4s
#
# [Fold 3] fold=(920,1380) | train=(1200,1260) | test=(1350,1380)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.4761 | SD=1.1333
#   DBP: MAE=5.6793 | SD=0.6969
#   elapsed: 3.4s
#
# [Fold 4] fold=(1380,1840) | train=(1660,1720) | test=(1810,1840)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.0779 | SD=0.9795
#   DBP: MAE=0.6680 | SD=0.6836
#   elapsed: 3.5s
#
# [Fold 5] fold=(1840,2300) | train=(2120,2180) | test=(2270,2300)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=17.8194 | SD=4.0256
#   DBP: MAE=13.6319 | SD=3.0233
#   elapsed: 4.1s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.9240 | SD=1.9159
# Avg DBP: MAE=4.9649 | SD=1.4880
# Elapsed for this gap: 19.7s
#
# [Patient Done] p040299.mat | filtering=True | elapsed: 78.0s
#
# --------------------------------------------------------------------------------
# [9/10] START p041107.mat | filtering=True
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p041107.mat | filtering=True
# ================================================================================
# ✅ (filtering=True) kept=1996 / 1996
# ❌ 제외됨: (혈압범위: 0, 신호편차: 0)
#
# [Data Ready] total_len=1996
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=399 segs (~66.50 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(309,369) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.2753 | SD=1.8969
#   DBP: MAE=1.1148 | SD=0.5941
#   elapsed: 4.3s
#
# [Fold 2] fold=(399,798) | train=(708,768) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.5916 | SD=2.7478
#   DBP: MAE=1.3568 | SD=0.8792
#   elapsed: 3.5s
#
# [Fold 3] fold=(798,1197) | train=(1107,1167) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.0991 | SD=5.8141
#   DBP: MAE=2.6207 | SD=2.2413
#   elapsed: 3.5s
#
# [Fold 4] fold=(1197,1596) | train=(1506,1566) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.3458 | SD=5.4604
#   DBP: MAE=2.6052 | SD=2.3997
#   elapsed: 3.8s
#
# [Fold 5] fold=(1596,1995) | train=(1905,1965) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.6806 | SD=4.9348
#   DBP: MAE=5.7778 | SD=5.2902
#   elapsed: 4.2s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.9985 | SD=4.1708
# Avg DBP: MAE=2.6951 | SD=2.2809
# Elapsed for this gap: 20.2s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(279,339) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.5589 | SD=1.9176
#   DBP: MAE=2.1906 | SD=0.6185
#   elapsed: 3.5s
#
# [Fold 2] fold=(399,798) | train=(678,738) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.1274 | SD=3.6981
#   DBP: MAE=1.1564 | SD=1.2690
#   elapsed: 3.6s
#
# [Fold 3] fold=(798,1197) | train=(1077,1137) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.7661 | SD=5.1782
#   DBP: MAE=2.6478 | SD=1.7446
#   elapsed: 4.6s
#
# [Fold 4] fold=(1197,1596) | train=(1476,1536) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.5006 | SD=5.4219
#   DBP: MAE=3.7727 | SD=2.5061
#   elapsed: 3.5s
#
# [Fold 5] fold=(1596,1995) | train=(1875,1935) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.8734 | SD=5.6854
#   DBP: MAE=5.6333 | SD=5.0933
#   elapsed: 3.6s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=5.1653 | SD=4.3802
# Avg DBP: MAE=3.0801 | SD=2.2463
# Elapsed for this gap: 19.6s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(249,309) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.0743 | SD=2.4914
#   DBP: MAE=4.4652 | SD=0.7441
#   elapsed: 4.3s
#
# [Fold 2] fold=(399,798) | train=(648,708) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.1815 | SD=3.4523
#   DBP: MAE=1.0489 | SD=1.1850
#   elapsed: 3.5s
#
# [Fold 3] fold=(798,1197) | train=(1047,1107) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.8115 | SD=5.2228
#   DBP: MAE=2.3036 | SD=2.6343
#   elapsed: 3.5s
#
# [Fold 4] fold=(1197,1596) | train=(1446,1506) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=7.7175 | SD=5.4745
#   DBP: MAE=2.6396 | SD=2.8776
#   elapsed: 3.8s
#
# [Fold 5] fold=(1596,1995) | train=(1845,1905) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.9668 | SD=6.9097
#   DBP: MAE=9.1989 | SD=5.5535
#   elapsed: 4.1s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=7.3503 | SD=4.7101
# Avg DBP: MAE=3.9312 | SD=2.5989
# Elapsed for this gap: 20.1s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,399) | train=(219,279) | test=(369,399)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=18.1819 | SD=2.3617
#   DBP: MAE=7.5734 | SD=0.7198
#   elapsed: 3.5s
#
# [Fold 2] fold=(399,798) | train=(618,678) | test=(768,798)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.0467 | SD=3.1914
#   DBP: MAE=0.9621 | SD=1.0910
#   elapsed: 3.5s
#
# [Fold 3] fold=(798,1197) | train=(1017,1077) | test=(1167,1197)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=5.9848 | SD=5.0857
#   DBP: MAE=1.1470 | SD=1.4765
#   elapsed: 4.4s
#
# [Fold 4] fold=(1197,1596) | train=(1416,1476) | test=(1566,1596)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=13.1035 | SD=7.6648
#   DBP: MAE=6.6653 | SD=4.7897
#   elapsed: 3.5s
#
# [Fold 5] fold=(1596,1995) | train=(1815,1875) | test=(1965,1995)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.6698 | SD=11.3409
#   DBP: MAE=7.1070 | SD=5.2603
#   elapsed: 3.6s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=10.7973 | SD=5.9289
# Avg DBP: MAE=4.6910 | SD=2.6675
# Elapsed for this gap: 19.3s
#
# [Patient Done] p041107.mat | filtering=True | elapsed: 79.1s
#
# --------------------------------------------------------------------------------
# [10/10] START p043774.mat | filtering=True
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p043774.mat | filtering=True
# ================================================================================
# ✅ (filtering=True) kept=1943 / 1943
# ❌ 제외됨: (혈압범위: 0, 신호편차: 0)
#
# [Data Ready] total_len=1943
#
# === PHASE 2 CONFIG ===
# N_FOLDS=5 | BlockGap=0min (0 segs)
# FoldLen=388 segs (~64.67 min)
# TrainDur=10min (60 segs) | TestDur=5min (30 segs)
# TimeGap sweep (min): [0, 5, 10, 15]
# ValFracInTrain=0.20
#
# ===============================
#  TimeGap = 0 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(298,358) | test=(358,388)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.0244 | SD=1.2285
#   DBP: MAE=0.7821 | SD=0.8086
#   elapsed: 3.6s
#
# [Fold 2] fold=(388,776) | train=(686,746) | test=(746,776)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.9992 | SD=1.8564
#   DBP: MAE=0.9170 | SD=1.1351
#   elapsed: 4.2s
#
# [Fold 3] fold=(776,1164) | train=(1074,1134) | test=(1134,1164)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.2503 | SD=1.4396
#   DBP: MAE=1.1387 | SD=1.0201
#   elapsed: 3.7s
#
# [Fold 4] fold=(1164,1552) | train=(1462,1522) | test=(1522,1552)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.0560 | SD=1.9591
#   DBP: MAE=1.4708 | SD=0.8652
#   elapsed: 3.5s
#
# [Fold 5] fold=(1552,1940) | train=(1850,1910) | test=(1910,1940)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=12.8400 | SD=3.5268
#   DBP: MAE=4.9490 | SD=1.7255
#   elapsed: 3.7s
#
# --- TimeGap 0 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.2340 | SD=2.0021
# Avg DBP: MAE=1.8515 | SD=1.1109
# Elapsed for this gap: 19.6s
#
# ===============================
#  TimeGap = 5 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(268,328) | test=(358,388)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.5593 | SD=1.3867
#   DBP: MAE=1.7687 | SD=0.8033
#   elapsed: 4.2s
#
# [Fold 2] fold=(388,776) | train=(656,716) | test=(746,776)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.5339 | SD=1.4388
#   DBP: MAE=5.5926 | SD=0.9661
#   elapsed: 3.5s
#
# [Fold 3] fold=(776,1164) | train=(1044,1104) | test=(1134,1164)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=1.1901 | SD=1.3345
#   DBP: MAE=0.8705 | SD=0.9442
#   elapsed: 3.6s
#
# [Fold 4] fold=(1164,1552) | train=(1432,1492) | test=(1522,1552)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=4.5970 | SD=2.1685
#   DBP: MAE=3.0079 | SD=0.9473
#   elapsed: 4.5s
#
# [Fold 5] fold=(1552,1940) | train=(1820,1880) | test=(1910,1940)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.1898 | SD=3.3472
#   DBP: MAE=4.7709 | SD=1.5668
#   elapsed: 3.6s
#
# --- TimeGap 5 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=4.6140 | SD=1.9351
# Avg DBP: MAE=3.2021 | SD=1.0456
# Elapsed for this gap: 20.1s
#
# ===============================
#  TimeGap = 10 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(238,298) | test=(358,388)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=2.7796 | SD=1.5837
#   DBP: MAE=1.0992 | SD=1.3740
#   elapsed: 3.4s
#
# [Fold 2] fold=(388,776) | train=(626,686) | test=(746,776)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.6322 | SD=1.4814
#   DBP: MAE=5.8216 | SD=0.9580
#   elapsed: 4.0s
#
# [Fold 3] fold=(776,1164) | train=(1014,1074) | test=(1134,1164)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.1483 | SD=1.7133
#   DBP: MAE=3.2735 | SD=1.0375
#   elapsed: 3.8s
#
# [Fold 4] fold=(1164,1552) | train=(1402,1462) | test=(1522,1552)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.9755 | SD=1.5986
#   DBP: MAE=4.9394 | SD=0.9969
#   elapsed: 3.4s
#
# [Fold 5] fold=(1552,1940) | train=(1790,1850) | test=(1910,1940)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=10.9331 | SD=2.6970
#   DBP: MAE=6.9618 | SD=1.2571
#   elapsed: 3.4s
#
# --- TimeGap 10 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=8.4937 | SD=1.8148
# Avg DBP: MAE=4.4191 | SD=1.1247
# Elapsed for this gap: 18.8s
#
# ===============================
#  TimeGap = 15 min
# ===============================
#
# [Fold 1] fold=(0,388) | train=(208,268) | test=(358,388)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=9.6942 | SD=2.2370
#   DBP: MAE=5.2830 | SD=1.9460
#   elapsed: 4.3s
#
# [Fold 2] fold=(388,776) | train=(596,656) | test=(746,776)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=3.7789 | SD=2.2749
#   DBP: MAE=2.3518 | SD=1.6792
#   elapsed: 3.4s
#
# [Fold 3] fold=(776,1164) | train=(984,1044) | test=(1134,1164)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.1208 | SD=1.0414
#   DBP: MAE=0.8008 | SD=0.8151
#   elapsed: 3.5s
#
# [Fold 4] fold=(1164,1552) | train=(1372,1432) | test=(1522,1552)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=8.2930 | SD=0.9097
#   DBP: MAE=4.0464 | SD=0.5756
#   elapsed: 4.0s
#
# [Fold 5] fold=(1552,1940) | train=(1760,1820) | test=(1910,1940)
#   sizes Train/Val/Test: 48/12/30
#   SBP: MAE=6.9097 | SD=2.6825
#   DBP: MAE=6.2599 | SD=1.1845
#   elapsed: 3.7s
#
# --- TimeGap 15 min SUMMARY ---
# ValidFolds: 5/5
# Avg SBP: MAE=6.9593 | SD=1.8291
# Avg DBP: MAE=3.7484 | SD=1.2401
# Elapsed for this gap: 19.7s
#
# [Patient Done] p043774.mat | filtering=True | elapsed: 78.1s
#
# ################################################################################
# [FINAL SUMMARY] filtering=True | patient-level mean across usable patients
# Used patients: 10 / 10
# ################################################################################
#
# [TimeGap=0 min] PatientsUsedForGap: 10/10
#   SBP(MAE): mean=3.8474 | std=1.0368
#   DBP(MAE): mean=2.4188 | std=1.5652
#   SBP(err SD): mean=3.1307 | std=1.2170
#   DBP(err SD): mean=1.9211 | std=1.0898
#
# [TimeGap=5 min] PatientsUsedForGap: 10/10
#   SBP(MAE): mean=5.3552 | std=1.0145
#   DBP(MAE): mean=2.8321 | std=0.9374
#   SBP(err SD): mean=3.2232 | std=1.2963
#   DBP(err SD): mean=1.6971 | std=0.6741
#
# [TimeGap=10 min] PatientsUsedForGap: 10/10
#   SBP(MAE): mean=7.1633 | std=1.8867
#   DBP(MAE): mean=3.8930 | std=2.2482
#   SBP(err SD): mean=3.8585 | std=2.4020
#   DBP(err SD): mean=2.0970 | std=1.5376
#
# [TimeGap=15 min] PatientsUsedForGap: 10/10
#   SBP(MAE): mean=8.5448 | std=4.6747
#   DBP(MAE): mean=5.0411 | std=3.3053
#   SBP(err SD): mean=4.0142 | std=2.5182
#   DBP(err SD): mean=2.3923 | std=1.9353
#
# [ALL DONE] filtering=True | Total elapsed: 896.3s
#
# ================================================================================
# [DONE] Filter sweep complete.
# ================================================================================
# Compare: filtering=False vs filtering=True in the logs above.
