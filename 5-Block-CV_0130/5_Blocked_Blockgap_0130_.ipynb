# %%
# ============================================================
# Phase 4 (extended) — multi-patient, 5-blocked time-wise CV
#  - TimeGap_min = 5 (FIXED)
#  - TestDur_min  = 5 (FIXED)
#  - TrainDur sweep: [3, 5, 10, 15]
#  - BlockGap sweep: [0, 3, 5, 10]
#  - filtering sweep: [False, True]
#
# Per patient:
#   - per fold MAE/SD
#   - per (TrainDur, BlockGap) summary:
#       Avg / WorstFold / StdAcrossFolds(MAE)
#
# Final:
#   - For each filtering:
#       For each TrainDur:
#           For each BlockGap:
#               patient-level mean ± std across patients
# ============================================================

import os, glob, time, random, gc
import numpy as np
import h5py
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from scipy.interpolate import interp1d
from scipy.integrate import trapezoid

# ==========================================
# [0] Experiment settings
# ==========================================
PULSEDB_DIR = "/content/drive/MyDrive/Colab Notebooks/PulseDB"
SEGMENT_LIMIT = None
PAD_LEN = 200
SEC_PER_SEGMENT = 10.0

BATCH_SIZE = 32
EPOCHS = 100
LR = 1e-3
WEIGHT_DECAY = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SEED = 42
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

print(f"Using Device: {DEVICE}")

# Protocol config
N_FOLDS = 5
TIME_GAP_MIN = 5
TEST_DUR_MIN = 5
VAL_FRAC_IN_TRAIN = 0.20

TRAIN_DUR_SWEEP_MIN = [3, 5, 10, 15]
BLOCK_GAP_SWEEP_MIN = [0, 3, 5, 10]
FILTERING_SWEEP = [False, True]

# ==========================================
# [1] Filtering + resample + priors
# ==========================================
def preprocess_ensemble_by_rpeaks(ppg_raw, rpeaks_raw, sbp, dbp, target_len=125, threshold_corr=0.7):
    if not (50 <= sbp <= 250) or not (30 <= dbp <= 160):
        return None

    ppg = ppg_raw.squeeze()
    rpeaks = rpeaks_raw.squeeze()
    rpeaks = np.sort(rpeaks.astype(int))

    beats = []
    for i in range(len(rpeaks) - 1):
        start, end = rpeaks[i], rpeaks[i + 1]
        if start < 0 or end > len(ppg):
            continue
        beat_segment = ppg[start:end]
        if len(beat_segment) < 20:
            continue

        x_old = np.linspace(0, 1, len(beat_segment))
        x_new = np.linspace(0, 1, target_len)
        f_interp = interp1d(x_old, beat_segment, kind='linear', fill_value="extrapolate")
        beats.append(f_interp(x_new))

    if len(beats) < 5:
        return None

    beats = np.array(beats)
    ensemble_avg = np.mean(beats, axis=0)

    e_min, e_max = ensemble_avg.min(), ensemble_avg.max()
    if e_max - e_min > 1e-6:
        ensemble_avg = (ensemble_avg - e_min) / (e_max - e_min)

    correlations = [np.corrcoef(ensemble_avg, b)[0, 1] for b in beats]
    consistent_beats_count = sum(1 for c in correlations if c >= threshold_corr)
    if (consistent_beats_count / len(beats)) < 0.7:
        return None

    return ensemble_avg.astype(np.float32)

def cubic_resample(ppg, target_len=PAD_LEN):
    x_old = np.linspace(0, 1, len(ppg))
    x_new = np.linspace(0, 1, target_len)
    if len(ppg) < 4:
        return np.interp(x_new, x_old, ppg).astype(np.float32)
    try:
        f = interp1d(x_old, ppg, kind="cubic", bounds_error=False, fill_value="extrapolate")
        return f(x_new).astype(np.float32)
    except Exception:
        return np.interp(x_new, x_old, ppg).astype(np.float32)

def extract_multiscale_morph_features(ppg_01):
    scales = [100, 150, 200, 250]
    all_features = []
    for scale in scales:
        x = cubic_resample(ppg_01, scale)

        peak_idx = int(np.argmax(x))
        end_idx = scale - 1

        vp = float(x[peak_idx])
        vt = float(x[end_idx])
        dv = vp - vt
        vm = float(np.mean(x))
        std_val = float(np.std(x))

        tvp = peak_idx / scale

        diff = np.diff(x)
        kmax = float(np.max(diff)) if len(diff) > 0 else 0.0
        tkmax = (int(np.argmax(diff)) / scale) if len(diff) > 0 else 0.0

        amax = float(trapezoid(x[:peak_idx])) if peak_idx > 0 else 0.0

        centered = x - vm
        skew_approx = float(np.mean(centered**3) / (std_val**3)) if std_val > 0 else 0.0
        kurt_approx = float(np.mean(centered**4) / (std_val**4)) if std_val > 0 else 0.0

        all_features.extend([vp, vt, dv, vm, kmax, tkmax, amax, std_val, tvp, skew_approx, kurt_approx])

    return np.array(all_features, dtype=np.float32)

# ==========================================
# [2] Load data
# ==========================================
def load_data_from_mat(mat_path, segment_limit=None, filtering=False):
    segments, priors, targets = [], [], []
    skip_bp, skip_noise = 0, 0

    with h5py.File(mat_path, "r") as f:
        sw = f["Subj_Wins"]
        ppg_refs = sw["PPG_F"][0]
        sbp_refs = sw["SegSBP"][0]
        dbp_refs = sw["SegDBP"][0]

        total = min(len(ppg_refs), segment_limit) if segment_limit else len(ppg_refs)

        if not filtering:
            for i in range(total):
                ppg = f[ppg_refs[i]][()].squeeze().astype(np.float32)
                sbp = float(f[sbp_refs[i]][()][0][0])
                dbp = float(f[dbp_refs[i]][()][0][0])

                segments.append(ppg)
                priors.append(extract_multiscale_morph_features(ppg))
                targets.append([sbp, dbp])

            print(f"✅ (NoFilter) kept: {len(segments)} / {total}")
            return segments, np.stack(priors).astype(np.float32), np.array(targets, dtype=np.float32)

        ecg_refs = sw["ECG_RPeaks"][0]
        for i in range(total):
            ppg_raw = f[ppg_refs[i]][()]
            sbp = float(f[sbp_refs[i]][()][0][0])
            dbp = float(f[dbp_refs[i]][()][0][0])
            rpeaks_raw = f[ecg_refs[i]][()]

            processed_ppg = preprocess_ensemble_by_rpeaks(ppg_raw, rpeaks_raw, sbp, dbp)

            if processed_ppg is None:
                if not (50 <= sbp <= 250) or not (30 <= dbp <= 160):
                    skip_bp += 1
                else:
                    skip_noise += 1
                continue

            segments.append(processed_ppg)
            priors.append(extract_multiscale_morph_features(processed_ppg))
            targets.append([sbp, dbp])

    print(f"✅ (Filter) kept: {len(segments)} / {total}")
    print(f"❌ excluded: (bp_range={skip_bp}, noise/quality={skip_noise})")
    return segments, np.stack(priors).astype(np.float32), np.array(targets, dtype=np.float32)

# ==========================================
# [3] Dataset
# ==========================================
class PPGDatasetRawY(Dataset):
    def __init__(self, segments, priors, targets_mmHg):
        self.segments = segments
        self.priors = priors
        self.targets = targets_mmHg

    def __len__(self):
        return len(self.segments)

    def __getitem__(self, idx):
        x = cubic_resample(self.segments[idx], PAD_LEN)
        x = torch.tensor(x, dtype=torch.float32).unsqueeze(0)
        p = torch.tensor(self.priors[idx], dtype=torch.float32)
        y = torch.tensor(self.targets[idx], dtype=torch.float32)
        return x, p, y

# ==========================================
# [4] Model
# ==========================================
class MorphCNNRegressor(nn.Module):
    def __init__(self, prior_dim=44):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(1, 32, 7, padding=3),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(32, 64, 5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, 5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, 256, 3, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )

        self.fc_prior = nn.Sequential(
            nn.Linear(prior_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.ReLU()
        )

        self.fc_out = nn.Sequential(
            nn.Linear(256 + 256, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 2)
        )

    def forward(self, x, prior):
        feat = self.cnn(x).squeeze(-1)
        pfeat = self.fc_prior(prior)
        return self.fc_out(torch.cat([feat, pfeat], dim=1))

# ==========================================
# [5] Train-only label scaler
# ==========================================
class LabelScaler2D:
    def __init__(self, mode="minmax", eps=1e-6):
        assert mode in ["minmax", "zscore"]
        self.mode = mode
        self.eps = eps
        self.fitted = False

    def fit(self, y_train_mmHg: np.ndarray):
        y = np.asarray(y_train_mmHg, dtype=np.float32)
        if self.mode == "minmax":
            self.y_min = y.min(axis=0)
            self.y_max = y.max(axis=0)
        else:
            self.y_mean = y.mean(axis=0)
            self.y_std = y.std(axis=0)
        self.fitted = True
        return self

    def transform(self, y_mmHg: torch.Tensor) -> torch.Tensor:
        assert self.fitted
        if self.mode == "minmax":
            y_min = torch.tensor(self.y_min, device=y_mmHg.device, dtype=y_mmHg.dtype)
            y_max = torch.tensor(self.y_max, device=y_mmHg.device, dtype=y_mmHg.dtype)
            return (y_mmHg - y_min) / (y_max - y_min + self.eps)
        else:
            y_mean = torch.tensor(self.y_mean, device=y_mmHg.device, dtype=y_mmHg.dtype)
            y_std = torch.tensor(self.y_std, device=y_mmHg.device, dtype=y_mmHg.dtype)
            return (y_mmHg - y_mean) / (y_std + self.eps)

    def inverse(self, y_scaled: torch.Tensor) -> torch.Tensor:
        assert self.fitted
        if self.mode == "minmax":
            y_min = torch.tensor(self.y_min, device=y_scaled.device, dtype=y_scaled.dtype)
            y_max = torch.tensor(self.y_max, device=y_scaled.device, dtype=y_scaled.dtype)
            return y_scaled * (y_max - y_min + self.eps) + y_min
        else:
            y_mean = torch.tensor(self.y_mean, device=y_scaled.device, dtype=y_scaled.dtype)
            y_std = torch.tensor(self.y_std, device=y_scaled.device, dtype=y_scaled.dtype)
            return y_scaled * (y_std + self.eps) + y_mean

# ==========================================
# [6] Train / Eval
# ==========================================
def set_seed(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def train_one_model(train_loader, val_loader, scaler: LabelScaler2D):
    model = MorphCNNRegressor(prior_dim=44).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    criterion = nn.MSELoss()

    best_val = float("inf")
    best_state = None

    for epoch in range(1, EPOCHS + 1):
        model.train()
        for x, p, y_mmHg in train_loader:
            x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
            y = scaler.transform(y_mmHg)
            pred = model(x, p)
            loss = criterion(pred, y)
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        val_losses = []
        with torch.no_grad():
            for x, p, y_mmHg in val_loader:
                x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
                y = scaler.transform(y_mmHg)
                pred = model(x, p)
                val_losses.append(float(criterion(pred, y).item()))
        avg_val = float(np.mean(val_losses)) if len(val_losses) else float("inf")

        if avg_val < best_val:
            best_val = avg_val
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    if best_state is not None:
        model.load_state_dict(best_state)
    return model

def eval_mae_sd_mmHg(model, loader, scaler: LabelScaler2D):
    model.eval()
    errs = []
    with torch.no_grad():
        for x, p, y_mmHg in loader:
            x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
            pred_scaled = model(x, p)
            pred_mmHg = scaler.inverse(pred_scaled)
            err = (pred_mmHg - y_mmHg).detach().cpu().numpy()
            errs.append(err)

    if len(errs) == 0:
        return dict(mae_sbp=np.nan, sd_sbp=np.nan, mae_dbp=np.nan, sd_dbp=np.nan, n=0)

    E = np.concatenate(errs, axis=0)
    e_sbp, e_dbp = E[:, 0], E[:, 1]
    return dict(
        mae_sbp=float(np.mean(np.abs(e_sbp))),
        sd_sbp=float(np.std(e_sbp, ddof=0)),
        mae_dbp=float(np.mean(np.abs(e_dbp))),
        sd_dbp=float(np.std(e_dbp, ddof=0)),
        n=int(E.shape[0])
    )

# ==========================================
# [7] CV helpers
# ==========================================
def segs_from_minutes(minutes: float) -> int:
    return int((minutes * 60.0) / SEC_PER_SEGMENT)

def summarize_folds(valid_stats):
    mae_sbp = np.array([v["mae_sbp"] for v in valid_stats], dtype=np.float32)
    mae_dbp = np.array([v["mae_dbp"] for v in valid_stats], dtype=np.float32)
    sd_sbp  = np.array([v["sd_sbp"]  for v in valid_stats], dtype=np.float32)
    sd_dbp  = np.array([v["sd_dbp"]  for v in valid_stats], dtype=np.float32)

    return {
        "avg_mae_sbp": float(mae_sbp.mean()) if len(mae_sbp) else float("nan"),
        "avg_mae_dbp": float(mae_dbp.mean()) if len(mae_dbp) else float("nan"),
        "avg_sd_sbp":  float(sd_sbp.mean())  if len(sd_sbp)  else float("nan"),
        "avg_sd_dbp":  float(sd_dbp.mean())  if len(sd_dbp)  else float("nan"),
        "worst_mae_sbp": float(mae_sbp.max()) if len(mae_sbp) else float("nan"),
        "worst_mae_dbp": float(mae_dbp.max()) if len(mae_dbp) else float("nan"),
        "std_mae_sbp": float(mae_sbp.std(ddof=0)) if len(mae_sbp) else float("nan"),
        "std_mae_dbp": float(mae_dbp.std(ddof=0)) if len(mae_dbp) else float("nan"),
        "valid_folds": int(len(mae_sbp)),
    }

def min_required_total_len(bg_min: float, tr_min: float) -> int:
    b_gap = segs_from_minutes(bg_min)
    need_per_fold = segs_from_minutes(tr_min) + segs_from_minutes(TIME_GAP_MIN) + segs_from_minutes(TEST_DUR_MIN)
    return N_FOLDS * need_per_fold + (N_FOLDS - 1) * b_gap

# ==========================================
# [8] One patient: (TrainDur x BlockGap)
# ==========================================
def run_one_patient(mat_path: str, filtering: bool):
    set_seed(SEED)

    print("\n" + "=" * 80)
    print(f"[PATIENT] {os.path.basename(mat_path)} | filtering={filtering}")
    print("=" * 80)

    segments, priors, targets_mmHg = load_data_from_mat(mat_path, segment_limit=SEGMENT_LIMIT, filtering=filtering)
    ds = PPGDatasetRawY(segments, priors, targets_mmHg)
    total_len = len(ds)
    print(f"[Data Ready] total_len={total_len}")

    gap_segs  = segs_from_minutes(TIME_GAP_MIN)
    test_segs = segs_from_minutes(TEST_DUR_MIN)

    # patient_summary[tr_min][bg_min] = summary or None
    patient_summary = {tr_min: {} for tr_min in TRAIN_DUR_SWEEP_MIN}

    for tr_min in TRAIN_DUR_SWEEP_MIN:
        tr_segs = segs_from_minutes(tr_min)
        print("\n" + "-" * 80)
        print(f"[TrainDur = {tr_min} min] (TimeGap={TIME_GAP_MIN}m, TestDur={TEST_DUR_MIN}m)")
        print("-" * 80)

        for bg_min in BLOCK_GAP_SWEEP_MIN:
            # feasibility conservative
            min_need = min_required_total_len(bg_min, tr_min)
            if total_len < min_need:
                patient_summary[tr_min][bg_min] = None
                print(f"[BlockGap {bg_min}m] SKIP (too short): total_len={total_len} < min_need={min_need}")
                continue

            b_gap_segs = segs_from_minutes(bg_min)
            available_len = total_len - (N_FOLDS - 1) * b_gap_segs
            if available_len <= 0:
                patient_summary[tr_min][bg_min] = None
                print(f"[BlockGap {bg_min}m] SKIP (available_len<=0).")
                continue

            fold_len = available_len // N_FOLDS
            if fold_len <= 0 or fold_len <= test_segs + 1:
                patient_summary[tr_min][bg_min] = None
                print(f"[BlockGap {bg_min}m] SKIP (fold_len too small). fold_len={fold_len}")
                continue

            print(f"\n  >>> BlockGap={bg_min}m | FoldLen={fold_len} segs (~{fold_len*SEC_PER_SEGMENT/60.0:.2f} min)")

            fold_stats = []
            for f_idx in range(N_FOLDS):
                fold_start = f_idx * (fold_len + b_gap_segs)
                fold_end   = fold_start + fold_len

                test_end = fold_end
                test_start = test_end - test_segs

                train_end = test_start - gap_segs
                train_start = train_end - tr_segs

                if train_start < fold_start or train_end > test_start:
                    print(f"    [Fold {f_idx+1}] SKIP (room): fold=({fold_start},{fold_end}) train=({train_start},{train_end}) test=({test_start},{test_end})")
                    fold_stats.append(None)
                    continue

                train_indices = list(range(train_start, train_end))
                test_indices  = list(range(test_start, test_end))

                n_total = len(train_indices)
                n_val = max(1, int(n_total * VAL_FRAC_IN_TRAIN))
                if n_total - n_val < 1:
                    print(f"    [Fold {f_idx+1}] SKIP (train too small after val split).")
                    fold_stats.append(None)
                    continue

                real_train_idx = train_indices[:-n_val]
                val_idx        = train_indices[-n_val:]

                y_train = targets_mmHg[np.array(real_train_idx)]
                scaler = LabelScaler2D(mode="minmax", eps=1e-6).fit(y_train)

                train_loader = DataLoader(Subset(ds, real_train_idx), batch_size=BATCH_SIZE, shuffle=True)
                val_loader   = DataLoader(Subset(ds, val_idx), batch_size=BATCH_SIZE, shuffle=False)
                test_loader  = DataLoader(Subset(ds, test_indices), batch_size=BATCH_SIZE, shuffle=False)

                t0 = time.time()
                model = train_one_model(train_loader, val_loader, scaler)
                stat = eval_mae_sd_mmHg(model, test_loader, scaler)
                elapsed = time.time() - t0

                stat.update({
                    "fold": f_idx + 1,
                    "train_dur_min": tr_min,
                    "block_gap_min": bg_min,
                    "train_n": len(real_train_idx),
                    "val_n": len(val_idx),
                    "test_n": len(test_indices),
                    "elapsed_s": float(elapsed),
                })
                fold_stats.append(stat)

                print(f"    [Fold {f_idx+1}] SBP MAE={stat['mae_sbp']:.4f}, SD={stat['sd_sbp']:.4f} | "
                      f"DBP MAE={stat['mae_dbp']:.4f}, SD={stat['sd_dbp']:.4f} | elapsed={elapsed:.1f}s")

                del model
                if torch.cuda.is_available():
                    torch.cuda.empty_cache()
                gc.collect()

            valid = [fs for fs in fold_stats if fs is not None and np.isfinite(fs["mae_sbp"])]

            if len(valid) == 0:
                patient_summary[tr_min][bg_min] = None
                print(f"  --- SUMMARY TrainDur={tr_min}m BlockGap={bg_min}m: ValidFolds=0/{N_FOLDS}")
            else:
                summ = summarize_folds(valid)
                patient_summary[tr_min][bg_min] = summ
                print(f"  --- SUMMARY TrainDur={tr_min}m BlockGap={bg_min}m | ValidFolds={summ['valid_folds']}/{N_FOLDS}")
                print(f"      Avg   SBP: MAE={summ['avg_mae_sbp']:.4f} | SD={summ['avg_sd_sbp']:.4f}")
                print(f"      Avg   DBP: MAE={summ['avg_mae_dbp']:.4f} | SD={summ['avg_sd_dbp']:.4f}")
                print(f"      Worst SBP: MAE={summ['worst_mae_sbp']:.4f} | StdAcrossFolds(MAE)={summ['std_mae_sbp']:.4f}")
                print(f"      Worst DBP: MAE={summ['worst_mae_dbp']:.4f} | StdAcrossFolds(MAE)={summ['std_mae_dbp']:.4f}")

    return patient_summary

# ==========================================
# [9] All patients: final grouping by TrainDur
# ==========================================
def run_all(pulsedb_dir: str):
    patient_files = sorted(glob.glob(os.path.join(pulsedb_dir, "p*.mat")))
    if len(patient_files) == 0:
        raise FileNotFoundError(f"No .mat files found under: {pulsedb_dir}")

    print("\n" + "#" * 80)
    print(f"[RUN ALL] Found {len(patient_files)} patients")
    for f in patient_files:
        print("  -", os.path.basename(f))
    print("#" * 80)

    all_results = {filtering: [] for filtering in FILTERING_SWEEP}
    skipped = {filtering: [] for filtering in FILTERING_SWEEP}

    t0_all = time.time()

    for filtering in FILTERING_SWEEP:
        print("\n" + "#" * 80)
        print(f"[FILTERING MODE] filtering={filtering}")
        print("#" * 80)

        for i, mat_path in enumerate(patient_files, 1):
            print("\n" + "-" * 80)
            print(f"[{i}/{len(patient_files)}] START {os.path.basename(mat_path)} | filtering={filtering}")
            print("-" * 80)

            try:
                summary = run_one_patient(mat_path, filtering=filtering)
                all_results[filtering].append({"patient": os.path.basename(mat_path), "summary": summary})
            except Exception as e:
                reason = f"{type(e).__name__}: {e}"
                print(f"[SKIP PATIENT] {os.path.basename(mat_path)} | reason: {reason}")
                skipped[filtering].append((os.path.basename(mat_path), reason))

            if torch.cuda.is_available():
                torch.cuda.empty_cache()
            gc.collect()

        # ---- FINAL: TrainDur -> BlockGap -> patient mean±std ----
        print("\n" + "#" * 80)
        print(f"[FINAL SUMMARY] filtering={filtering} | grouped by TrainDur then BlockGap")
        print(f"Used patients: {len(all_results[filtering])} / {len(patient_files)}")
        print("#" * 80)

        def mean_std(arr):
            if len(arr) == 0:
                return float("nan"), float("nan")
            arr = np.asarray(arr, dtype=np.float32)
            ddof = 1 if len(arr) >= 2 else 0
            return float(arr.mean()), float(arr.std(ddof=ddof))

        for tr_min in TRAIN_DUR_SWEEP_MIN:
            print("\n" + "=" * 80)
            print(f"[TrainDur = {tr_min} min]  (TimeGap={TIME_GAP_MIN}m, TestDur={TEST_DUR_MIN}m)")
            print("=" * 80)

            for bg_min in BLOCK_GAP_SWEEP_MIN:
                avg_mae_sbp_list, avg_mae_dbp_list = [], []
                avg_sd_sbp_list,  avg_sd_dbp_list  = [], []
                worst_mae_sbp_list, worst_mae_dbp_list = [], []
                std_mae_sbp_list, std_mae_dbp_list = [], []

                used = 0
                for item in all_results[filtering]:
                    s_tr = item["summary"].get(tr_min, None)
                    if s_tr is None:
                        continue
                    s = s_tr.get(bg_min, None)
                    if s is None:
                        continue
                    if not np.isfinite(s["avg_mae_sbp"]):
                        continue
                    used += 1

                    avg_mae_sbp_list.append(s["avg_mae_sbp"])
                    avg_mae_dbp_list.append(s["avg_mae_dbp"])
                    avg_sd_sbp_list.append(s["avg_sd_sbp"])
                    avg_sd_dbp_list.append(s["avg_sd_dbp"])
                    worst_mae_sbp_list.append(s["worst_mae_sbp"])
                    worst_mae_dbp_list.append(s["worst_mae_dbp"])
                    std_mae_sbp_list.append(s["std_mae_sbp"])
                    std_mae_dbp_list.append(s["std_mae_dbp"])

                print(f"\n  [BlockGap={bg_min} min] PatientsUsed: {used}/{len(all_results[filtering])}")

                m, s = mean_std(avg_mae_sbp_list)
                print(f"    AvgMAE SBP: mean={m:.4f} | std={s:.4f}")
                m, s = mean_std(avg_mae_dbp_list)
                print(f"    AvgMAE DBP: mean={m:.4f} | std={s:.4f}")

                m, s = mean_std(avg_sd_sbp_list)
                print(f"    AvgSD  SBP: mean={m:.4f} | std={s:.4f}")
                m, s = mean_std(avg_sd_dbp_list)
                print(f"    AvgSD  DBP: mean={m:.4f} | std={s:.4f}")

                m, s = mean_std(worst_mae_sbp_list)
                print(f"    WorstMAE SBP: mean={m:.4f} | std={s:.4f}")
                m, s = mean_std(worst_mae_dbp_list)
                print(f"    WorstMAE DBP: mean={m:.4f} | std={s:.4f}")

                m, s = mean_std(std_mae_sbp_list)
                print(f"    StdAcrossFolds(MAE) SBP: mean={m:.4f} | std={s:.4f}")
                m, s = mean_std(std_mae_dbp_list)
                print(f"    StdAcrossFolds(MAE) DBP: mean={m:.4f} | std={s:.4f}")

        if len(skipped[filtering]) > 0:
            print("\n" + "#" * 80)
            print(f"[SKIPPED PATIENTS] filtering={filtering}")
            print("#" * 80)
            for p, r in skipped[filtering]:
                print(f"- {p}: {r}")

    print(f"\n[ALL DONE] Total elapsed: {time.time() - t0_all:.1f}s")
    return all_results, skipped

# ==========================================
# [MAIN]
# ==========================================
if __name__ == "__main__":
    run_all(PULSEDB_DIR)
# Out:
# Using Device: cuda
#
# ################################################################################
# [RUN ALL] Found 10 patients
#   - p001855.mat
#   - p004679.mat
#   - p004833.mat
#   - p009993.mat
#   - p030582.mat
#   - p030589.mat
#   - p030670.mat
#   - p040299.mat
#   - p041107.mat
#   - p043774.mat
# ################################################################################
#
# ################################################################################
# [FILTERING MODE] filtering=False
# ################################################################################
#
# --------------------------------------------------------------------------------
# [1/10] START p001855.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p001855.mat | filtering=False
# ================================================================================
# ✅ (NoFilter) kept: 2178 / 2178
# [Data Ready] total_len=2178
#
# --------------------------------------------------------------------------------
# [TrainDur = 3 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=435 segs (~72.50 min)
#     [Fold 1] SBP MAE=1.3080, SD=1.3587 | DBP MAE=0.9770, SD=1.0525 | elapsed=3.5s
#     [Fold 2] SBP MAE=8.1376, SD=2.7273 | DBP MAE=4.2287, SD=1.3839 | elapsed=1.8s
#     [Fold 3] SBP MAE=2.6515, SD=1.2792 | DBP MAE=2.1346, SD=0.6523 | elapsed=1.8s
#     [Fold 4] SBP MAE=4.6231, SD=2.7126 | DBP MAE=3.4682, SD=1.6236 | elapsed=1.7s
#     [Fold 5] SBP MAE=2.6269, SD=1.5467 | DBP MAE=0.8624, SD=0.6246 | elapsed=2.3s
#   --- SUMMARY TrainDur=3m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=3.8694 | SD=1.9249
#       Avg   DBP: MAE=2.3342 | SD=1.0674
#       Worst SBP: MAE=8.1376 | StdAcrossFolds(MAE)=2.3822
#       Worst DBP: MAE=4.2287 | StdAcrossFolds(MAE)=1.3359
#
#   >>> BlockGap=3m | FoldLen=421 segs (~70.17 min)
#     [Fold 1] SBP MAE=4.4966, SD=1.7643 | DBP MAE=1.7537, SD=1.1631 | elapsed=2.2s
#     [Fold 2] SBP MAE=8.5717, SD=4.2102 | DBP MAE=4.0168, SD=2.1105 | elapsed=1.8s
#     [Fold 3] SBP MAE=2.8948, SD=1.8491 | DBP MAE=2.1494, SD=0.9695 | elapsed=1.8s
#     [Fold 4] SBP MAE=4.0057, SD=2.4061 | DBP MAE=2.9731, SD=1.4790 | elapsed=1.9s
#     [Fold 5] SBP MAE=2.2931, SD=1.2308 | DBP MAE=0.7231, SD=0.5062 | elapsed=1.8s
#   --- SUMMARY TrainDur=3m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=4.4524 | SD=2.2921
#       Avg   DBP: MAE=2.3232 | SD=1.2456
#       Worst SBP: MAE=8.5717 | StdAcrossFolds(MAE)=2.2027
#       Worst DBP: MAE=4.0168 | StdAcrossFolds(MAE)=1.1141
#
#   >>> BlockGap=5m | FoldLen=411 segs (~68.50 min)
#     [Fold 1] SBP MAE=3.9803, SD=1.5736 | DBP MAE=1.0771, SD=0.9859 | elapsed=2.1s
#     [Fold 2] SBP MAE=6.8049, SD=3.6266 | DBP MAE=3.6336, SD=1.7044 | elapsed=2.5s
#     [Fold 3] SBP MAE=2.9643, SD=3.5221 | DBP MAE=2.4927, SD=1.6928 | elapsed=1.8s
#     [Fold 4] SBP MAE=3.7626, SD=1.7420 | DBP MAE=2.8608, SD=1.0187 | elapsed=1.9s
#     [Fold 5] SBP MAE=2.8099, SD=1.4651 | DBP MAE=0.9215, SD=0.5770 | elapsed=1.8s
#   --- SUMMARY TrainDur=3m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=4.0644 | SD=2.3859
#       Avg   DBP: MAE=2.1971 | SD=1.1958
#       Worst SBP: MAE=6.8049 | StdAcrossFolds(MAE)=1.4417
#       Worst DBP: MAE=3.6336 | StdAcrossFolds(MAE)=1.0462
#
#   >>> BlockGap=10m | FoldLen=387 segs (~64.50 min)
#     [Fold 1] SBP MAE=4.5483, SD=1.4503 | DBP MAE=1.1180, SD=0.8619 | elapsed=1.8s
#     [Fold 2] SBP MAE=2.7046, SD=3.0836 | DBP MAE=1.1803, SD=1.2495 | elapsed=1.8s
#     [Fold 3] SBP MAE=3.4834, SD=3.9866 | DBP MAE=2.2820, SD=1.8458 | elapsed=2.5s
#     [Fold 4] SBP MAE=2.2633, SD=0.9537 | DBP MAE=2.5044, SD=0.6695 | elapsed=1.9s
#     [Fold 5] SBP MAE=3.2256, SD=1.7825 | DBP MAE=1.0538, SD=0.7064 | elapsed=1.8s
#   --- SUMMARY TrainDur=3m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=3.2450 | SD=2.2513
#       Avg   DBP: MAE=1.6277 | SD=1.0666
#       Worst SBP: MAE=4.5483 | StdAcrossFolds(MAE)=0.7761
#       Worst DBP: MAE=2.5044 | StdAcrossFolds(MAE)=0.6302
#
# --------------------------------------------------------------------------------
# [TrainDur = 5 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=435 segs (~72.50 min)
#     [Fold 1] SBP MAE=1.5283, SD=1.9390 | DBP MAE=1.0728, SD=1.2990 | elapsed=2.8s
#     [Fold 2] SBP MAE=6.7540, SD=2.6031 | DBP MAE=2.8270, SD=1.2712 | elapsed=2.7s
#     [Fold 3] SBP MAE=2.2780, SD=1.1219 | DBP MAE=2.0102, SD=0.6965 | elapsed=3.4s
#     [Fold 4] SBP MAE=4.4383, SD=2.6880 | DBP MAE=3.2103, SD=1.6241 | elapsed=2.6s
#     [Fold 5] SBP MAE=3.0853, SD=1.4413 | DBP MAE=1.1102, SD=0.5762 | elapsed=2.6s
#   --- SUMMARY TrainDur=5m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=3.6168 | SD=1.9587
#       Avg   DBP: MAE=2.0461 | SD=1.0934
#       Worst SBP: MAE=6.7540 | StdAcrossFolds(MAE)=1.8414
#       Worst DBP: MAE=3.2103 | StdAcrossFolds(MAE)=0.8706
#
#   >>> BlockGap=3m | FoldLen=421 segs (~70.17 min)
#     [Fold 1] SBP MAE=3.1966, SD=1.5644 | DBP MAE=1.1888, SD=1.0478 | elapsed=2.6s
#     [Fold 2] SBP MAE=13.1836, SD=2.2940 | DBP MAE=4.5153, SD=1.3151 | elapsed=2.9s
#     [Fold 3] SBP MAE=2.3335, SD=1.9788 | DBP MAE=1.8054, SD=0.6612 | elapsed=3.0s
#     [Fold 4] SBP MAE=4.2108, SD=2.3770 | DBP MAE=3.1790, SD=1.3779 | elapsed=2.6s
#     [Fold 5] SBP MAE=3.1744, SD=1.3304 | DBP MAE=0.9925, SD=0.5392 | elapsed=2.7s
#   --- SUMMARY TrainDur=5m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=5.2198 | SD=1.9089
#       Avg   DBP: MAE=2.3362 | SD=0.9882
#       Worst SBP: MAE=13.1836 | StdAcrossFolds(MAE)=4.0261
#       Worst DBP: MAE=4.5153 | StdAcrossFolds(MAE)=1.3313
#
#   >>> BlockGap=5m | FoldLen=411 segs (~68.50 min)
#     [Fold 1] SBP MAE=4.3955, SD=1.5902 | DBP MAE=1.3017, SD=1.0633 | elapsed=2.6s
#     [Fold 2] SBP MAE=5.6486, SD=3.6609 | DBP MAE=1.5650, SD=1.6374 | elapsed=4.3s
#     [Fold 3] SBP MAE=3.1383, SD=3.5985 | DBP MAE=2.4970, SD=2.1160 | elapsed=2.7s
#     [Fold 4] SBP MAE=3.5345, SD=1.8573 | DBP MAE=2.8790, SD=1.0307 | elapsed=2.7s
#     [Fold 5] SBP MAE=3.4495, SD=1.4545 | DBP MAE=1.0553, SD=0.5610 | elapsed=2.6s
#   --- SUMMARY TrainDur=5m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=4.0333 | SD=2.4323
#       Avg   DBP: MAE=1.8596 | SD=1.2817
#       Worst SBP: MAE=5.6486 | StdAcrossFolds(MAE)=0.9090
#       Worst DBP: MAE=2.8790 | StdAcrossFolds(MAE)=0.7057
#
#   >>> BlockGap=10m | FoldLen=387 segs (~64.50 min)
#     [Fold 1] SBP MAE=5.4309, SD=1.9673 | DBP MAE=1.3145, SD=0.9379 | elapsed=3.4s
#     [Fold 2] SBP MAE=2.6578, SD=2.9305 | DBP MAE=1.2059, SD=1.1734 | elapsed=2.7s
#     [Fold 3] SBP MAE=3.0610, SD=3.3931 | DBP MAE=2.2571, SD=2.0179 | elapsed=2.7s
#     [Fold 4] SBP MAE=1.7334, SD=1.0291 | DBP MAE=2.3608, SD=0.7418 | elapsed=2.7s
#     [Fold 5] SBP MAE=2.6321, SD=1.2974 | DBP MAE=0.8684, SD=0.5461 | elapsed=3.0s
#   --- SUMMARY TrainDur=5m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=3.1030 | SD=2.1235
#       Avg   DBP: MAE=1.6013 | SD=1.0834
#       Worst SBP: MAE=5.4309 | StdAcrossFolds(MAE)=1.2423
#       Worst DBP: MAE=2.3608 | StdAcrossFolds(MAE)=0.5971
#
# --------------------------------------------------------------------------------
# [TrainDur = 10 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=435 segs (~72.50 min)
#     [Fold 1] SBP MAE=1.5468, SD=1.6743 | DBP MAE=0.9379, SD=1.0815 | elapsed=5.0s
#     [Fold 2] SBP MAE=4.5848, SD=1.6350 | DBP MAE=1.9286, SD=0.6521 | elapsed=4.6s
#     [Fold 3] SBP MAE=2.8284, SD=1.1072 | DBP MAE=1.5002, SD=0.6099 | elapsed=5.6s
#     [Fold 4] SBP MAE=2.6698, SD=2.7097 | DBP MAE=2.9224, SD=1.6493 | elapsed=4.5s
#     [Fold 5] SBP MAE=3.2509, SD=1.3196 | DBP MAE=0.7489, SD=0.5941 | elapsed=4.8s
#   --- SUMMARY TrainDur=10m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=2.9761 | SD=1.6891
#       Avg   DBP: MAE=1.6076 | SD=0.9174
#       Worst SBP: MAE=4.5848 | StdAcrossFolds(MAE)=0.9820
#       Worst DBP: MAE=2.9224 | StdAcrossFolds(MAE)=0.7784
#
#   >>> BlockGap=3m | FoldLen=421 segs (~70.17 min)
#     [Fold 1] SBP MAE=4.2358, SD=1.3784 | DBP MAE=1.0697, SD=0.9285 | elapsed=5.2s
#     [Fold 2] SBP MAE=9.4082, SD=2.2347 | DBP MAE=2.2654, SD=0.8948 | elapsed=4.5s
#     [Fold 3] SBP MAE=2.5608, SD=1.2698 | DBP MAE=1.6120, SD=0.7934 | elapsed=5.6s
#     [Fold 4] SBP MAE=2.3336, SD=2.5890 | DBP MAE=2.2409, SD=1.4324 | elapsed=4.6s
#     [Fold 5] SBP MAE=2.8853, SD=1.1095 | DBP MAE=0.9943, SD=0.5133 | elapsed=4.5s
#   --- SUMMARY TrainDur=10m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=4.2847 | SD=1.7163
#       Avg   DBP: MAE=1.6365 | SD=0.9125
#       Worst SBP: MAE=9.4082 | StdAcrossFolds(MAE)=2.6454
#       Worst DBP: MAE=2.2654 | StdAcrossFolds(MAE)=0.5468
#
#   >>> BlockGap=5m | FoldLen=411 segs (~68.50 min)
#     [Fold 1] SBP MAE=3.3034, SD=1.5386 | DBP MAE=1.0185, SD=0.9971 | elapsed=5.5s
#     [Fold 2] SBP MAE=4.7563, SD=3.5344 | DBP MAE=1.8587, SD=1.5769 | elapsed=4.5s
#     [Fold 3] SBP MAE=3.0776, SD=3.4288 | DBP MAE=2.3713, SD=1.9441 | elapsed=5.4s
#     [Fold 4] SBP MAE=2.5498, SD=2.3874 | DBP MAE=2.3723, SD=1.2053 | elapsed=4.7s
#     [Fold 5] SBP MAE=3.5191, SD=1.3017 | DBP MAE=1.1344, SD=0.5419 | elapsed=4.6s
#   --- SUMMARY TrainDur=10m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=3.4412 | SD=2.4382
#       Avg   DBP: MAE=1.7510 | SD=1.2530
#       Worst SBP: MAE=4.7563 | StdAcrossFolds(MAE)=0.7323
#       Worst DBP: MAE=2.3723 | StdAcrossFolds(MAE)=0.5829
#
#   >>> BlockGap=10m | FoldLen=387 segs (~64.50 min)
#     [Fold 1] SBP MAE=18.5701, SD=6.2211 | DBP MAE=9.8217, SD=2.9634 | elapsed=5.5s
#     [Fold 2] SBP MAE=2.6117, SD=3.2279 | DBP MAE=1.0367, SD=1.2226 | elapsed=4.7s
#     [Fold 3] SBP MAE=3.2684, SD=1.9963 | DBP MAE=2.3778, SD=3.0243 | elapsed=5.3s
#     [Fold 4] SBP MAE=1.5792, SD=1.4424 | DBP MAE=2.1154, SD=0.7587 | elapsed=4.9s
#     [Fold 5] SBP MAE=4.1610, SD=1.2939 | DBP MAE=1.8424, SD=0.5410 | elapsed=4.5s
#   --- SUMMARY TrainDur=10m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=6.0381 | SD=2.8363
#       Avg   DBP: MAE=3.4388 | SD=1.7020
#       Worst SBP: MAE=18.5701 | StdAcrossFolds(MAE)=6.3225
#       Worst DBP: MAE=9.8217 | StdAcrossFolds(MAE)=3.2229
#
# --------------------------------------------------------------------------------
# [TrainDur = 15 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=435 segs (~72.50 min)
#     [Fold 1] SBP MAE=1.7843, SD=1.4228 | DBP MAE=1.0874, SD=1.2353 | elapsed=7.9s
#     [Fold 2] SBP MAE=3.7507, SD=1.9950 | DBP MAE=1.6998, SD=0.6678 | elapsed=7.1s
#     [Fold 3] SBP MAE=1.8185, SD=1.1495 | DBP MAE=0.8443, SD=0.5565 | elapsed=7.4s
#     [Fold 4] SBP MAE=2.8713, SD=3.0670 | DBP MAE=2.2741, SD=1.6878 | elapsed=7.8s
#     [Fold 5] SBP MAE=4.7835, SD=1.3072 | DBP MAE=2.1666, SD=0.5415 | elapsed=6.9s
#   --- SUMMARY TrainDur=15m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=3.0017 | SD=1.7883
#       Avg   DBP: MAE=1.6145 | SD=0.9378
#       Worst SBP: MAE=4.7835 | StdAcrossFolds(MAE)=1.1519
#       Worst DBP: MAE=2.2741 | StdAcrossFolds(MAE)=0.5689
#
#   >>> BlockGap=3m | FoldLen=421 segs (~70.17 min)
#     [Fold 1] SBP MAE=9.1260, SD=2.3428 | DBP MAE=2.8523, SD=2.1080 | elapsed=7.8s
#     [Fold 2] SBP MAE=6.6226, SD=2.4469 | DBP MAE=2.8323, SD=1.0941 | elapsed=6.9s
#     [Fold 3] SBP MAE=3.6135, SD=1.1613 | DBP MAE=1.2610, SD=1.6763 | elapsed=7.8s
#     [Fold 4] SBP MAE=2.9303, SD=2.7129 | DBP MAE=2.8275, SD=1.4268 | elapsed=7.6s
#     [Fold 5] SBP MAE=4.5704, SD=1.0990 | DBP MAE=1.7011, SD=0.4735 | elapsed=7.2s
#   --- SUMMARY TrainDur=15m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=5.3726 | SD=1.9526
#       Avg   DBP: MAE=2.2949 | SD=1.3557
#       Worst SBP: MAE=9.1260 | StdAcrossFolds(MAE)=2.2518
#       Worst DBP: MAE=2.8523 | StdAcrossFolds(MAE)=0.6789
#
#   >>> BlockGap=5m | FoldLen=411 segs (~68.50 min)
#     [Fold 1] SBP MAE=12.6897, SD=8.8495 | DBP MAE=5.8835, SD=4.3515 | elapsed=7.8s
#     [Fold 2] SBP MAE=2.9768, SD=3.5432 | DBP MAE=1.3366, SD=1.5961 | elapsed=6.9s
#     [Fold 3] SBP MAE=2.2676, SD=2.3666 | DBP MAE=1.5767, SD=2.7251 | elapsed=7.8s
#     [Fold 4] SBP MAE=2.6759, SD=2.3167 | DBP MAE=2.5293, SD=1.1266 | elapsed=6.9s
#     [Fold 5] SBP MAE=5.2817, SD=1.3086 | DBP MAE=1.3159, SD=0.5231 | elapsed=7.7s
#   --- SUMMARY TrainDur=15m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=5.1783 | SD=3.6769
#       Avg   DBP: MAE=2.5284 | SD=2.0645
#       Worst SBP: MAE=12.6897 | StdAcrossFolds(MAE)=3.8991
#       Worst DBP: MAE=5.8835 | StdAcrossFolds(MAE)=1.7351
#
#   >>> BlockGap=10m | FoldLen=387 segs (~64.50 min)
#     [Fold 1] SBP MAE=10.8542, SD=2.1993 | DBP MAE=5.5142, SD=1.5641 | elapsed=7.5s
#     [Fold 2] SBP MAE=4.9209, SD=5.5665 | DBP MAE=1.8702, SD=2.1941 | elapsed=7.2s
#     [Fold 3] SBP MAE=3.0737, SD=2.9825 | DBP MAE=1.8984, SD=2.7663 | elapsed=7.8s
#     [Fold 4] SBP MAE=1.0074, SD=1.1978 | DBP MAE=1.7652, SD=0.5926 | elapsed=6.9s
#     [Fold 5] SBP MAE=5.0500, SD=1.3678 | DBP MAE=2.1928, SD=0.6700 | elapsed=7.8s
#   --- SUMMARY TrainDur=15m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=4.9813 | SD=2.6628
#       Avg   DBP: MAE=2.6482 | SD=1.5574
#       Worst SBP: MAE=10.8542 | StdAcrossFolds(MAE)=3.2842
#       Worst DBP: MAE=5.5142 | StdAcrossFolds(MAE)=1.4400
#
# --------------------------------------------------------------------------------
# [2/10] START p004679.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p004679.mat | filtering=False
# ================================================================================
# ✅ (NoFilter) kept: 1862 / 1862
# [Data Ready] total_len=1862
#
# --------------------------------------------------------------------------------
# [TrainDur = 3 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=372 segs (~62.00 min)
#     [Fold 1] SBP MAE=3.7235, SD=3.8454 | DBP MAE=2.2190, SD=2.0399 | elapsed=2.2s
#     [Fold 2] SBP MAE=7.6628, SD=6.2110 | DBP MAE=3.7552, SD=2.9135 | elapsed=2.3s
#     [Fold 3] SBP MAE=10.0309, SD=3.0644 | DBP MAE=4.4507, SD=1.2803 | elapsed=1.8s
#     [Fold 4] SBP MAE=5.3891, SD=2.5722 | DBP MAE=1.0882, SD=1.3210 | elapsed=1.9s
#     [Fold 5] SBP MAE=25.2951, SD=8.3138 | DBP MAE=9.2911, SD=2.2738 | elapsed=1.9s
#   --- SUMMARY TrainDur=3m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=10.4203 | SD=4.8013
#       Avg   DBP: MAE=4.1608 | SD=1.9657
#       Worst SBP: MAE=25.2951 | StdAcrossFolds(MAE)=7.7353
#       Worst DBP: MAE=9.2911 | StdAcrossFolds(MAE)=2.8206
#
#   >>> BlockGap=3m | FoldLen=358 segs (~59.67 min)
#     [Fold 1] SBP MAE=1.9048, SD=2.4661 | DBP MAE=1.2751, SD=1.0857 | elapsed=1.8s
#     [Fold 2] SBP MAE=6.9616, SD=5.0096 | DBP MAE=3.3004, SD=2.1032 | elapsed=2.1s
#     [Fold 3] SBP MAE=10.4654, SD=3.7473 | DBP MAE=4.4863, SD=1.5692 | elapsed=2.4s
#     [Fold 4] SBP MAE=5.6543, SD=2.5633 | DBP MAE=1.2351, SD=1.3624 | elapsed=1.8s
#     [Fold 5] SBP MAE=33.3277, SD=7.5660 | DBP MAE=15.9783, SD=3.9660 | elapsed=1.8s
#   --- SUMMARY TrainDur=3m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=11.6628 | SD=4.2704
#       Avg   DBP: MAE=5.2550 | SD=2.0173
#       Worst SBP: MAE=33.3277 | StdAcrossFolds(MAE)=11.1734
#       Worst DBP: MAE=15.9783 | StdAcrossFolds(MAE)=5.5027
#
#   >>> BlockGap=5m | FoldLen=348 segs (~58.00 min)
#     [Fold 1] SBP MAE=3.4117, SD=4.2078 | DBP MAE=1.7554, SD=2.1131 | elapsed=1.9s
#     [Fold 2] SBP MAE=4.4794, SD=3.7979 | DBP MAE=2.2239, SD=1.4135 | elapsed=1.9s
#     [Fold 3] SBP MAE=11.8924, SD=3.7487 | DBP MAE=4.3951, SD=1.7165 | elapsed=1.9s
#     [Fold 4] SBP MAE=4.3329, SD=3.2429 | DBP MAE=1.4726, SD=1.5566 | elapsed=2.5s
#     [Fold 5] SBP MAE=33.9881, SD=7.9708 | DBP MAE=9.6173, SD=2.2215 | elapsed=1.8s
#   --- SUMMARY TrainDur=3m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=11.6209 | SD=4.5936
#       Avg   DBP: MAE=3.8929 | SD=1.8043
#       Worst SBP: MAE=33.9881 | StdAcrossFolds(MAE)=11.5920
#       Worst DBP: MAE=9.6173 | StdAcrossFolds(MAE)=3.0408
#
#   >>> BlockGap=10m | FoldLen=324 segs (~54.00 min)
#     [Fold 1] SBP MAE=4.4464, SD=4.1096 | DBP MAE=2.5670, SD=1.8661 | elapsed=1.9s
#     [Fold 2] SBP MAE=7.6120, SD=4.4314 | DBP MAE=4.6426, SD=1.9607 | elapsed=1.8s
#     [Fold 3] SBP MAE=12.0385, SD=3.7412 | DBP MAE=3.6198, SD=1.5918 | elapsed=1.8s
#     [Fold 4] SBP MAE=3.6630, SD=2.2498 | DBP MAE=1.4561, SD=0.9614 | elapsed=1.9s
#     [Fold 5] SBP MAE=16.2728, SD=8.3484 | DBP MAE=5.5507, SD=2.8002 | elapsed=2.5s
#   --- SUMMARY TrainDur=3m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=8.8065 | SD=4.5760
#       Avg   DBP: MAE=3.5672 | SD=1.8360
#       Worst SBP: MAE=16.2728 | StdAcrossFolds(MAE)=4.7557
#       Worst DBP: MAE=5.5507 | StdAcrossFolds(MAE)=1.4526
#
# --------------------------------------------------------------------------------
# [TrainDur = 5 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=372 segs (~62.00 min)
#     [Fold 1] SBP MAE=2.3469, SD=2.8028 | DBP MAE=1.5657, SD=1.4385 | elapsed=2.8s
#     [Fold 2] SBP MAE=6.1591, SD=4.2063 | DBP MAE=3.1219, SD=1.7844 | elapsed=2.7s
#     [Fold 3] SBP MAE=10.4607, SD=3.4375 | DBP MAE=4.3793, SD=1.1813 | elapsed=2.7s
#     [Fold 4] SBP MAE=6.0461, SD=2.9684 | DBP MAE=1.3234, SD=1.6127 | elapsed=3.0s
#     [Fold 5] SBP MAE=13.0898, SD=11.2406 | DBP MAE=6.4188, SD=4.4091 | elapsed=3.2s
#   --- SUMMARY TrainDur=5m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=7.6205 | SD=4.9311
#       Avg   DBP: MAE=3.3618 | SD=2.0852
#       Worst SBP: MAE=13.0898 | StdAcrossFolds(MAE)=3.7525
#       Worst DBP: MAE=6.4188 | StdAcrossFolds(MAE)=1.8878
#
#   >>> BlockGap=3m | FoldLen=358 segs (~59.67 min)
#     [Fold 1] SBP MAE=1.8949, SD=2.3513 | DBP MAE=1.4780, SD=0.9860 | elapsed=2.6s
#     [Fold 2] SBP MAE=5.1686, SD=4.0927 | DBP MAE=2.4406, SD=1.7331 | elapsed=2.6s
#     [Fold 3] SBP MAE=9.5980, SD=3.8968 | DBP MAE=3.7695, SD=1.7062 | elapsed=2.6s
#     [Fold 4] SBP MAE=5.8579, SD=3.1292 | DBP MAE=1.3632, SD=1.5950 | elapsed=3.4s
#     [Fold 5] SBP MAE=33.4356, SD=8.9236 | DBP MAE=8.6963, SD=2.7829 | elapsed=2.7s
#   --- SUMMARY TrainDur=5m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=11.1910 | SD=4.4787
#       Avg   DBP: MAE=3.5495 | SD=1.7607
#       Worst SBP: MAE=33.4356 | StdAcrossFolds(MAE)=11.3885
#       Worst DBP: MAE=8.6963 | StdAcrossFolds(MAE)=2.7144
#
#   >>> BlockGap=5m | FoldLen=348 segs (~58.00 min)
#     [Fold 1] SBP MAE=2.5021, SD=2.9384 | DBP MAE=1.9158, SD=1.3673 | elapsed=2.7s
#     [Fold 2] SBP MAE=6.6508, SD=4.0611 | DBP MAE=3.7761, SD=1.6682 | elapsed=2.7s
#     [Fold 3] SBP MAE=7.1676, SD=4.7635 | DBP MAE=2.3093, SD=1.8976 | elapsed=3.1s
#     [Fold 4] SBP MAE=5.4886, SD=2.8644 | DBP MAE=1.4518, SD=1.5129 | elapsed=2.9s
#     [Fold 5] SBP MAE=11.2026, SD=10.9883 | DBP MAE=5.1212, SD=4.3599 | elapsed=2.7s
#   --- SUMMARY TrainDur=5m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=6.6023 | SD=5.1231
#       Avg   DBP: MAE=2.9149 | SD=2.1612
#       Worst SBP: MAE=11.2026 | StdAcrossFolds(MAE)=2.8120
#       Worst DBP: MAE=5.1212 | StdAcrossFolds(MAE)=1.3502
#
#   >>> BlockGap=10m | FoldLen=324 segs (~54.00 min)
#     [Fold 1] SBP MAE=3.9815, SD=4.1345 | DBP MAE=2.2180, SD=1.8676 | elapsed=2.7s
#     [Fold 2] SBP MAE=5.5119, SD=4.2728 | DBP MAE=4.1939, SD=1.6907 | elapsed=2.8s
#     [Fold 3] SBP MAE=6.3961, SD=4.4340 | DBP MAE=4.9573, SD=5.6297 | elapsed=3.2s
#     [Fold 4] SBP MAE=3.3452, SD=2.0964 | DBP MAE=1.5947, SD=1.0147 | elapsed=2.7s
#     [Fold 5] SBP MAE=20.2433, SD=13.0031 | DBP MAE=8.4116, SD=4.6855 | elapsed=2.6s
#   --- SUMMARY TrainDur=5m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=7.8956 | SD=5.5881
#       Avg   DBP: MAE=4.2751 | SD=2.9776
#       Worst SBP: MAE=20.2433 | StdAcrossFolds(MAE)=6.2678
#       Worst DBP: MAE=8.4116 | StdAcrossFolds(MAE)=2.4083
#
# --------------------------------------------------------------------------------
# [TrainDur = 10 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=372 segs (~62.00 min)
#     [Fold 1] SBP MAE=1.9581, SD=2.4469 | DBP MAE=2.1909, SD=1.4829 | elapsed=5.1s
#     [Fold 2] SBP MAE=3.4033, SD=4.3675 | DBP MAE=1.8815, SD=2.1026 | elapsed=5.0s
#     [Fold 3] SBP MAE=11.1210, SD=3.9249 | DBP MAE=1.5113, SD=1.8050 | elapsed=4.6s
#     [Fold 4] SBP MAE=6.1090, SD=2.6883 | DBP MAE=1.3036, SD=1.4478 | elapsed=5.5s
#     [Fold 5] SBP MAE=14.5368, SD=10.4037 | DBP MAE=6.3895, SD=5.3691 | elapsed=4.6s
#   --- SUMMARY TrainDur=10m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=7.4256 | SD=4.7663
#       Avg   DBP: MAE=2.6554 | SD=2.4415
#       Worst SBP: MAE=14.5368 | StdAcrossFolds(MAE)=4.7335
#       Worst DBP: MAE=6.3895 | StdAcrossFolds(MAE)=1.8918
#
#   >>> BlockGap=3m | FoldLen=358 segs (~59.67 min)
#     [Fold 1] SBP MAE=1.7389, SD=2.2713 | DBP MAE=1.3844, SD=1.0611 | elapsed=4.8s
#     [Fold 2] SBP MAE=5.6338, SD=4.6168 | DBP MAE=3.7620, SD=2.2403 | elapsed=5.3s
#     [Fold 3] SBP MAE=11.2680, SD=3.8999 | DBP MAE=1.6948, SD=2.0305 | elapsed=4.6s
#     [Fold 4] SBP MAE=5.5947, SD=2.4673 | DBP MAE=1.2153, SD=1.3341 | elapsed=5.6s
#     [Fold 5] SBP MAE=18.5780, SD=8.5961 | DBP MAE=9.8778, SD=5.0098 | elapsed=4.7s
#   --- SUMMARY TrainDur=10m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=8.5627 | SD=4.3703
#       Avg   DBP: MAE=3.5869 | SD=2.3352
#       Worst SBP: MAE=18.5780 | StdAcrossFolds(MAE)=5.8579
#       Worst DBP: MAE=9.8778 | StdAcrossFolds(MAE)=3.2760
#
#   >>> BlockGap=5m | FoldLen=348 segs (~58.00 min)
#     [Fold 1] SBP MAE=3.1555, SD=3.1393 | DBP MAE=2.0988, SD=1.5427 | elapsed=4.6s
#     [Fold 2] SBP MAE=6.5836, SD=3.7714 | DBP MAE=4.5504, SD=1.6065 | elapsed=5.5s
#     [Fold 3] SBP MAE=7.2919, SD=6.1826 | DBP MAE=7.9991, SD=7.6467 | elapsed=4.6s
#     [Fold 4] SBP MAE=4.2776, SD=2.6318 | DBP MAE=1.5605, SD=1.2948 | elapsed=5.6s
#     [Fold 5] SBP MAE=15.5629, SD=10.2809 | DBP MAE=7.4242, SD=4.8202 | elapsed=4.6s
#   --- SUMMARY TrainDur=10m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=7.3743 | SD=5.2012
#       Avg   DBP: MAE=4.7266 | SD=3.3822
#       Worst SBP: MAE=15.5629 | StdAcrossFolds(MAE)=4.3606
#       Worst DBP: MAE=7.9991 | StdAcrossFolds(MAE)=2.6438
#
#   >>> BlockGap=10m | FoldLen=324 segs (~54.00 min)
#     [Fold 1] SBP MAE=3.8951, SD=4.3381 | DBP MAE=2.1214, SD=2.0667 | elapsed=4.6s
#     [Fold 2] SBP MAE=8.3736, SD=3.1690 | DBP MAE=5.2290, SD=1.3247 | elapsed=5.5s
#     [Fold 3] SBP MAE=7.2860, SD=4.4502 | DBP MAE=15.7061, SD=7.6963 | elapsed=4.6s
#     [Fold 4] SBP MAE=2.4469, SD=3.0757 | DBP MAE=3.2870, SD=1.2820 | elapsed=5.3s
#     [Fold 5] SBP MAE=13.4451, SD=10.9878 | DBP MAE=5.8211, SD=6.0657 | elapsed=4.8s
#   --- SUMMARY TrainDur=10m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=7.0893 | SD=5.2042
#       Avg   DBP: MAE=6.4329 | SD=3.6871
#       Worst SBP: MAE=13.4451 | StdAcrossFolds(MAE)=3.8429
#       Worst DBP: MAE=15.7061 | StdAcrossFolds(MAE)=4.8229
#
# --------------------------------------------------------------------------------
# [TrainDur = 15 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=372 segs (~62.00 min)
#     [Fold 1] SBP MAE=3.0477, SD=2.4892 | DBP MAE=2.8001, SD=1.4638 | elapsed=7.5s
#     [Fold 2] SBP MAE=3.2388, SD=3.4217 | DBP MAE=3.2152, SD=1.5532 | elapsed=7.2s
#     [Fold 3] SBP MAE=7.4948, SD=5.0715 | DBP MAE=3.8227, SD=5.0684 | elapsed=7.8s
#     [Fold 4] SBP MAE=4.9495, SD=2.9843 | DBP MAE=1.3738, SD=1.9008 | elapsed=7.0s
#     [Fold 5] SBP MAE=14.2208, SD=9.2041 | DBP MAE=8.6024, SD=5.2518 | elapsed=7.8s
#   --- SUMMARY TrainDur=15m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=6.5903 | SD=4.6342
#       Avg   DBP: MAE=3.9629 | SD=3.0476
#       Worst SBP: MAE=14.2208 | StdAcrossFolds(MAE)=4.1356
#       Worst DBP: MAE=8.6024 | StdAcrossFolds(MAE)=2.4560
#
#   >>> BlockGap=3m | FoldLen=358 segs (~59.67 min)
#     [Fold 1] SBP MAE=1.9544, SD=2.5397 | DBP MAE=1.3067, SD=1.1987 | elapsed=7.0s
#     [Fold 2] SBP MAE=7.6538, SD=3.3636 | DBP MAE=4.9614, SD=1.6631 | elapsed=7.7s
#     [Fold 3] SBP MAE=9.3762, SD=6.7573 | DBP MAE=11.1644, SD=6.5046 | elapsed=7.7s
#     [Fold 4] SBP MAE=3.7595, SD=2.9436 | DBP MAE=1.7498, SD=2.1252 | elapsed=6.9s
#     [Fold 5] SBP MAE=16.9289, SD=8.7698 | DBP MAE=10.0747, SD=5.0410 | elapsed=7.8s
#   --- SUMMARY TrainDur=15m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=7.9346 | SD=4.8748
#       Avg   DBP: MAE=5.8514 | SD=3.3065
#       Worst SBP: MAE=16.9289 | StdAcrossFolds(MAE)=5.2201
#       Worst DBP: MAE=11.1644 | StdAcrossFolds(MAE)=4.1069
#
#   >>> BlockGap=5m | FoldLen=348 segs (~58.00 min)
#     [Fold 1] SBP MAE=2.1564, SD=2.6133 | DBP MAE=1.1332, SD=1.2892 | elapsed=6.9s
#     [Fold 2] SBP MAE=6.3725, SD=3.5307 | DBP MAE=4.8538, SD=1.2812 | elapsed=7.8s
#     [Fold 3] SBP MAE=9.7069, SD=7.5371 | DBP MAE=6.5986, SD=6.1736 | elapsed=7.2s
#     [Fold 4] SBP MAE=3.5625, SD=3.0250 | DBP MAE=1.7080, SD=2.0544 | elapsed=7.5s
#     [Fold 5] SBP MAE=13.6071, SD=10.2069 | DBP MAE=6.7951, SD=5.7035 | elapsed=7.8s
#   --- SUMMARY TrainDur=15m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=7.0811 | SD=5.3826
#       Avg   DBP: MAE=4.2177 | SD=3.3004
#       Worst SBP: MAE=13.6071 | StdAcrossFolds(MAE)=4.1622
#       Worst DBP: MAE=6.7951 | StdAcrossFolds(MAE)=2.3887
#
#   >>> BlockGap=10m | FoldLen=324 segs (~54.00 min)
#     [Fold 1] SBP MAE=2.8935, SD=2.9719 | DBP MAE=1.5602, SD=1.5041 | elapsed=6.9s
#     [Fold 2] SBP MAE=5.5454, SD=3.1542 | DBP MAE=3.6410, SD=1.4646 | elapsed=7.8s
#     [Fold 3] SBP MAE=5.1892, SD=6.3918 | DBP MAE=12.0598, SD=6.5563 | elapsed=6.9s
#     [Fold 4] SBP MAE=3.0775, SD=3.2819 | DBP MAE=1.6262, SD=1.7536 | elapsed=7.8s
#     [Fold 5] SBP MAE=21.4833, SD=10.2014 | DBP MAE=11.7012, SD=8.1745 | elapsed=7.6s
#   --- SUMMARY TrainDur=15m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=7.6378 | SD=5.2002
#       Avg   DBP: MAE=6.1177 | SD=3.8906
#       Worst SBP: MAE=21.4833 | StdAcrossFolds(MAE)=7.0054
#       Worst DBP: MAE=12.0598 | StdAcrossFolds(MAE)=4.7658
#
# --------------------------------------------------------------------------------
# [3/10] START p004833.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p004833.mat | filtering=False
# ================================================================================
# ✅ (NoFilter) kept: 2506 / 2506
# [Data Ready] total_len=2506
#
# --------------------------------------------------------------------------------
# [TrainDur = 3 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=501 segs (~83.50 min)
#     [Fold 1] SBP MAE=7.4628, SD=5.6061 | DBP MAE=3.3409, SD=3.8592 | elapsed=1.9s
#     [Fold 2] SBP MAE=3.9942, SD=4.5372 | DBP MAE=1.0265, SD=1.5752 | elapsed=2.3s
#     [Fold 3] SBP MAE=2.3109, SD=2.7467 | DBP MAE=0.9337, SD=1.0783 | elapsed=2.3s
#     [Fold 4] SBP MAE=5.2259, SD=6.2669 | DBP MAE=1.5386, SD=1.7286 | elapsed=1.8s
#     [Fold 5] SBP MAE=10.6718, SD=9.6391 | DBP MAE=3.9796, SD=6.9901 | elapsed=1.9s
#   --- SUMMARY TrainDur=3m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=5.9331 | SD=5.7592
#       Avg   DBP: MAE=2.1638 | SD=3.0463
#       Worst SBP: MAE=10.6718 | StdAcrossFolds(MAE)=2.9043
#       Worst DBP: MAE=3.9796 | StdAcrossFolds(MAE)=1.2554
#
#   >>> BlockGap=3m | FoldLen=486 segs (~81.00 min)
#     [Fold 1] SBP MAE=11.0394, SD=2.9918 | DBP MAE=6.8190, SD=1.3870 | elapsed=1.9s
#     [Fold 2] SBP MAE=3.0672, SD=4.5354 | DBP MAE=1.0751, SD=1.2728 | elapsed=1.9s
#     [Fold 3] SBP MAE=2.7478, SD=3.4583 | DBP MAE=1.0773, SD=1.4147 | elapsed=2.3s
#     [Fold 4] SBP MAE=6.0781, SD=6.2076 | DBP MAE=2.6386, SD=1.8540 | elapsed=2.3s
#     [Fold 5] SBP MAE=6.2029, SD=7.1907 | DBP MAE=2.9888, SD=4.3661 | elapsed=1.9s
#   --- SUMMARY TrainDur=3m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=5.8271 | SD=4.8768
#       Avg   DBP: MAE=2.9198 | SD=2.0589
#       Worst SBP: MAE=11.0394 | StdAcrossFolds(MAE)=2.9823
#       Worst DBP: MAE=6.8190 | StdAcrossFolds(MAE)=2.1017
#
#   >>> BlockGap=5m | FoldLen=477 segs (~79.50 min)
#     [Fold 1] SBP MAE=16.0294, SD=4.3332 | DBP MAE=6.1277, SD=1.3959 | elapsed=1.9s
#     [Fold 2] SBP MAE=3.8090, SD=5.7124 | DBP MAE=1.9664, SD=4.2432 | elapsed=1.9s
#     [Fold 3] SBP MAE=2.6069, SD=3.2884 | DBP MAE=0.9087, SD=1.0662 | elapsed=1.9s
#     [Fold 4] SBP MAE=5.2112, SD=6.3903 | DBP MAE=2.0081, SD=2.0056 | elapsed=2.3s
#     [Fold 5] SBP MAE=10.3297, SD=10.2857 | DBP MAE=3.9562, SD=7.3101 | elapsed=2.3s
#   --- SUMMARY TrainDur=3m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=7.5972 | SD=6.0020
#       Avg   DBP: MAE=2.9934 | SD=3.2042
#       Worst SBP: MAE=16.0294 | StdAcrossFolds(MAE)=4.9702
#       Worst DBP: MAE=6.1277 | StdAcrossFolds(MAE)=1.8505
#
#   >>> BlockGap=10m | FoldLen=453 segs (~75.50 min)
#     [Fold 1] SBP MAE=15.9330, SD=6.3779 | DBP MAE=7.8380, SD=5.2073 | elapsed=1.8s
#     [Fold 2] SBP MAE=6.9611, SD=6.1045 | DBP MAE=2.3441, SD=4.2223 | elapsed=1.8s
#     [Fold 3] SBP MAE=2.1281, SD=2.4851 | DBP MAE=1.0268, SD=1.3433 | elapsed=1.9s
#     [Fold 4] SBP MAE=4.2066, SD=5.3820 | DBP MAE=1.9677, SD=2.3660 | elapsed=1.9s
#     [Fold 5] SBP MAE=11.6181, SD=9.2702 | DBP MAE=4.4170, SD=6.7812 | elapsed=2.1s
#   --- SUMMARY TrainDur=3m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=8.1694 | SD=5.9239
#       Avg   DBP: MAE=3.5187 | SD=3.9840
#       Worst SBP: MAE=15.9330 | StdAcrossFolds(MAE)=5.0165
#       Worst DBP: MAE=7.8380 | StdAcrossFolds(MAE)=2.4273
#
# --------------------------------------------------------------------------------
# [TrainDur = 5 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=501 segs (~83.50 min)
#     [Fold 1] SBP MAE=10.1879, SD=5.9682 | DBP MAE=4.0907, SD=3.4770 | elapsed=3.2s
#     [Fold 2] SBP MAE=2.9274, SD=3.7963 | DBP MAE=1.1226, SD=1.4947 | elapsed=2.7s
#     [Fold 3] SBP MAE=2.0937, SD=2.5977 | DBP MAE=0.7821, SD=0.9806 | elapsed=2.7s
#     [Fold 4] SBP MAE=3.6492, SD=4.7728 | DBP MAE=1.7999, SD=1.7963 | elapsed=2.7s
#     [Fold 5] SBP MAE=5.6388, SD=8.1959 | DBP MAE=5.5322, SD=6.2213 | elapsed=3.5s
#   --- SUMMARY TrainDur=5m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=4.8994 | SD=5.0662
#       Avg   DBP: MAE=2.6655 | SD=2.7940
#       Worst SBP: MAE=10.1879 | StdAcrossFolds(MAE)=2.8927
#       Worst DBP: MAE=5.5322 | StdAcrossFolds(MAE)=1.8399
#
#   >>> BlockGap=3m | FoldLen=486 segs (~81.00 min)
#     [Fold 1] SBP MAE=14.3777, SD=3.1246 | DBP MAE=6.1470, SD=1.1786 | elapsed=2.7s
#     [Fold 2] SBP MAE=3.2160, SD=3.9109 | DBP MAE=0.8166, SD=1.0028 | elapsed=2.7s
#     [Fold 3] SBP MAE=2.4566, SD=2.9755 | DBP MAE=0.7467, SD=0.9186 | elapsed=2.7s
#     [Fold 4] SBP MAE=4.2629, SD=6.1499 | DBP MAE=1.9100, SD=2.2864 | elapsed=3.2s
#     [Fold 5] SBP MAE=6.5086, SD=5.5756 | DBP MAE=6.6135, SD=4.0073 | elapsed=2.9s
#   --- SUMMARY TrainDur=5m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=6.1644 | SD=4.3473
#       Avg   DBP: MAE=3.2468 | SD=1.8787
#       Worst SBP: MAE=14.3777 | StdAcrossFolds(MAE)=4.3274
#       Worst DBP: MAE=6.6135 | StdAcrossFolds(MAE)=2.5958
#
#   >>> BlockGap=5m | FoldLen=477 segs (~79.50 min)
#     [Fold 1] SBP MAE=15.7778, SD=3.3674 | DBP MAE=6.8330, SD=1.1104 | elapsed=2.7s
#     [Fold 2] SBP MAE=4.0459, SD=5.6980 | DBP MAE=1.8363, SD=3.8333 | elapsed=2.7s
#     [Fold 3] SBP MAE=2.4612, SD=2.7074 | DBP MAE=1.0407, SD=1.0510 | elapsed=2.9s
#     [Fold 4] SBP MAE=3.7141, SD=6.0374 | DBP MAE=1.1604, SD=1.4259 | elapsed=3.3s
#     [Fold 5] SBP MAE=5.8568, SD=8.2364 | DBP MAE=6.2872, SD=6.0769 | elapsed=2.7s
#   --- SUMMARY TrainDur=5m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=6.3711 | SD=5.2093
#       Avg   DBP: MAE=3.4315 | SD=2.6995
#       Worst SBP: MAE=15.7778 | StdAcrossFolds(MAE)=4.8271
#       Worst DBP: MAE=6.8330 | StdAcrossFolds(MAE)=2.5746
#
#   >>> BlockGap=10m | FoldLen=453 segs (~75.50 min)
#     [Fold 1] SBP MAE=17.9942, SD=7.7848 | DBP MAE=5.9608, SD=3.7175 | elapsed=2.7s
#     [Fold 2] SBP MAE=10.3423, SD=5.9353 | DBP MAE=2.1750, SD=4.2467 | elapsed=2.6s
#     [Fold 3] SBP MAE=2.8269, SD=2.5581 | DBP MAE=1.1236, SD=1.4142 | elapsed=3.5s
#     [Fold 4] SBP MAE=4.5043, SD=6.2202 | DBP MAE=1.2656, SD=1.3674 | elapsed=2.7s
#     [Fold 5] SBP MAE=7.1152, SD=8.4959 | DBP MAE=6.6450, SD=6.2523 | elapsed=2.7s
#   --- SUMMARY TrainDur=5m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=8.5566 | SD=6.1989
#       Avg   DBP: MAE=3.4340 | SD=3.3996
#       Worst SBP: MAE=17.9942 | StdAcrossFolds(MAE)=5.3588
#       Worst DBP: MAE=6.6450 | StdAcrossFolds(MAE)=2.3799
#
# --------------------------------------------------------------------------------
# [TrainDur = 10 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=501 segs (~83.50 min)
#     [Fold 1] SBP MAE=10.0213, SD=4.5451 | DBP MAE=3.6292, SD=2.3414 | elapsed=4.9s
#     [Fold 2] SBP MAE=2.4342, SD=3.2710 | DBP MAE=0.9124, SD=1.3176 | elapsed=5.4s
#     [Fold 3] SBP MAE=2.6454, SD=2.2987 | DBP MAE=0.7138, SD=0.7716 | elapsed=4.6s
#     [Fold 4] SBP MAE=2.6405, SD=4.1791 | DBP MAE=0.9559, SD=1.0034 | elapsed=5.6s
#     [Fold 5] SBP MAE=10.1162, SD=8.2750 | DBP MAE=7.6402, SD=7.1169 | elapsed=4.6s
#   --- SUMMARY TrainDur=10m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=5.5715 | SD=4.5138
#       Avg   DBP: MAE=2.7703 | SD=2.5102
#       Worst SBP: MAE=10.1162 | StdAcrossFolds(MAE)=3.6729
#       Worst DBP: MAE=7.6402 | StdAcrossFolds(MAE)=2.6618
#
#   >>> BlockGap=3m | FoldLen=486 segs (~81.00 min)
#     [Fold 1] SBP MAE=16.6937, SD=2.9829 | DBP MAE=4.3962, SD=1.3564 | elapsed=4.7s
#     [Fold 2] SBP MAE=2.4932, SD=3.9729 | DBP MAE=0.9152, SD=1.2310 | elapsed=5.4s
#     [Fold 3] SBP MAE=2.3025, SD=2.4357 | DBP MAE=0.6671, SD=0.7749 | elapsed=4.7s
#     [Fold 4] SBP MAE=3.2500, SD=4.6405 | DBP MAE=1.6831, SD=1.0367 | elapsed=5.6s
#     [Fold 5] SBP MAE=10.2902, SD=6.0603 | DBP MAE=3.9177, SD=4.4571 | elapsed=4.7s
#   --- SUMMARY TrainDur=10m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=7.0059 | SD=4.0185
#       Avg   DBP: MAE=2.3159 | SD=1.7712
#       Worst SBP: MAE=16.6937 | StdAcrossFolds(MAE)=5.6786
#       Worst DBP: MAE=4.3962 | StdAcrossFolds(MAE)=1.5475
#
#   >>> BlockGap=5m | FoldLen=477 segs (~79.50 min)
#     [Fold 1] SBP MAE=17.9131, SD=4.4418 | DBP MAE=5.4673, SD=1.6101 | elapsed=4.7s
#     [Fold 2] SBP MAE=4.3610, SD=5.3496 | DBP MAE=1.7193, SD=3.9467 | elapsed=5.6s
#     [Fold 3] SBP MAE=1.9758, SD=2.4714 | DBP MAE=0.8179, SD=0.8447 | elapsed=4.7s
#     [Fold 4] SBP MAE=3.7774, SD=5.8211 | DBP MAE=1.1797, SD=1.1145 | elapsed=5.7s
#     [Fold 5] SBP MAE=9.8655, SD=9.2398 | DBP MAE=7.1942, SD=7.0634 | elapsed=4.6s
#   --- SUMMARY TrainDur=10m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=7.5786 | SD=5.4647
#       Avg   DBP: MAE=3.2757 | SD=2.9159
#       Worst SBP: MAE=17.9131 | StdAcrossFolds(MAE)=5.8004
#       Worst DBP: MAE=7.1942 | StdAcrossFolds(MAE)=2.5696
#
#   >>> BlockGap=10m | FoldLen=453 segs (~75.50 min)
#     [Fold 1] SBP MAE=20.1567, SD=8.0833 | DBP MAE=5.2510, SD=3.8318 | elapsed=4.6s
#     [Fold 2] SBP MAE=9.5326, SD=6.1458 | DBP MAE=3.0036, SD=4.5764 | elapsed=5.7s
#     [Fold 3] SBP MAE=2.2237, SD=1.7505 | DBP MAE=0.7101, SD=0.8567 | elapsed=4.7s
#     [Fold 4] SBP MAE=3.5645, SD=5.2597 | DBP MAE=1.2098, SD=1.2703 | elapsed=5.6s
#     [Fold 5] SBP MAE=11.0735, SD=8.5423 | DBP MAE=7.6186, SD=7.3601 | elapsed=4.8s
#   --- SUMMARY TrainDur=10m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=9.3102 | SD=5.9563
#       Avg   DBP: MAE=3.5586 | SD=3.5791
#       Worst SBP: MAE=20.1567 | StdAcrossFolds(MAE)=6.3880
#       Worst DBP: MAE=7.6186 | StdAcrossFolds(MAE)=2.5802
#
# --------------------------------------------------------------------------------
# [TrainDur = 15 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=501 segs (~83.50 min)
#     [Fold 1] SBP MAE=9.5182, SD=5.4543 | DBP MAE=3.7445, SD=2.2281 | elapsed=7.8s
#     [Fold 2] SBP MAE=2.6119, SD=3.1352 | DBP MAE=0.8699, SD=1.4233 | elapsed=7.1s
#     [Fold 3] SBP MAE=2.4687, SD=2.0754 | DBP MAE=0.8445, SD=0.9089 | elapsed=7.9s
#     [Fold 4] SBP MAE=3.0145, SD=4.4349 | DBP MAE=0.9118, SD=0.9825 | elapsed=7.0s
#     [Fold 5] SBP MAE=11.7657, SD=9.8857 | DBP MAE=7.3710, SD=7.2860 | elapsed=7.9s
#   --- SUMMARY TrainDur=15m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=5.8758 | SD=4.9971
#       Avg   DBP: MAE=2.7484 | SD=2.5658
#       Worst SBP: MAE=11.7657 | StdAcrossFolds(MAE)=3.9600
#       Worst DBP: MAE=7.3710 | StdAcrossFolds(MAE)=2.5647
#
#   >>> BlockGap=3m | FoldLen=486 segs (~81.00 min)
#     [Fold 1] SBP MAE=15.8669, SD=3.6092 | DBP MAE=6.1716, SD=1.7949 | elapsed=7.5s
#     [Fold 2] SBP MAE=2.8132, SD=3.6980 | DBP MAE=0.8977, SD=1.0003 | elapsed=7.4s
#     [Fold 3] SBP MAE=2.0492, SD=2.1349 | DBP MAE=0.6884, SD=0.8215 | elapsed=7.9s
#     [Fold 4] SBP MAE=3.6571, SD=5.5307 | DBP MAE=1.2345, SD=1.0881 | elapsed=7.0s
#     [Fold 5] SBP MAE=11.8285, SD=6.2189 | DBP MAE=8.1681, SD=4.2445 | elapsed=7.9s
#   --- SUMMARY TrainDur=15m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=7.2430 | SD=4.2383
#       Avg   DBP: MAE=3.4321 | SD=1.7899
#       Worst SBP: MAE=15.8669 | StdAcrossFolds(MAE)=5.5652
#       Worst DBP: MAE=8.1681 | StdAcrossFolds(MAE)=3.1214
#
#   >>> BlockGap=5m | FoldLen=477 segs (~79.50 min)
#     [Fold 1] SBP MAE=19.4832, SD=4.6128 | DBP MAE=5.3166, SD=2.0700 | elapsed=7.1s
#     [Fold 2] SBP MAE=5.5500, SD=5.6259 | DBP MAE=1.8599, SD=4.1510 | elapsed=7.7s
#     [Fold 3] SBP MAE=2.7299, SD=2.8303 | DBP MAE=0.7723, SD=0.7238 | elapsed=8.0s
#     [Fold 4] SBP MAE=3.8680, SD=5.5586 | DBP MAE=1.1264, SD=1.2859 | elapsed=7.0s
#     [Fold 5] SBP MAE=9.7458, SD=7.6077 | DBP MAE=7.1624, SD=7.4466 | elapsed=7.9s
#   --- SUMMARY TrainDur=15m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=8.2754 | SD=5.2471
#       Avg   DBP: MAE=3.2475 | SD=3.1355
#       Worst SBP: MAE=19.4832 | StdAcrossFolds(MAE)=6.0890
#       Worst DBP: MAE=7.1624 | StdAcrossFolds(MAE)=2.5361
#
#   >>> BlockGap=10m | FoldLen=453 segs (~75.50 min)
#     [Fold 1] SBP MAE=20.1557, SD=7.4179 | DBP MAE=5.6965, SD=4.0965 | elapsed=7.0s
#     [Fold 2] SBP MAE=8.7152, SD=5.6817 | DBP MAE=2.3305, SD=4.2436 | elapsed=7.9s
#     [Fold 3] SBP MAE=2.5010, SD=2.0602 | DBP MAE=0.6320, SD=0.7313 | elapsed=7.6s
#     [Fold 4] SBP MAE=3.8084, SD=5.7453 | DBP MAE=1.1190, SD=1.2911 | elapsed=7.3s
#     [Fold 5] SBP MAE=16.1564, SD=8.5419 | DBP MAE=6.9259, SD=7.8183 | elapsed=7.8s
#   --- SUMMARY TrainDur=15m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=10.2674 | SD=5.8894
#       Avg   DBP: MAE=3.3408 | SD=3.6361
#       Worst SBP: MAE=20.1557 | StdAcrossFolds(MAE)=6.8834
#       Worst DBP: MAE=6.9259 | StdAcrossFolds(MAE)=2.5178
#
# --------------------------------------------------------------------------------
# [4/10] START p009993.mat | filtering=False
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p009993.mat | filtering=False
# ================================================================================
# ✅ (NoFilter) kept: 2050 / 2050
# [Data Ready] total_len=2050
#
# --------------------------------------------------------------------------------
# [TrainDur = 3 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=410 segs (~68.33 min)
#     [Fold 1] SBP MAE=8.7928, SD=1.8433 | DBP MAE=4.4202, SD=1.6754 | elapsed=1.8s
#     [Fold 2] SBP MAE=15.0493, SD=10.1488 | DBP MAE=25.0733, SD=2.5621 | elapsed=2.6s
#     [Fold 3] SBP MAE=10.3714, SD=9.3470 | DBP MAE=3.0261, SD=3.1501 | elapsed=2.0s
#     [Fold 4] SBP MAE=7.8869, SD=10.6518 | DBP MAE=6.7997, SD=3.3044 | elapsed=1.8s
#     [Fold 5] SBP MAE=4.0783, SD=3.6357 | DBP MAE=1.4367, SD=1.6149 | elapsed=1.8s
#   --- SUMMARY TrainDur=3m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=9.2357 | SD=7.1253
#       Avg   DBP: MAE=8.1512 | SD=2.4614
#       Worst SBP: MAE=15.0493 | StdAcrossFolds(MAE)=3.5693
#       Worst DBP: MAE=25.0733 | StdAcrossFolds(MAE)=8.6424
#
#   >>> BlockGap=3m | FoldLen=395 segs (~65.83 min)
#     [Fold 1] SBP MAE=3.0247, SD=1.7516 | DBP MAE=0.6987, SD=0.8716 | elapsed=1.8s
#     [Fold 2] SBP MAE=17.6526, SD=10.4233 | DBP MAE=23.0901, SD=2.3746 | elapsed=1.8s
#     [Fold 3] SBP MAE=10.2599, SD=7.7459 | DBP MAE=3.6147, SD=2.3234 | elapsed=2.4s
#     [Fold 4] SBP MAE=7.7918, SD=9.5549 | DBP MAE=6.1721, SD=3.7961 | elapsed=2.2s
#     [Fold 5] SBP MAE=6.2572, SD=3.6458 | DBP MAE=1.8481, SD=1.6805 | elapsed=1.8s
#   --- SUMMARY TrainDur=3m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=8.9972 | SD=6.6243
#       Avg   DBP: MAE=7.0847 | SD=2.2092
#       Worst SBP: MAE=17.6526 | StdAcrossFolds(MAE)=4.9222
#       Worst DBP: MAE=23.0901 | StdAcrossFolds(MAE)=8.2128
#
#   >>> BlockGap=5m | FoldLen=386 segs (~64.33 min)
#     [Fold 1] SBP MAE=2.8445, SD=3.7287 | DBP MAE=0.9173, SD=1.0596 | elapsed=1.8s
#     [Fold 2] SBP MAE=14.4575, SD=12.0432 | DBP MAE=21.3338, SD=4.6201 | elapsed=1.8s
#     [Fold 3] SBP MAE=9.8579, SD=6.6793 | DBP MAE=3.0591, SD=2.1889 | elapsed=1.9s
#     [Fold 4] SBP MAE=8.1392, SD=9.9920 | DBP MAE=6.0315, SD=3.7035 | elapsed=2.3s
#     [Fold 5] SBP MAE=3.8774, SD=3.6379 | DBP MAE=1.4113, SD=1.5763 | elapsed=2.2s
#   --- SUMMARY TrainDur=3m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=7.8353 | SD=7.2162
#       Avg   DBP: MAE=6.5506 | SD=2.6297
#       Worst SBP: MAE=14.4575 | StdAcrossFolds(MAE)=4.2097
#       Worst DBP: MAE=21.3338 | StdAcrossFolds(MAE)=7.6046
#
#   >>> BlockGap=10m | FoldLen=362 segs (~60.33 min)
#     [Fold 1] SBP MAE=6.4680, SD=4.6666 | DBP MAE=2.8466, SD=1.4394 | elapsed=1.8s
#     [Fold 2] SBP MAE=6.0886, SD=8.6997 | DBP MAE=12.4262, SD=13.9177 | elapsed=1.8s
#     [Fold 3] SBP MAE=8.2012, SD=6.3834 | DBP MAE=2.6819, SD=1.9131 | elapsed=1.8s
#     [Fold 4] SBP MAE=6.6878, SD=8.4082 | DBP MAE=4.2318, SD=4.1161 | elapsed=1.9s
#     [Fold 5] SBP MAE=3.7579, SD=3.6555 | DBP MAE=1.3916, SD=1.5644 | elapsed=2.1s
#   --- SUMMARY TrainDur=3m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=6.2407 | SD=6.3627
#       Avg   DBP: MAE=4.7156 | SD=4.5901
#       Worst SBP: MAE=8.2012 | StdAcrossFolds(MAE)=1.4341
#       Worst DBP: MAE=12.4262 | StdAcrossFolds(MAE)=3.9589
#
# --------------------------------------------------------------------------------
# [TrainDur = 5 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=410 segs (~68.33 min)
#     [Fold 1] SBP MAE=5.3856, SD=1.8804 | DBP MAE=4.7825, SD=1.6250 | elapsed=3.1s
#     [Fold 2] SBP MAE=13.8965, SD=9.8463 | DBP MAE=25.9370, SD=2.8738 | elapsed=2.7s
#     [Fold 3] SBP MAE=10.4775, SD=8.8379 | DBP MAE=3.3944, SD=3.0047 | elapsed=2.6s
#     [Fold 4] SBP MAE=8.6196, SD=10.7581 | DBP MAE=6.0179, SD=3.3515 | elapsed=2.7s
#     [Fold 5] SBP MAE=5.5706, SD=4.1500 | DBP MAE=1.5807, SD=1.7574 | elapsed=3.4s
#   --- SUMMARY TrainDur=5m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=8.7900 | SD=7.0946
#       Avg   DBP: MAE=8.3425 | SD=2.5225
#       Worst SBP: MAE=13.8965 | StdAcrossFolds(MAE)=3.1909
#       Worst DBP: MAE=25.9370 | StdAcrossFolds(MAE)=8.9202
#
#   >>> BlockGap=3m | FoldLen=395 segs (~65.83 min)
#     [Fold 1] SBP MAE=3.9301, SD=2.0523 | DBP MAE=0.6998, SD=0.8672 | elapsed=2.7s
#     [Fold 2] SBP MAE=17.3501, SD=10.3828 | DBP MAE=22.0779, SD=2.4377 | elapsed=2.7s
#     [Fold 3] SBP MAE=8.9134, SD=6.6513 | DBP MAE=2.8728, SD=2.2365 | elapsed=2.7s
#     [Fold 4] SBP MAE=8.1446, SD=9.9810 | DBP MAE=5.3776, SD=3.7493 | elapsed=3.2s
#     [Fold 5] SBP MAE=5.7290, SD=3.7200 | DBP MAE=1.8707, SD=1.7341 | elapsed=2.9s
#   --- SUMMARY TrainDur=5m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=8.8135 | SD=6.5575
#       Avg   DBP: MAE=6.5798 | SD=2.2050
#       Worst SBP: MAE=17.3501 | StdAcrossFolds(MAE)=4.6194
#       Worst DBP: MAE=22.0779 | StdAcrossFolds(MAE)=7.9010
#
#   >>> BlockGap=5m | FoldLen=386 segs (~64.33 min)
#     [Fold 1] SBP MAE=3.9796, SD=2.6609 | DBP MAE=1.3505, SD=1.1570 | elapsed=2.7s
#     [Fold 2] SBP MAE=13.3693, SD=11.6732 | DBP MAE=21.3582, SD=4.6745 | elapsed=2.8s
#     [Fold 3] SBP MAE=9.9602, SD=6.7897 | DBP MAE=3.1102, SD=2.2206 | elapsed=2.9s
#     [Fold 4] SBP MAE=7.9666, SD=9.9099 | DBP MAE=5.4193, SD=3.6158 | elapsed=3.2s
#     [Fold 5] SBP MAE=4.9519, SD=3.9275 | DBP MAE=1.4914, SD=1.7194 | elapsed=2.7s
#   --- SUMMARY TrainDur=5m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=8.0455 | SD=6.9923
#       Avg   DBP: MAE=6.5459 | SD=2.6775
#       Worst SBP: MAE=13.3693 | StdAcrossFolds(MAE)=3.4093
#       Worst DBP: MAE=21.3582 | StdAcrossFolds(MAE)=7.5500
#
#   >>> BlockGap=10m | FoldLen=362 segs (~60.33 min)
#     [Fold 1] SBP MAE=5.3392, SD=4.5379 | DBP MAE=3.3869, SD=1.5480 | elapsed=2.7s
#     [Fold 2] SBP MAE=5.8758, SD=8.8920 | DBP MAE=12.3893, SD=13.8711 | elapsed=2.6s
#     [Fold 3] SBP MAE=6.8607, SD=6.2475 | DBP MAE=2.8157, SD=1.7119 | elapsed=3.3s
#     [Fold 4] SBP MAE=6.8423, SD=8.3132 | DBP MAE=4.3881, SD=4.0198 | elapsed=2.7s
#     [Fold 5] SBP MAE=5.1842, SD=3.7255 | DBP MAE=1.4541, SD=1.5768 | elapsed=2.7s
#   --- SUMMARY TrainDur=5m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=6.0205 | SD=6.3432
#       Avg   DBP: MAE=4.8868 | SD=4.5455
#       Worst SBP: MAE=6.8607 | StdAcrossFolds(MAE)=0.7163
#       Worst DBP: MAE=12.3893 | StdAcrossFolds(MAE)=3.8693
#
# --------------------------------------------------------------------------------
# [TrainDur = 10 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=410 segs (~68.33 min)
#     [Fold 1] SBP MAE=3.8958, SD=1.9456 | DBP MAE=2.5056, SD=1.6376 | elapsed=4.6s
#     [Fold 2] SBP MAE=10.2339, SD=9.4254 | DBP MAE=24.1990, SD=2.6870 | elapsed=5.5s
#     [Fold 3] SBP MAE=11.0680, SD=10.7550 | DBP MAE=3.6498, SD=3.5723 | elapsed=4.6s
#     [Fold 4] SBP MAE=8.0704, SD=9.5801 | DBP MAE=5.5107, SD=3.0092 | elapsed=5.6s
#     [Fold 5] SBP MAE=4.7615, SD=3.9836 | DBP MAE=1.4084, SD=1.6125 | elapsed=4.6s
#   --- SUMMARY TrainDur=10m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=7.6059 | SD=7.1379
#       Avg   DBP: MAE=7.4547 | SD=2.5037
#       Worst SBP: MAE=11.0680 | StdAcrossFolds(MAE)=2.8623
#       Worst DBP: MAE=24.1990 | StdAcrossFolds(MAE)=8.4815
#
#   >>> BlockGap=3m | FoldLen=395 segs (~65.83 min)
#     [Fold 1] SBP MAE=5.1369, SD=2.2481 | DBP MAE=0.6719, SD=0.8570 | elapsed=4.6s
#     [Fold 2] SBP MAE=11.2046, SD=9.4512 | DBP MAE=24.5143, SD=2.6497 | elapsed=5.6s
#     [Fold 3] SBP MAE=9.9415, SD=5.9086 | DBP MAE=3.5494, SD=1.9311 | elapsed=4.6s
#     [Fold 4] SBP MAE=6.3685, SD=8.1373 | DBP MAE=5.4108, SD=3.5445 | elapsed=5.4s
#     [Fold 5] SBP MAE=7.1728, SD=4.1061 | DBP MAE=2.2239, SD=1.8641 | elapsed=4.7s
#   --- SUMMARY TrainDur=10m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=7.9648 | SD=5.9703
#       Avg   DBP: MAE=7.2740 | SD=2.1693
#       Worst SBP: MAE=11.2046 | StdAcrossFolds(MAE)=2.2617
#       Worst DBP: MAE=24.5143 | StdAcrossFolds(MAE)=8.7597
#
#   >>> BlockGap=5m | FoldLen=386 segs (~64.33 min)
#     [Fold 1] SBP MAE=3.1944, SD=3.2778 | DBP MAE=1.2371, SD=1.4063 | elapsed=4.6s
#     [Fold 2] SBP MAE=11.4920, SD=11.0651 | DBP MAE=22.3767, SD=4.9532 | elapsed=5.6s
#     [Fold 3] SBP MAE=11.6589, SD=6.2643 | DBP MAE=4.0905, SD=1.9805 | elapsed=4.7s
#     [Fold 4] SBP MAE=7.8389, SD=9.3131 | DBP MAE=4.9209, SD=3.4175 | elapsed=5.1s
#     [Fold 5] SBP MAE=5.3795, SD=3.7716 | DBP MAE=1.5324, SD=1.6237 | elapsed=5.0s
#   --- SUMMARY TrainDur=10m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=7.9128 | SD=6.7384
#       Avg   DBP: MAE=6.8315 | SD=2.6762
#       Worst SBP: MAE=11.6589 | StdAcrossFolds(MAE)=3.3326
#       Worst DBP: MAE=22.3767 | StdAcrossFolds(MAE)=7.9018
#
#   >>> BlockGap=10m | FoldLen=362 segs (~60.33 min)
#     [Fold 1] SBP MAE=6.6263, SD=5.4884 | DBP MAE=3.0236, SD=1.5568 | elapsed=4.6s
#     [Fold 2] SBP MAE=5.8584, SD=8.8370 | DBP MAE=12.5139, SD=13.8748 | elapsed=5.5s
#     [Fold 3] SBP MAE=9.7548, SD=6.3557 | DBP MAE=3.7191, SD=1.9073 | elapsed=4.6s
# ...
#       Avg   SBP: MAE=6.7426 | SD=2.1770
#       Avg   DBP: MAE=3.0674 | SD=1.1456
#       Worst SBP: MAE=12.4466 | StdAcrossFolds(MAE)=3.9942
#       Worst DBP: MAE=6.3253 | StdAcrossFolds(MAE)=1.8684
#
#   >>> BlockGap=3m | FoldLen=374 segs (~62.33 min)
#     [Fold 1] SBP MAE=1.8350, SD=1.3892 | DBP MAE=1.4242, SD=0.9515 | elapsed=1.9s
#     [Fold 2] SBP MAE=10.5656, SD=1.5374 | DBP MAE=6.2465, SD=0.8989 | elapsed=1.9s
#     [Fold 3] SBP MAE=10.8117, SD=1.1093 | DBP MAE=5.5060, SD=0.6600 | elapsed=2.4s
#     [Fold 4] SBP MAE=3.6396, SD=1.5386 | DBP MAE=2.0849, SD=0.7515 | elapsed=2.0s
#     [Fold 5] SBP MAE=12.3005, SD=3.1593 | DBP MAE=2.6466, SD=1.3931 | elapsed=1.9s
#   --- SUMMARY TrainDur=5m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=7.8305 | SD=1.7467
#       Avg   DBP: MAE=3.5816 | SD=0.9310
#       Worst SBP: MAE=12.3005 | StdAcrossFolds(MAE)=4.2393
#       Worst DBP: MAE=6.2465 | StdAcrossFolds(MAE)=1.9274
#
#   >>> BlockGap=5m | FoldLen=364 segs (~60.67 min)
#     [Fold 1] SBP MAE=2.4365, SD=1.3436 | DBP MAE=0.9289, SD=1.0314 | elapsed=1.8s
#     [Fold 2] SBP MAE=8.8620, SD=2.3963 | DBP MAE=5.4895, SD=1.2994 | elapsed=1.9s
#     [Fold 3] SBP MAE=12.5824, SD=1.0876 | DBP MAE=5.8832, SD=0.6658 | elapsed=1.9s
#     [Fold 4] SBP MAE=10.3700, SD=2.1779 | DBP MAE=4.9578, SD=0.8979 | elapsed=2.5s
#     [Fold 5] SBP MAE=17.6024, SD=3.3948 | DBP MAE=6.3340, SD=1.5733 | elapsed=2.0s
#   --- SUMMARY TrainDur=5m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=10.3707 | SD=2.0800
#       Avg   DBP: MAE=4.7187 | SD=1.0936
#       Worst SBP: MAE=17.6024 | StdAcrossFolds(MAE)=4.9481
#       Worst DBP: MAE=6.3340 | StdAcrossFolds(MAE)=1.9483
#
#   >>> BlockGap=10m | FoldLen=340 segs (~56.67 min)
#     [Fold 1] SBP MAE=5.6746, SD=6.4842 | DBP MAE=3.1201, SD=8.8176 | elapsed=1.9s
#     [Fold 2] SBP MAE=13.4842, SD=7.6329 | DBP MAE=7.6225, SD=4.5881 | elapsed=1.9s
#     [Fold 3] SBP MAE=11.2030, SD=1.9506 | DBP MAE=4.8058, SD=1.0649 | elapsed=1.9s
#     [Fold 4] SBP MAE=6.4697, SD=1.2597 | DBP MAE=2.7219, SD=0.6963 | elapsed=1.9s
#     [Fold 5] SBP MAE=24.1307, SD=2.9921 | DBP MAE=8.5432, SD=1.4001 | elapsed=2.4s
#   --- SUMMARY TrainDur=5m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=12.1924 | SD=4.0639
#       Avg   DBP: MAE=5.3627 | SD=3.3134
#       Worst SBP: MAE=24.1307 | StdAcrossFolds(MAE)=6.6393
#       Worst DBP: MAE=8.5432 | StdAcrossFolds(MAE)=2.3467
#
# --------------------------------------------------------------------------------
# [TrainDur = 10 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=388 segs (~64.67 min)
#     [Fold 1] SBP MAE=1.4923, SD=1.4933 | DBP MAE=1.3774, SD=0.8132 | elapsed=3.4s
#     [Fold 2] SBP MAE=9.2051, SD=1.6115 | DBP MAE=5.4576, SD=1.0439 | elapsed=3.3s
#     [Fold 3] SBP MAE=2.5914, SD=1.8308 | DBP MAE=1.0534, SD=1.1404 | elapsed=3.2s
#     [Fold 4] SBP MAE=5.5137, SD=2.7263 | DBP MAE=3.0917, SD=1.2647 | elapsed=4.1s
#     [Fold 5] SBP MAE=4.9166, SD=3.6129 | DBP MAE=4.8320, SD=1.5999 | elapsed=3.3s
#   --- SUMMARY TrainDur=10m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=4.7438 | SD=2.2550
#       Avg   DBP: MAE=3.1624 | SD=1.1724
#       Worst SBP: MAE=9.2051 | StdAcrossFolds(MAE)=2.6732
#       Worst DBP: MAE=5.4576 | StdAcrossFolds(MAE)=1.7717
#
#   >>> BlockGap=3m | FoldLen=374 segs (~62.33 min)
#     [Fold 1] SBP MAE=1.7634, SD=1.3755 | DBP MAE=1.0488, SD=0.9364 | elapsed=3.2s
#     [Fold 2] SBP MAE=10.7060, SD=1.9506 | DBP MAE=5.9783, SD=1.0964 | elapsed=3.6s
#     [Fold 3] SBP MAE=8.3544, SD=1.9108 | DBP MAE=3.3315, SD=1.2110 | elapsed=3.7s
#     [Fold 4] SBP MAE=5.4434, SD=1.1523 | DBP MAE=3.0095, SD=0.6124 | elapsed=3.4s
#     [Fold 5] SBP MAE=11.4627, SD=2.3951 | DBP MAE=2.2968, SD=1.3164 | elapsed=3.3s
#   --- SUMMARY TrainDur=10m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=7.5460 | SD=1.7569
#       Avg   DBP: MAE=3.1330 | SD=1.0346
#       Worst SBP: MAE=11.4627 | StdAcrossFolds(MAE)=3.5732
#       Worst DBP: MAE=5.9783 | StdAcrossFolds(MAE)=1.6244
#
#   >>> BlockGap=5m | FoldLen=364 segs (~60.67 min)
#     [Fold 1] SBP MAE=4.3180, SD=1.5424 | DBP MAE=1.0531, SD=1.3535 | elapsed=4.0s
#     [Fold 2] SBP MAE=7.1338, SD=2.1048 | DBP MAE=3.3991, SD=1.5340 | elapsed=3.2s
#     [Fold 3] SBP MAE=12.4023, SD=1.0326 | DBP MAE=5.4362, SD=0.6525 | elapsed=3.2s
#     [Fold 4] SBP MAE=5.5531, SD=1.1806 | DBP MAE=2.6817, SD=0.6666 | elapsed=3.3s
#     [Fold 5] SBP MAE=5.2102, SD=3.7479 | DBP MAE=1.3758, SD=1.6672 | elapsed=4.0s
#   --- SUMMARY TrainDur=10m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=6.9235 | SD=1.9217
#       Avg   DBP: MAE=2.7892 | SD=1.1747
#       Worst SBP: MAE=12.4023 | StdAcrossFolds(MAE)=2.8866
#       Worst DBP: MAE=5.4362 | StdAcrossFolds(MAE)=1.5749
#
#   >>> BlockGap=10m | FoldLen=340 segs (~56.67 min)
#     [Fold 1] SBP MAE=3.2557, SD=3.2530 | DBP MAE=1.6890, SD=2.1644 | elapsed=3.2s
#     [Fold 2] SBP MAE=7.1733, SD=5.4536 | DBP MAE=3.6465, SD=3.5247 | elapsed=3.2s
#     [Fold 3] SBP MAE=14.5061, SD=0.8369 | DBP MAE=6.0536, SD=0.6685 | elapsed=3.7s
#     [Fold 4] SBP MAE=7.9071, SD=1.4649 | DBP MAE=3.6014, SD=0.6546 | elapsed=3.6s
#     [Fold 5] SBP MAE=3.3518, SD=4.1187 | DBP MAE=3.7959, SD=1.7252 | elapsed=3.2s
#   --- SUMMARY TrainDur=10m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=7.2388 | SD=3.0254
#       Avg   DBP: MAE=3.7573 | SD=1.7475
#       Worst SBP: MAE=14.5061 | StdAcrossFolds(MAE)=4.1046
#       Worst DBP: MAE=6.0536 | StdAcrossFolds(MAE)=1.3848
#
# --------------------------------------------------------------------------------
# [TrainDur = 15 min] (TimeGap=5m, TestDur=5m)
# --------------------------------------------------------------------------------
#
#   >>> BlockGap=0m | FoldLen=388 segs (~64.67 min)
#     [Fold 1] SBP MAE=2.4067, SD=1.7047 | DBP MAE=1.0607, SD=1.0974 | elapsed=5.2s
#     [Fold 2] SBP MAE=9.2446, SD=1.5641 | DBP MAE=5.3645, SD=1.0264 | elapsed=5.2s
#     [Fold 3] SBP MAE=4.5938, SD=1.7768 | DBP MAE=1.4655, SD=1.0237 | elapsed=4.8s
#     [Fold 4] SBP MAE=4.5326, SD=1.8359 | DBP MAE=1.5594, SD=0.7487 | elapsed=5.6s
#     [Fold 5] SBP MAE=3.2943, SD=2.6790 | DBP MAE=3.1680, SD=1.2037 | elapsed=4.8s
#   --- SUMMARY TrainDur=15m BlockGap=0m | ValidFolds=5/5
#       Avg   SBP: MAE=4.8144 | SD=1.9121
#       Avg   DBP: MAE=2.5236 | SD=1.0200
#       Worst SBP: MAE=9.2446 | StdAcrossFolds(MAE)=2.3606
#       Worst DBP: MAE=5.3645 | StdAcrossFolds(MAE)=1.5922
#
#   >>> BlockGap=3m | FoldLen=374 segs (~62.33 min)
#     [Fold 1] SBP MAE=2.7290, SD=2.0209 | DBP MAE=0.9303, SD=1.3816 | elapsed=5.2s
#     [Fold 2] SBP MAE=8.9308, SD=1.7795 | DBP MAE=5.4325, SD=0.9963 | elapsed=5.2s
#     [Fold 3] SBP MAE=9.8263, SD=1.8024 | DBP MAE=4.2061, SD=1.2108 | elapsed=4.7s
#     [Fold 4] SBP MAE=6.0901, SD=1.4118 | DBP MAE=2.7416, SD=1.2832 | elapsed=5.6s
#     [Fold 5] SBP MAE=2.6933, SD=2.8256 | DBP MAE=2.5962, SD=1.4801 | elapsed=4.8s
#   --- SUMMARY TrainDur=15m BlockGap=3m | ValidFolds=5/5
#       Avg   SBP: MAE=6.0539 | SD=1.9680
#       Avg   DBP: MAE=3.1813 | SD=1.2704
#       Worst SBP: MAE=9.8263 | StdAcrossFolds(MAE)=2.9952
#       Worst DBP: MAE=5.4325 | StdAcrossFolds(MAE)=1.5311
#
#   >>> BlockGap=5m | FoldLen=364 segs (~60.67 min)
#     [Fold 1] SBP MAE=2.8019, SD=1.6189 | DBP MAE=1.0064, SD=1.0076 | elapsed=5.3s
#     [Fold 2] SBP MAE=4.4779, SD=1.7237 | DBP MAE=2.2911, SD=1.3931 | elapsed=5.2s
#     [Fold 3] SBP MAE=13.2323, SD=1.1302 | DBP MAE=4.7032, SD=0.6339 | elapsed=4.8s
#     [Fold 4] SBP MAE=4.7112, SD=1.3253 | DBP MAE=2.7291, SD=0.8512 | elapsed=5.6s
#     [Fold 5] SBP MAE=3.8357, SD=2.5980 | DBP MAE=3.8117, SD=1.2766 | elapsed=4.8s
#   --- SUMMARY TrainDur=15m BlockGap=5m | ValidFolds=5/5
#       Avg   SBP: MAE=5.8118 | SD=1.6792
#       Avg   DBP: MAE=2.9083 | SD=1.0325
#       Worst SBP: MAE=13.2323 | StdAcrossFolds(MAE)=3.7688
#       Worst DBP: MAE=4.7032 | StdAcrossFolds(MAE)=1.2703
#
#   >>> BlockGap=10m | FoldLen=340 segs (~56.67 min)
#     [Fold 1] SBP MAE=7.6987, SD=3.2817 | DBP MAE=2.6051, SD=0.7566 | elapsed=5.3s
#     [Fold 2] SBP MAE=15.6470, SD=7.9974 | DBP MAE=7.6795, SD=4.7443 | elapsed=5.0s
#     [Fold 3] SBP MAE=9.9761, SD=1.5331 | DBP MAE=3.4222, SD=1.0206 | elapsed=4.9s
#     [Fold 4] SBP MAE=6.2786, SD=1.9473 | DBP MAE=2.4987, SD=1.0851 | elapsed=5.6s
#     [Fold 5] SBP MAE=2.1267, SD=2.2985 | DBP MAE=1.3097, SD=1.1600 | elapsed=4.8s
#   --- SUMMARY TrainDur=15m BlockGap=10m | ValidFolds=5/5
#       Avg   SBP: MAE=8.3454 | SD=3.4116
#       Avg   DBP: MAE=3.5030 | SD=1.7533
#       Worst SBP: MAE=15.6470 | StdAcrossFolds(MAE)=4.4573
#       Worst DBP: MAE=7.6795 | StdAcrossFolds(MAE)=2.1943
#
# ################################################################################
# [FINAL SUMMARY] filtering=True | grouped by TrainDur then BlockGap
# Used patients: 10 / 10
# ################################################################################
#
# ================================================================================
# [TrainDur = 3 min]  (TimeGap=5m, TestDur=5m)
# ================================================================================
#
#   [BlockGap=0 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.5922 | std=1.1942
#     AvgMAE DBP: mean=2.8329 | std=0.8951
#     AvgSD  SBP: mean=3.2893 | std=1.5313
#     AvgSD  DBP: mean=1.6975 | std=0.6211
#     WorstMAE SBP: mean=10.1615 | std=4.3553
#     WorstMAE DBP: mean=5.5225 | std=3.6628
#     StdAcrossFolds(MAE) SBP: mean=2.8233 | std=1.9147
#     StdAcrossFolds(MAE) DBP: mean=1.6359 | std=1.4122
#
#   [BlockGap=3 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.5614 | std=1.4910
#     AvgMAE DBP: mean=2.9315 | std=1.0592
#     AvgSD  SBP: mean=3.4218 | std=1.6187
#     AvgSD  DBP: mean=1.7527 | std=0.8795
#     WorstMAE SBP: mean=11.1206 | std=5.0214
#     WorstMAE DBP: mean=6.5382 | std=3.9749
#     StdAcrossFolds(MAE) SBP: mean=3.3839 | std=1.9477
#     StdAcrossFolds(MAE) DBP: mean=2.0698 | std=1.4630
#
#   [BlockGap=5 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=6.6287 | std=3.2468
#     AvgMAE DBP: mean=3.7567 | std=3.3800
#     AvgSD  SBP: mean=3.6074 | std=2.2581
#     AvgSD  DBP: mean=2.1307 | std=1.9652
#     WorstMAE SBP: mean=14.1478 | std=11.6452
#     WorstMAE DBP: mean=10.6013 | std=15.8066
#     StdAcrossFolds(MAE) SBP: mean=4.2145 | std=4.2411
#     StdAcrossFolds(MAE) DBP: mean=3.6795 | std=6.1384
#
#   [BlockGap=10 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.6524 | std=1.8709
#     AvgMAE DBP: mean=3.4602 | std=2.5443
#     AvgSD  SBP: mean=3.7666 | std=1.4486
#     AvgSD  DBP: mean=1.8443 | std=0.5404
#     WorstMAE SBP: mean=9.8023 | std=2.7308
#     WorstMAE DBP: mean=8.4998 | std=10.1021
#     StdAcrossFolds(MAE) SBP: mean=2.4375 | std=0.9353
#     StdAcrossFolds(MAE) DBP: mean=2.6960 | std=3.7623
#
# ================================================================================
# [TrainDur = 5 min]  (TimeGap=5m, TestDur=5m)
# ================================================================================
#
#   [BlockGap=0 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.6632 | std=2.2022
#     AvgMAE DBP: mean=2.7994 | std=1.1239
#     AvgSD  SBP: mean=3.5408 | std=2.0108
#     AvgSD  DBP: mean=1.7703 | std=0.8908
#     WorstMAE SBP: mean=11.7811 | std=6.7033
#     WorstMAE DBP: mean=5.8253 | std=3.7454
#     StdAcrossFolds(MAE) SBP: mean=3.6473 | std=2.3215
#     StdAcrossFolds(MAE) DBP: mean=1.7643 | std=1.3948
#
#   [BlockGap=3 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.5846 | std=1.4672
#     AvgMAE DBP: mean=2.5464 | std=0.9262
#     AvgSD  SBP: mean=3.2637 | std=1.6349
#     AvgSD  DBP: mean=1.5475 | std=0.5867
#     WorstMAE SBP: mean=10.5811 | std=3.0656
#     WorstMAE DBP: mean=5.4264 | std=3.3507
#     StdAcrossFolds(MAE) SBP: mean=3.0760 | std=1.3206
#     StdAcrossFolds(MAE) DBP: mean=1.6828 | std=1.2483
#
#   [BlockGap=5 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=6.1192 | std=2.1277
#     AvgMAE DBP: mean=3.0224 | std=1.5554
#     AvgSD  SBP: mean=3.4295 | std=2.0094
#     AvgSD  DBP: mean=1.8548 | std=1.2708
#     WorstMAE SBP: mean=11.6316 | std=4.8354
#     WorstMAE DBP: mean=6.6205 | std=5.1829
#     StdAcrossFolds(MAE) SBP: mean=3.3169 | std=1.7789
#     StdAcrossFolds(MAE) DBP: mean=2.0861 | std=1.8682
#
#   [BlockGap=10 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=6.0902 | std=2.5417
#     AvgMAE DBP: mean=3.3921 | std=2.0127
#     AvgSD  SBP: mean=3.6376 | std=1.4396
#     AvgSD  DBP: mean=1.9406 | std=0.7509
#     WorstMAE SBP: mean=11.7305 | std=5.9479
#     WorstMAE DBP: mean=7.7407 | std=6.8480
#     StdAcrossFolds(MAE) SBP: mean=3.4293 | std=1.9221
#     StdAcrossFolds(MAE) DBP: mean=2.4045 | std=2.4596
#
# ================================================================================
# [TrainDur = 10 min]  (TimeGap=5m, TestDur=5m)
# ================================================================================
#
#   [BlockGap=0 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.3293 | std=1.0886
#     AvgMAE DBP: mean=2.8380 | std=0.9933
#     AvgSD  SBP: mean=3.3213 | std=1.4381
#     AvgSD  DBP: mean=1.7134 | std=0.7942
#     WorstMAE SBP: mean=10.6555 | std=3.2327
#     WorstMAE DBP: mean=6.2710 | std=3.8261
#     StdAcrossFolds(MAE) SBP: mean=3.1415 | std=1.3960
#     StdAcrossFolds(MAE) DBP: mean=1.9623 | std=1.4270
#
#   [BlockGap=3 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.8139 | std=1.4378
#     AvgMAE DBP: mean=2.8609 | std=1.0610
#     AvgSD  SBP: mean=3.2775 | std=1.4769
#     AvgSD  DBP: mean=1.6742 | std=0.6820
#     WorstMAE SBP: mean=11.2403 | std=3.5684
#     WorstMAE DBP: mean=6.1517 | std=3.5947
#     StdAcrossFolds(MAE) SBP: mean=3.2824 | std=1.4093
#     StdAcrossFolds(MAE) DBP: mean=1.8969 | std=1.3513
#
#   [BlockGap=5 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.9830 | std=1.8647
#     AvgMAE DBP: mean=2.9871 | std=1.6442
#     AvgSD  SBP: mean=3.2111 | std=1.4376
#     AvgSD  DBP: mean=1.6293 | std=0.5989
#     WorstMAE SBP: mean=11.8131 | std=5.0203
#     WorstMAE DBP: mean=7.0846 | std=5.7819
#     StdAcrossFolds(MAE) SBP: mean=3.2693 | std=1.7692
#     StdAcrossFolds(MAE) DBP: mean=2.2154 | std=2.0987
#
#   [BlockGap=10 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=6.2766 | std=2.3493
#     AvgMAE DBP: mean=3.4611 | std=2.0026
#     AvgSD  SBP: mean=3.6243 | std=1.6826
#     AvgSD  DBP: mean=1.9402 | std=0.8412
#     WorstMAE SBP: mean=11.7106 | std=4.2618
#     WorstMAE DBP: mean=8.4509 | std=6.5131
#     StdAcrossFolds(MAE) SBP: mean=3.2135 | std=1.4348
#     StdAcrossFolds(MAE) DBP: mean=2.6538 | std=2.2996
#
# ================================================================================
# [TrainDur = 15 min]  (TimeGap=5m, TestDur=5m)
# ================================================================================
#
#   [BlockGap=0 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.5787 | std=1.5197
#     AvgMAE DBP: mean=2.8224 | std=1.1684
#     AvgSD  SBP: mean=3.5658 | std=1.3183
#     AvgSD  DBP: mean=1.8055 | std=0.8238
#     WorstMAE SBP: mean=11.0892 | std=4.9662
#     WorstMAE DBP: mean=5.9490 | std=3.9534
#     StdAcrossFolds(MAE) SBP: mean=3.2505 | std=1.9693
#     StdAcrossFolds(MAE) DBP: mean=1.7776 | std=1.4346
#
#   [BlockGap=3 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=5.9796 | std=1.9936
#     AvgMAE DBP: mean=2.7472 | std=1.2756
#     AvgSD  SBP: mean=3.7650 | std=1.8888
#     AvgSD  DBP: mean=1.7357 | std=0.6720
#     WorstMAE SBP: mean=12.5048 | std=5.5685
#     WorstMAE DBP: mean=6.0406 | std=3.9965
#     StdAcrossFolds(MAE) SBP: mean=3.7665 | std=1.8503
#     StdAcrossFolds(MAE) DBP: mean=1.8658 | std=1.3979
#
#   [BlockGap=5 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=6.0723 | std=2.1218
#     AvgMAE DBP: mean=2.6264 | std=0.9121
#     AvgSD  SBP: mean=3.4805 | std=1.9217
#     AvgSD  DBP: mean=1.7556 | std=0.8668
#     WorstMAE SBP: mean=12.4082 | std=5.8268
#     WorstMAE DBP: mean=5.4620 | std=3.4021
#     StdAcrossFolds(MAE) SBP: mean=3.7204 | std=1.9350
#     StdAcrossFolds(MAE) DBP: mean=1.6348 | std=1.3143
#
#   [BlockGap=10 min] PatientsUsed: 10/10
#     AvgMAE SBP: mean=7.3417 | std=5.6521
#     AvgMAE DBP: mean=2.8103 | std=1.3574
#     AvgSD  SBP: mean=4.1868 | std=3.1050
#     AvgSD  DBP: mean=1.8980 | std=0.8915
#     WorstMAE SBP: mean=19.0298 | std=24.4851
#     WorstMAE DBP: mean=6.3554 | std=4.3495
#     StdAcrossFolds(MAE) SBP: mean=6.2971 | std=9.3002
#     StdAcrossFolds(MAE) DBP: mean=1.9062 | std=1.5115
#
# [ALL DONE] Total elapsed: 6255.8s
