# %%
import os, glob, time, random, gc
import numpy as np
import h5py
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from scipy.interpolate import interp1d
from scipy.integrate import trapezoid

# ==========================================
# [0] Experiment settings
# ==========================================
PULSEDB_DIR = "/content/drive/MyDrive/Colab Notebooks/PulseDB/with_Hyper"
SEGMENT_LIMIT = None
PAD_LEN = 200
SEC_PER_SEGMENT = 10.0

BATCH_SIZE = 32
EPOCHS = 100
LR = 1e-3
WEIGHT_DECAY = 1e-4
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SEED = 42
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
print(f"Using Device: {DEVICE}")

# protocol config
N_FOLDS = 5  # Block Quantity
TIME_GAP_MIN = 5  # Train-Test Gap
TEST_DUR_MIN = 5  # Test Duration
TRAIN_DUR_MIN = 15  # Train Duration
BLOCK_GAP_MIN = 3  # Block-Block Gap
VAL_FRAC_IN_TRAIN = 0.20  # Validation Ratio
FILTERING = True

# ==========================================
# [1] Filtering + resample + priors
# ==========================================
def preprocess_ensemble_by_rpeaks(ppg_raw, rpeaks_raw, sbp, dbp, target_len=125, threshold_corr=0.7):
    if not (50 <= sbp <= 250) or not (30 <= dbp <= 160):
        return None

    ppg = ppg_raw.squeeze()
    rpeaks = rpeaks_raw.squeeze()
    rpeaks = np.sort(rpeaks.astype(int))

    beats = []
    for i in range(len(rpeaks) - 1):
        start, end = rpeaks[i], rpeaks[i + 1]
        if start < 0 or end > len(ppg):
            continue
        beat_segment = ppg[start:end]
        if len(beat_segment) < 20:
            continue

        x_old = np.linspace(0, 1, len(beat_segment))
        x_new = np.linspace(0, 1, target_len)
        f_interp = interp1d(x_old, beat_segment, kind='linear', fill_value="extrapolate")
        beats.append(f_interp(x_new))

    if len(beats) < 5:
        return None

    beats = np.array(beats)
    ensemble_avg = np.mean(beats, axis=0)

    e_min, e_max = ensemble_avg.min(), ensemble_avg.max()
    if e_max - e_min > 1e-6:
        ensemble_avg = (ensemble_avg - e_min) / (e_max - e_min)

    correlations = [np.corrcoef(ensemble_avg, b)[0, 1] for b in beats]
    consistent_beats_count = sum(1 for c in correlations if c >= threshold_corr)
    if (consistent_beats_count / len(beats)) < 0.7:
        return None

    return ensemble_avg.astype(np.float32)

def cubic_resample(ppg, target_len=PAD_LEN):
    x_old = np.linspace(0, 1, len(ppg))
    x_new = np.linspace(0, 1, target_len)
    if len(ppg) < 4:
        return np.interp(x_new, x_old, ppg).astype(np.float32)
    try:
        f = interp1d(x_old, ppg, kind="cubic", bounds_error=False, fill_value="extrapolate")
        return f(x_new).astype(np.float32)
    except Exception:
        return np.interp(x_new, x_old, ppg).astype(np.float32)

def extract_multiscale_morph_features(ppg_01):
    scales = [100, 150, 200, 250]
    all_features = []
    for scale in scales:
        x = cubic_resample(ppg_01, scale)

        peak_idx = int(np.argmax(x))
        end_idx = scale - 1

        vp = float(x[peak_idx])
        vt = float(x[end_idx])
        dv = vp - vt
        vm = float(np.mean(x))
        std_val = float(np.std(x))

        tvp = peak_idx / scale

        diff = np.diff(x)
        kmax = float(np.max(diff)) if len(diff) > 0 else 0.0
        tkmax = (int(np.argmax(diff)) / scale) if len(diff) > 0 else 0.0

        amax = float(trapezoid(x[:peak_idx])) if peak_idx > 0 else 0.0

        centered = x - vm
        skew_approx = float(np.mean(centered**3) / (std_val**3)) if std_val > 0 else 0.0
        kurt_approx = float(np.mean(centered**4) / (std_val**4)) if std_val > 0 else 0.0

        all_features.extend([vp, vt, dv, vm, kmax, tkmax, amax, std_val, tvp, skew_approx, kurt_approx])

    return np.array(all_features, dtype=np.float32)

# ==========================================
# [2] Load data
# ==========================================
def load_data_from_mat(mat_path, segment_limit=None, filtering=False):
    segments, priors, targets = [], [], []
    skip_bp, skip_noise = 0, 0

    with h5py.File(mat_path, "r") as f:
        sw = f["Subj_Wins"]
        ppg_refs = sw["PPG_F"][0]
        sbp_refs = sw["SegSBP"][0]
        dbp_refs = sw["SegDBP"][0]

        total = min(len(ppg_refs), segment_limit) if segment_limit else len(ppg_refs)

        if not filtering:
            for i in range(total):
                ppg = f[ppg_refs[i]][()].squeeze().astype(np.float32)
                sbp = float(f[sbp_refs[i]][()][0][0])
                dbp = float(f[dbp_refs[i]][()][0][0])

                segments.append(ppg)
                priors.append(extract_multiscale_morph_features(ppg))
                targets.append([sbp, dbp])

            print(f"✅ (NoFilter) kept: {len(segments)} / {total}")
            return segments, np.stack(priors).astype(np.float32), np.array(targets, dtype=np.float32)

        # filtering=True
        ecg_refs = sw["ECG_RPeaks"][0]
        for i in range(total):
            ppg_raw = f[ppg_refs[i]][()]
            sbp = float(f[sbp_refs[i]][()][0][0])
            dbp = float(f[dbp_refs[i]][()][0][0])
            rpeaks_raw = f[ecg_refs[i]][()]

            processed_ppg = preprocess_ensemble_by_rpeaks(ppg_raw, rpeaks_raw, sbp, dbp)

            if processed_ppg is None:
                if not (50 <= sbp <= 250) or not (30 <= dbp <= 160):
                    skip_bp += 1
                else:
                    skip_noise += 1
                continue

            segments.append(processed_ppg)
            priors.append(extract_multiscale_morph_features(processed_ppg))
            targets.append([sbp, dbp])

    print(f"✅ (Filter) kept: {len(segments)} / {total}")
    print(f"❌ excluded: (bp_range={skip_bp}, noise/quality={skip_noise})")
    return segments, np.stack(priors).astype(np.float32), np.array(targets, dtype=np.float32)

# ==========================================
# [3] Dataset
# ==========================================
class PPGDatasetRawY(Dataset):
    def __init__(self, segments, priors, targets_mmHg):
        self.segments = segments
        self.priors = priors
        self.targets = targets_mmHg

    def __len__(self):
        return len(self.segments)

    def __getitem__(self, idx):
        x = cubic_resample(self.segments[idx], PAD_LEN)
        x = torch.tensor(x, dtype=torch.float32).unsqueeze(0)
        p = torch.tensor(self.priors[idx], dtype=torch.float32)
        y = torch.tensor(self.targets[idx], dtype=torch.float32)
        return x, p, y

# ==========================================
# [4] Model
# ==========================================
class MorphCNNRegressor(nn.Module):
    def __init__(self, prior_dim=44):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv1d(1, 32, 7, padding=3),
            nn.BatchNorm1d(32),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(32, 64, 5, padding=2),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(64, 128, 5, padding=2),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.MaxPool1d(2),

            nn.Conv1d(128, 256, 3, padding=1),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.AdaptiveAvgPool1d(1)
        )

        self.fc_prior = nn.Sequential(
            nn.Linear(prior_dim, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 256),
            nn.BatchNorm1d(256),
            nn.ReLU()
        )

        self.fc_out = nn.Sequential(
            nn.Linear(256 + 256, 256),
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 2)
        )

    def forward(self, x, prior):
        feat = self.cnn(x).squeeze(-1)
        pfeat = self.fc_prior(prior)
        return self.fc_out(torch.cat([feat, pfeat], dim=1))

# ==========================================
# [5] Train-only label scaler
# ==========================================
class LabelScaler2D:
    def __init__(self, mode="minmax", eps=1e-6):
        assert mode in ["minmax", "zscore"]
        self.mode = mode
        self.eps = eps
        self.fitted = False

    def fit(self, y_train_mmHg: np.ndarray):
        y = np.asarray(y_train_mmHg, dtype=np.float32)
        if self.mode == "minmax":
            self.y_min = y.min(axis=0)
            self.y_max = y.max(axis=0)
        else:
            self.y_mean = y.mean(axis=0)
            self.y_std = y.std(axis=0)
        self.fitted = True
        return self

    def transform(self, y_mmHg: torch.Tensor) -> torch.Tensor:
        assert self.fitted
        if self.mode == "minmax":
            y_min = torch.tensor(self.y_min, device=y_mmHg.device, dtype=y_mmHg.dtype)
            y_max = torch.tensor(self.y_max, device=y_mmHg.device, dtype=y_mmHg.dtype)
            return (y_mmHg - y_min) / (y_max - y_min + self.eps)
        else:
            y_mean = torch.tensor(self.y_mean, device=y_mmHg.device, dtype=y_mmHg.dtype)
            y_std = torch.tensor(self.y_std, device=y_mmHg.device, dtype=y_mmHg.dtype)
            return (y_mmHg - y_mean) / (y_std + self.eps)

    def inverse(self, y_scaled: torch.Tensor) -> torch.Tensor:
        assert self.fitted
        if self.mode == "minmax":
            y_min = torch.tensor(self.y_min, device=y_scaled.device, dtype=y_scaled.dtype)
            y_max = torch.tensor(self.y_max, device=y_scaled.device, dtype=y_scaled.dtype)
            return y_scaled * (y_max - y_min + self.eps) + y_min
        else:
            y_mean = torch.tensor(self.y_mean, device=y_scaled.device, dtype=y_scaled.dtype)
            y_std = torch.tensor(self.y_std, device=y_scaled.device, dtype=y_scaled.dtype)
            return y_scaled * (y_std + self.eps) + y_mean

# ==========================================
# [6] Train / Eval
# ==========================================
def set_seed(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def train_one_model(train_loader, val_loader, scaler: LabelScaler2D):
    model = MorphCNNRegressor(prior_dim=44).to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
    criterion = nn.MSELoss()

    best_val = float("inf")
    best_state = None

    for epoch in range(1, EPOCHS + 1):
        model.train()
        for x, p, y_mmHg in train_loader:
            x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
            y = scaler.transform(y_mmHg)
            pred = model(x, p)
            loss = criterion(pred, y)
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

        model.eval()
        val_losses = []
        with torch.no_grad():
            for x, p, y_mmHg in val_loader:
                x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
                y = scaler.transform(y_mmHg)
                pred = model(x, p)
                val_losses.append(float(criterion(pred, y).item()))
        avg_val = float(np.mean(val_losses)) if len(val_losses) else float("inf")

        if avg_val < best_val:
            best_val = avg_val
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

    if best_state is not None:
        model.load_state_dict(best_state)
    return model

def eval_mae_sd_mmHg(model, loader, scaler: LabelScaler2D):
    model.eval()
    errs = []
    with torch.no_grad():
        for x, p, y_mmHg in loader:
            x, p, y_mmHg = x.to(DEVICE), p.to(DEVICE), y_mmHg.to(DEVICE)
            pred_scaled = model(x, p)
            pred_mmHg = scaler.inverse(pred_scaled)
            err = (pred_mmHg - y_mmHg).detach().cpu().numpy()
            errs.append(err)

    if len(errs) == 0:
        return dict(mae_sbp=np.nan, sd_sbp=np.nan, mae_dbp=np.nan, sd_dbp=np.nan, n=0)

    E = np.concatenate(errs, axis=0)
    e_sbp, e_dbp = E[:, 0], E[:, 1]
    return dict(
        mae_sbp=float(np.mean(np.abs(e_sbp))),
        sd_sbp=float(np.std(e_sbp, ddof=0)),
        mae_dbp=float(np.mean(np.abs(e_dbp))),
        sd_dbp=float(np.std(e_dbp, ddof=0)),
        n=int(E.shape[0])
    )

# ==========================================
# [7] CV helpers
# ==========================================
def segs_from_minutes(minutes: float) -> int:
    return int((minutes * 60.0) / SEC_PER_SEGMENT)

def summarize_folds(valid_stats):
    mae_sbp = np.array([v["mae_sbp"] for v in valid_stats], dtype=np.float32)
    mae_dbp = np.array([v["mae_dbp"] for v in valid_stats], dtype=np.float32)
    sd_sbp  = np.array([v["sd_sbp"]  for v in valid_stats], dtype=np.float32)
    sd_dbp  = np.array([v["sd_dbp"]  for v in valid_stats], dtype=np.float32)

    return {
        "avg_mae_sbp": float(mae_sbp.mean()),
        "avg_mae_dbp": float(mae_dbp.mean()),
        "avg_sd_sbp":  float(sd_sbp.mean()),
        "avg_sd_dbp":  float(sd_dbp.mean()),
        "worst_mae_sbp": float(mae_sbp.max()),
        "worst_mae_dbp": float(mae_dbp.max()),
        "std_mae_sbp": float(mae_sbp.std(ddof=0)),
        "std_mae_dbp": float(mae_dbp.std(ddof=0)),
        "valid_folds": int(len(valid_stats)),
    }

def min_required_total_len(bg_min: float, tr_min: float) -> int:
    b_gap = segs_from_minutes(bg_min)
    need_per_fold = segs_from_minutes(tr_min) + segs_from_minutes(TIME_GAP_MIN) + segs_from_minutes(TEST_DUR_MIN)
    return N_FOLDS * need_per_fold + (N_FOLDS - 1) * b_gap

# ==========================================
# [8] One patient (fixed config)
# ==========================================
def run_one_patient_fixed(mat_path: str, filtering: bool):
    set_seed(SEED)

    print("\n" + "=" * 80)
    print(f"[PATIENT] {os.path.basename(mat_path)} | filtering={filtering}")
    print("=" * 80)

    segments, priors, targets_mmHg = load_data_from_mat(mat_path, segment_limit=SEGMENT_LIMIT, filtering=filtering)
    ds = PPGDatasetRawY(segments, priors, targets_mmHg)
    total_len = len(ds)
    print(f"[Data Ready] total_len={total_len}")

    gap_segs  = segs_from_minutes(TIME_GAP_MIN)
    test_segs = segs_from_minutes(TEST_DUR_MIN)
    tr_segs   = segs_from_minutes(TRAIN_DUR_MIN)
    b_gap_segs = segs_from_minutes(BLOCK_GAP_MIN)

    # feasibility
    min_need = min_required_total_len(BLOCK_GAP_MIN, TRAIN_DUR_MIN)
    if total_len < min_need:
        print(f"[SKIP] too short: total_len={total_len} < min_need={min_need}")
        return None

    available_len = total_len - (N_FOLDS - 1) * b_gap_segs
    if available_len <= 0:
        print("[SKIP] available_len<=0")
        return None

    fold_len = available_len // N_FOLDS
    if fold_len <= 0 or fold_len <= test_segs + 1:
        print(f"[SKIP] fold_len too small: fold_len={fold_len}")
        return None

    print("\n=== FIXED CONFIG ===")
    print(f"N_FOLDS={N_FOLDS}")
    print(f"TrainDur={TRAIN_DUR_MIN}m ({tr_segs} segs) | TimeGap={TIME_GAP_MIN}m ({gap_segs} segs) | TestDur={TEST_DUR_MIN}m ({test_segs} segs)")
    print(f"BlockGap={BLOCK_GAP_MIN}m ({b_gap_segs} segs) | FoldLen={fold_len} segs (~{fold_len*SEC_PER_SEGMENT/60.0:.2f} min)")

    fold_stats = []
    for f_idx in range(N_FOLDS):
        fold_start = f_idx * (fold_len + b_gap_segs)
        fold_end   = fold_start + fold_len

        test_end = fold_end
        test_start = test_end - test_segs

        train_end = test_start - gap_segs
        train_start = train_end - tr_segs

        if train_start < fold_start or train_end > test_start:
            print(f"[Fold {f_idx+1}] SKIP (room): fold=({fold_start},{fold_end}) train=({train_start},{train_end}) test=({test_start},{test_end})")
            fold_stats.append(None)
            continue

        train_indices = list(range(train_start, train_end))
        test_indices  = list(range(test_start, test_end))

        n_total = len(train_indices)
        n_val = max(1, int(n_total * VAL_FRAC_IN_TRAIN))
        if n_total - n_val < 1:
            print(f"[Fold {f_idx+1}] SKIP (train too small after val split).")
            fold_stats.append(None)
            continue

        real_train_idx = train_indices[:-n_val]
        val_idx        = train_indices[-n_val:]

        y_train = targets_mmHg[np.array(real_train_idx)]
        scaler = LabelScaler2D(mode="minmax", eps=1e-6).fit(y_train)

        train_loader = DataLoader(Subset(ds, real_train_idx), batch_size=BATCH_SIZE, shuffle=True)
        val_loader   = DataLoader(Subset(ds, val_idx), batch_size=BATCH_SIZE, shuffle=False)
        test_loader  = DataLoader(Subset(ds, test_indices), batch_size=BATCH_SIZE, shuffle=False)

        t0 = time.time()
        model = train_one_model(train_loader, val_loader, scaler)
        stat = eval_mae_sd_mmHg(model, test_loader, scaler)
        elapsed = time.time() - t0

        stat.update({
            "fold": f_idx + 1,
            "train_dur_min": TRAIN_DUR_MIN,
            "block_gap_min": BLOCK_GAP_MIN,
            "train_n": len(real_train_idx),
            "val_n": len(val_idx),
            "test_n": len(test_indices),
            "elapsed_s": float(elapsed),
        })
        fold_stats.append(stat)

        print(f"\n[Fold {f_idx+1}] fold=({fold_start},{fold_end}) | train=({train_start},{train_end}) | test=({test_start},{test_end})")
        print(f"  sizes Train/Val/Test: {len(real_train_idx)}/{len(val_idx)}/{len(test_indices)}")
        print(f"  SBP: MAE={stat['mae_sbp']:.4f} | SD={stat['sd_sbp']:.4f}")
        print(f"  DBP: MAE={stat['mae_dbp']:.4f} | SD={stat['sd_dbp']:.4f}")
        print(f"  elapsed: {elapsed:.1f}s")

        del model
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
        gc.collect()

    valid = [fs for fs in fold_stats if fs is not None and np.isfinite(fs["mae_sbp"])]

    print("\n--- PATIENT SUMMARY ---")
    if len(valid) == 0:
        print("No valid folds.")
        return None

    summ = summarize_folds(valid)
    print(f"ValidFolds: {summ['valid_folds']}/{N_FOLDS}")
    print(f"Avg   SBP: MAE={summ['avg_mae_sbp']:.4f} | SD={summ['avg_sd_sbp']:.4f}")
    print(f"Avg   DBP: MAE={summ['avg_mae_dbp']:.4f} | SD={summ['avg_sd_dbp']:.4f}")
    print(f"Worst SBP: MAE={summ['worst_mae_sbp']:.4f} | StdAcrossFolds(MAE)={summ['std_mae_sbp']:.4f}")
    print(f"Worst DBP: MAE={summ['worst_mae_dbp']:.4f} | StdAcrossFolds(MAE)={summ['std_mae_dbp']:.4f}")

    return summ

# ==========================================
# [9] All patients (fixed config)
# ==========================================
def run_all_fixed(pulsedb_dir: str, filtering: bool):
    patient_files = sorted(glob.glob(os.path.join(pulsedb_dir, "p*.mat")))
    if len(patient_files) == 0:
        raise FileNotFoundError(f"No .mat files found under: {pulsedb_dir}")

    print("\n" + "#" * 80)
    print(f"[RUN ALL FIXED] Found {len(patient_files)} patients | filtering={filtering}")
    print(f"DIR: {pulsedb_dir}")
    print("#" * 80)

    results = []
    skipped = []

    t0_all = time.time()

    for i, mat_path in enumerate(patient_files, 1):
        print("\n" + "-" * 80)
        print(f"[{i}/{len(patient_files)}] START {os.path.basename(mat_path)}")
        print("-" * 80)

        try:
            summ = run_one_patient_fixed(mat_path, filtering=filtering)
            if summ is None:
                skipped.append((os.path.basename(mat_path), "no valid result (too short or fold invalid)"))
            else:
                results.append({"patient": os.path.basename(mat_path), "summary": summ})
        except Exception as e:
            reason = f"{type(e).__name__}: {e}"
            print(f"[SKIP PATIENT] {os.path.basename(mat_path)} | reason: {reason}")
            skipped.append((os.path.basename(mat_path), reason))

        if torch.cuda.is_available():
            torch.cuda.empty_cache()
        gc.collect()

    # final aggregation across patients
    def mean_std(arr):
        if len(arr) == 0:
            return float("nan"), float("nan")
        arr = np.asarray(arr, dtype=np.float32)
        ddof = 1 if len(arr) >= 2 else 0
        return float(arr.mean()), float(arr.std(ddof=ddof))

    print("\n" + "#" * 80)
    print(f"[FINAL SUMMARY] fixed config | filtering={filtering} | used={len(results)}/{len(patient_files)}")
    print("#" * 80)

    avg_mae_sbp = [r["summary"]["avg_mae_sbp"] for r in results]
    avg_mae_dbp = [r["summary"]["avg_mae_dbp"] for r in results]
    avg_sd_sbp  = [r["summary"]["avg_sd_sbp"]  for r in results]
    avg_sd_dbp  = [r["summary"]["avg_sd_dbp"]  for r in results]
    worst_mae_sbp = [r["summary"]["worst_mae_sbp"] for r in results]
    worst_mae_dbp = [r["summary"]["worst_mae_dbp"] for r in results]

    m, s = mean_std(avg_mae_sbp);  print(f"AvgMAE SBP: mean={m:.4f} | std={s:.4f}")
    m, s = mean_std(avg_mae_dbp);  print(f"AvgMAE DBP: mean={m:.4f} | std={s:.4f}")
    m, s = mean_std(avg_sd_sbp);   print(f"AvgSD  SBP: mean={m:.4f} | std={s:.4f}")
    m, s = mean_std(avg_sd_dbp);   print(f"AvgSD  DBP: mean={m:.4f} | std={s:.4f}")
    m, s = mean_std(worst_mae_sbp);print(f"WorstMAE SBP: mean={m:.4f} | std={s:.4f}")
    m, s = mean_std(worst_mae_dbp);print(f"WorstMAE DBP: mean={m:.4f} | std={s:.4f}")

    if skipped:
        print("\n" + "#" * 80)
        print("[SKIPPED PATIENTS]")
        print("#" * 80)
        for p, r in skipped:
            print(f"- {p}: {r}")

    print(f"\n[ALL DONE] Total elapsed: {time.time() - t0_all:.1f}s")
    return results, skipped

# ==========================================
# [MAIN]
# ==========================================
if __name__ == "__main__":
    run_all_fixed(PULSEDB_DIR, filtering=FILTERING)
# Out:
# Using Device: cuda
#
# ################################################################################
# [RUN ALL FIXED] Found 10 patients | filtering=True
# DIR: /content/drive/MyDrive/Colab Notebooks/PulseDB/with_Hyper
# ################################################################################
#
# --------------------------------------------------------------------------------
# [1/10] START p004679.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p004679.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 1859 / 1862
# ❌ excluded: (bp_range=0, noise/quality=3)
# [Data Ready] total_len=1859
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=357 segs (~59.50 min)
#
# [Fold 1] fold=(0,357) | train=(207,297) | test=(327,357)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.3478 | SD=3.8747
#   DBP: MAE=1.5849 | SD=1.8757
#   elapsed: 7.3s
#
# [Fold 2] fold=(375,732) | train=(582,672) | test=(702,732)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.6875 | SD=4.3972
#   DBP: MAE=3.8960 | SD=2.0181
#   elapsed: 6.4s
#
# [Fold 3] fold=(750,1107) | train=(957,1047) | test=(1077,1107)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.6430 | SD=3.8095
#   DBP: MAE=5.4671 | SD=1.6658
#   elapsed: 5.2s
#
# [Fold 4] fold=(1125,1482) | train=(1332,1422) | test=(1452,1482)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.0530 | SD=3.1836
#   DBP: MAE=1.9989 | SD=2.4835
#   elapsed: 5.4s
#
# [Fold 5] fold=(1500,1857) | train=(1707,1797) | test=(1827,1857)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=13.0829 | SD=7.3961
#   DBP: MAE=10.9774 | SD=3.6441
#   elapsed: 6.0s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=6.7629 | SD=4.5322
# Avg   DBP: MAE=4.7849 | SD=2.3374
# Worst SBP: MAE=13.0829 | StdAcrossFolds(MAE)=3.4528
# Worst DBP: MAE=10.9774 | StdAcrossFolds(MAE)=3.3942
#
# --------------------------------------------------------------------------------
# [2/10] START p004833.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p004833.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 1683 / 2506
# ❌ excluded: (bp_range=0, noise/quality=823)
# [Data Ready] total_len=1683
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=322 segs (~53.67 min)
#
# [Fold 1] fold=(0,322) | train=(172,262) | test=(292,322)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.0837 | SD=2.5909
#   DBP: MAE=3.7654 | SD=1.3281
#   elapsed: 5.4s
#
# [Fold 2] fold=(340,662) | train=(512,602) | test=(632,662)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.4547 | SD=2.2733
#   DBP: MAE=1.0013 | SD=0.7984
#   elapsed: 5.9s
#
# [Fold 3] fold=(680,1002) | train=(852,942) | test=(972,1002)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.9456 | SD=2.6047
#   DBP: MAE=1.2678 | SD=1.3071
#   elapsed: 5.6s
#
# [Fold 4] fold=(1020,1342) | train=(1192,1282) | test=(1312,1342)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.3762 | SD=1.5892
#   DBP: MAE=1.9345 | SD=1.2970
#   elapsed: 5.3s
#
# [Fold 5] fold=(1360,1682) | train=(1532,1622) | test=(1652,1682)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=13.6916 | SD=8.1253
#   DBP: MAE=8.2368 | SD=5.7273
#   elapsed: 7.5s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=5.1104 | SD=3.4367
# Avg   DBP: MAE=3.2411 | SD=2.0916
# Worst SBP: MAE=13.6916 | StdAcrossFolds(MAE)=4.3338
# Worst DBP: MAE=8.2368 | StdAcrossFolds(MAE)=2.6777
#
# --------------------------------------------------------------------------------
# [3/10] START p027884.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p027884.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 1799 / 1802
# ❌ excluded: (bp_range=0, noise/quality=3)
# [Data Ready] total_len=1799
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=345 segs (~57.50 min)
#
# [Fold 1] fold=(0,345) | train=(195,285) | test=(315,345)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=1.4611 | SD=1.6378
#   DBP: MAE=3.9848 | SD=1.0187
#   elapsed: 9.8s
#
# [Fold 2] fold=(363,708) | train=(558,648) | test=(678,708)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.6271 | SD=1.7009
#   DBP: MAE=4.1813 | SD=1.0794
#   elapsed: 8.5s
#
# [Fold 3] fold=(726,1071) | train=(921,1011) | test=(1041,1071)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=10.5983 | SD=2.1990
#   DBP: MAE=6.4684 | SD=1.3306
#   elapsed: 5.4s
#
# [Fold 4] fold=(1089,1434) | train=(1284,1374) | test=(1404,1434)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=8.0037 | SD=2.3420
#   DBP: MAE=3.8646 | SD=1.3653
#   elapsed: 6.2s
#
# [Fold 5] fold=(1452,1797) | train=(1647,1737) | test=(1767,1797)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=8.0988 | SD=4.4729
#   DBP: MAE=2.5197 | SD=2.8275
#   elapsed: 5.3s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=6.5578 | SD=2.4705
# Avg   DBP: MAE=4.2038 | SD=1.5243
# Worst SBP: MAE=10.5983 | StdAcrossFolds(MAE)=3.1779
# Worst DBP: MAE=6.4684 | StdAcrossFolds(MAE)=1.2750
#
# --------------------------------------------------------------------------------
# [4/10] START p029120.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p029120.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 2045 / 2045
# ❌ excluded: (bp_range=0, noise/quality=0)
# [Data Ready] total_len=2045
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=394 segs (~65.67 min)
#
# [Fold 1] fold=(0,394) | train=(244,334) | test=(364,394)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.6336 | SD=3.1981
#   DBP: MAE=1.1226 | SD=1.4045
#   elapsed: 5.5s
#
# [Fold 2] fold=(412,806) | train=(656,746) | test=(776,806)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.9211 | SD=3.9835
#   DBP: MAE=2.6726 | SD=1.7249
#   elapsed: 6.2s
#
# [Fold 3] fold=(824,1218) | train=(1068,1158) | test=(1188,1218)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.0629 | SD=5.2410
#   DBP: MAE=2.9094 | SD=3.9023
#   elapsed: 5.3s
#
# [Fold 4] fold=(1236,1630) | train=(1480,1570) | test=(1600,1630)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=9.7058 | SD=6.1679
#   DBP: MAE=2.7737 | SD=2.6099
#   elapsed: 6.3s
#
# [Fold 5] fold=(1648,2042) | train=(1892,1982) | test=(2012,2042)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=12.3758 | SD=4.4596
#   DBP: MAE=3.6702 | SD=1.7570
#   elapsed: 5.3s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=7.1399 | SD=4.6100
# Avg   DBP: MAE=2.6297 | SD=2.2797
# Worst SBP: MAE=12.3758 | StdAcrossFolds(MAE)=3.4671
# Worst DBP: MAE=3.6702 | StdAcrossFolds(MAE)=0.8312
#
# --------------------------------------------------------------------------------
# [5/10] START p030582.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p030582.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 2206 / 2215
# ❌ excluded: (bp_range=0, noise/quality=9)
# [Data Ready] total_len=2206
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=426 segs (~71.00 min)
#
# [Fold 1] fold=(0,426) | train=(276,366) | test=(396,426)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.5038 | SD=2.4723
#   DBP: MAE=0.8083 | SD=1.0143
#   elapsed: 6.0s
#
# [Fold 2] fold=(444,870) | train=(720,810) | test=(840,870)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.1205 | SD=3.4360
#   DBP: MAE=1.9935 | SD=1.8405
#   elapsed: 5.8s
#
# [Fold 3] fold=(888,1314) | train=(1164,1254) | test=(1284,1314)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=17.3005 | SD=6.3586
#   DBP: MAE=4.0952 | SD=3.3852
#   elapsed: 5.2s
#
# [Fold 4] fold=(1332,1758) | train=(1608,1698) | test=(1728,1758)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=0.9737 | SD=1.2376
#   DBP: MAE=0.4627 | SD=0.5531
#   elapsed: 6.3s
#
# [Fold 5] fold=(1776,2202) | train=(2052,2142) | test=(2172,2202)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=6.4968 | SD=2.8594
#   DBP: MAE=3.5348 | SD=2.3402
#   elapsed: 5.4s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=6.4791 | SD=3.2728
# Avg   DBP: MAE=2.1789 | SD=1.8266
# Worst SBP: MAE=17.3005 | StdAcrossFolds(MAE)=5.7025
# Worst DBP: MAE=4.0952 | StdAcrossFolds(MAE)=1.4401
#
# --------------------------------------------------------------------------------
# [6/10] START p030670.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p030670.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 1764 / 1764
# ❌ excluded: (bp_range=0, noise/quality=0)
# [Data Ready] total_len=1764
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=338 segs (~56.33 min)
#
# [Fold 1] fold=(0,338) | train=(188,278) | test=(308,338)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.2648 | SD=1.4396
#   DBP: MAE=0.7282 | SD=0.8507
#   elapsed: 5.6s
#
# [Fold 2] fold=(356,694) | train=(544,634) | test=(664,694)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.3869 | SD=1.6398
#   DBP: MAE=0.4713 | SD=0.6577
#   elapsed: 6.2s
#
# [Fold 3] fold=(712,1050) | train=(900,990) | test=(1020,1050)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=9.2970 | SD=1.0328
#   DBP: MAE=0.3718 | SD=0.4574
#   elapsed: 5.4s
#
# [Fold 4] fold=(1068,1406) | train=(1256,1346) | test=(1376,1406)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.1556 | SD=4.0315
#   DBP: MAE=0.8419 | SD=0.9547
#   elapsed: 6.2s
#
# [Fold 5] fold=(1424,1762) | train=(1612,1702) | test=(1732,1762)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.3397 | SD=1.7590
#   DBP: MAE=0.6850 | SD=0.6453
#   elapsed: 5.4s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=4.0888 | SD=1.9805
# Avg   DBP: MAE=0.6196 | SD=0.7132
# Worst SBP: MAE=9.2970 | StdAcrossFolds(MAE)=2.6986
# Worst DBP: MAE=0.8419 | StdAcrossFolds(MAE)=0.1725
#
# --------------------------------------------------------------------------------
# [7/10] START p042875.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p042875.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 1837 / 1837
# ❌ excluded: (bp_range=0, noise/quality=0)
# [Data Ready] total_len=1837
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=353 segs (~58.83 min)
#
# [Fold 1] fold=(0,353) | train=(203,293) | test=(323,353)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=23.0644 | SD=4.0995
#   DBP: MAE=12.2471 | SD=1.6453
#   elapsed: 5.4s
#
# [Fold 2] fold=(371,724) | train=(574,664) | test=(694,724)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.7424 | SD=18.9083
#   DBP: MAE=3.4045 | SD=2.8096
#   elapsed: 6.4s
#
# [Fold 3] fold=(742,1095) | train=(945,1035) | test=(1065,1095)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.4019 | SD=4.5314
#   DBP: MAE=1.4344 | SD=1.6452
#   elapsed: 5.3s
#
# [Fold 4] fold=(1113,1466) | train=(1316,1406) | test=(1436,1466)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=2.7649 | SD=3.4075
#   DBP: MAE=1.9494 | SD=1.1797
#   elapsed: 6.4s
#
# [Fold 5] fold=(1484,1837) | train=(1687,1777) | test=(1807,1837)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=13.8013 | SD=2.5728
#   DBP: MAE=1.1139 | SD=0.7625
#   elapsed: 5.3s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=10.5550 | SD=6.7039
# Avg   DBP: MAE=4.0299 | SD=1.6084
# Worst SBP: MAE=23.0644 | StdAcrossFolds(MAE)=7.2412
# Worst DBP: MAE=12.2471 | StdAcrossFolds(MAE)=4.1828
#
# --------------------------------------------------------------------------------
# [8/10] START p043774.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p043774.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 1943 / 1943
# ❌ excluded: (bp_range=0, noise/quality=0)
# [Data Ready] total_len=1943
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=374 segs (~62.33 min)
#
# [Fold 1] fold=(0,374) | train=(224,314) | test=(344,374)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=1.7423 | SD=1.4288
#   DBP: MAE=0.9430 | SD=1.1318
#   elapsed: 5.2s
#
# [Fold 2] fold=(392,766) | train=(616,706) | test=(736,766)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=4.4101 | SD=1.3356
#   DBP: MAE=2.7396 | SD=0.9278
#   elapsed: 6.3s
#
# [Fold 3] fold=(784,1158) | train=(1008,1098) | test=(1128,1158)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.5260 | SD=1.3277
#   DBP: MAE=3.5580 | SD=0.8884
#   elapsed: 5.2s
#
# [Fold 4] fold=(1176,1550) | train=(1400,1490) | test=(1520,1550)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.9969 | SD=2.4939
#   DBP: MAE=1.6836 | SD=1.2984
#   elapsed: 6.7s
#
# [Fold 5] fold=(1568,1942) | train=(1792,1882) | test=(1912,1942)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=3.3093 | SD=3.0539
#   DBP: MAE=1.3202 | SD=1.5968
#   elapsed: 5.3s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=4.1969 | SD=1.9280
# Avg   DBP: MAE=2.0489 | SD=1.1686
# Worst SBP: MAE=7.5260 | StdAcrossFolds(MAE)=1.8964
# Worst DBP: MAE=3.5580 | StdAcrossFolds(MAE)=0.9635
#
# --------------------------------------------------------------------------------
# [9/10] START p086210.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p086210.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 2067 / 2069
# ❌ excluded: (bp_range=0, noise/quality=2)
# [Data Ready] total_len=2067
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=399 segs (~66.50 min)
#
# [Fold 1] fold=(0,399) | train=(249,339) | test=(369,399)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=5.8433 | SD=4.4268
#   DBP: MAE=6.4521 | SD=3.8203
#   elapsed: 5.4s
#
# [Fold 2] fold=(417,816) | train=(666,756) | test=(786,816)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=34.0976 | SD=2.1943
#   DBP: MAE=19.7362 | SD=2.2820
#   elapsed: 6.3s
#
# [Fold 3] fold=(834,1233) | train=(1083,1173) | test=(1203,1233)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=6.3785 | SD=7.5809
#   DBP: MAE=1.6281 | SD=2.6594
#   elapsed: 5.3s
#
# [Fold 4] fold=(1251,1650) | train=(1500,1590) | test=(1620,1650)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=7.9525 | SD=6.8463
#   DBP: MAE=2.2929 | SD=2.5075
#   elapsed: 5.7s
#
# [Fold 5] fold=(1668,2067) | train=(1917,2007) | test=(2037,2067)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=11.3855 | SD=8.8816
#   DBP: MAE=10.8928 | SD=6.0051
#   elapsed: 5.8s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=13.1315 | SD=5.9860
# Avg   DBP: MAE=8.2004 | SD=3.4549
# Worst SBP: MAE=34.0976 | StdAcrossFolds(MAE)=10.6599
# Worst DBP: MAE=19.7362 | StdAcrossFolds(MAE)=6.6554
#
# --------------------------------------------------------------------------------
# [10/10] START p099008.mat
# --------------------------------------------------------------------------------
#
# ================================================================================
# [PATIENT] p099008.mat | filtering=True
# ================================================================================
# ✅ (Filter) kept: 1881 / 1883
# ❌ excluded: (bp_range=0, noise/quality=2)
# [Data Ready] total_len=1881
#
# === FIXED CONFIG ===
# N_FOLDS=5
# TrainDur=15m (90 segs) | TimeGap=5m (30 segs) | TestDur=5m (30 segs)
# BlockGap=3m (18 segs) | FoldLen=361 segs (~60.17 min)
#
# [Fold 1] fold=(0,361) | train=(211,301) | test=(331,361)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=26.1809 | SD=10.2653
#   DBP: MAE=5.2219 | SD=5.3502
#   elapsed: 5.3s
#
# [Fold 2] fold=(379,740) | train=(590,680) | test=(710,740)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=0.9189 | SD=0.6410
#   DBP: MAE=0.5619 | SD=0.5232
#   elapsed: 5.6s
#
# [Fold 3] fold=(758,1119) | train=(969,1059) | test=(1089,1119)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=1.6199 | SD=0.9449
#   DBP: MAE=0.6936 | SD=0.6701
#   elapsed: 5.9s
#
# [Fold 4] fold=(1137,1498) | train=(1348,1438) | test=(1468,1498)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=31.0769 | SD=2.9707
#   DBP: MAE=22.0477 | SD=2.4940
#   elapsed: 5.3s
#
# [Fold 5] fold=(1516,1877) | train=(1727,1817) | test=(1847,1877)
#   sizes Train/Val/Test: 72/18/30
#   SBP: MAE=10.4583 | SD=6.9098
#   DBP: MAE=1.8739 | SD=2.1700
#   elapsed: 6.3s
#
# --- PATIENT SUMMARY ---
# ValidFolds: 5/5
# Avg   SBP: MAE=14.0510 | SD=4.3463
# Avg   DBP: MAE=6.0798 | SD=2.2415
# Worst SBP: MAE=31.0769 | StdAcrossFolds(MAE)=12.4652
# Worst DBP: MAE=22.0477 | StdAcrossFolds(MAE)=8.1591
#
# ################################################################################
# [FINAL SUMMARY] fixed config | filtering=True | used=10/10
# ################################################################################
# AvgMAE SBP: mean=7.8073 | std=3.5571
# AvgMAE DBP: mean=3.8017 | std=2.1919
# AvgSD  SBP: mean=3.9267 | std=1.6171
# AvgSD  DBP: mean=1.9246 | std=0.7510
# WorstMAE SBP: mean=17.2111 | std=9.2175
# WorstMAE DBP: mean=9.1879 | std=7.1121
#
# [ALL DONE] Total elapsed: 408.1s
